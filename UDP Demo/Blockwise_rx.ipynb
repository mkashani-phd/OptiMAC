# %%
import socket
import hmac
import numpy as np
import time

def receive_and_verify(sock, key, block_size_bytes=128):
    received_data = {}
    total_verified_data = 0
    start_time = time.time()  # Start time of receiving

    while True:
        data, _ = sock.recvfrom(4096)
        if data == b'END':
            break
        
        block_index = int.from_bytes(data[:4], 'big')
        block = data[4:-48]
        received_mac = data[-48:]
        
        expected_mac = hmac.new(key, block, digestmod='sha384').digest()
        
        if received_mac == expected_mac:
            # print(f"Block {block_index} is verified")
            total_verified_data += len(block)  # Count useful data as verified
            received_data[block_index] = block
        else:
            print(f"Block {block_index} failed verification")
    
    end_time = time.time()  # End time of receiving
    receiving_time = end_time - start_time  # Calculate total receiving time

    complete_message = b''.join(received_data[i] for i in sorted(received_data.keys()))
    print(f"Complete message: {complete_message.decode('utf-8')}")
    
    print(f"\nReceiving Time: {receiving_time} seconds")
    print(f"Goodput (useful data received): {total_verified_data * 8} bits")

# Example usage
ip = "0.0.0.0"
port = 23422
sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
sock.bind((ip, port))

key = b'secret_key'

receive_and_verify(sock, key)
sock.close()
# Out:
# Block 0 is verified
# Block 1 is verified
# Block 2 is verified
# Block 3 is verified
# Block 4 is verified
# Block 5 is verified
# Block 6 is verified
# Block 7 is verified
# Block 8 is verified
# Block 9 is verified
# Block 10 is verified
# Block 11 is verified
# Block 12 is verified
# Block 13 is verified
# Block 14 is verified
# Block 15 is verified
# Block 16 is verified
# Block 17 is verified
# Block 18 is verified
# Block 19 is verified
# Block 20 is verified
# Block 21 is verified
# Block 22 is verified
# Block 23 is verified
# Block 24 is verified
# Block 25 is verified
# Block 26 is verified
# Block 27 is verified
# Block 28 is verified
# Block 29 is verified
# Block 30 is verified
# Block 31 is verified
# Block 32 is verified
# Block 33 is verified
# Block 34 is verified
# Block 35 is verified
# Block 36 is verified
# Block 37 is verified
# Block 38 is verified
# Block 39 is verified
# Block 40 is verified
# Block 41 is verified
# Block 42 is verified
# Block 43 is verified
# Block 44 is verified
# Block 45 is verified
# Block 46 is verified
# Block 47 is verified
# Block 48 is verified
# Block 49 is verified
# Block 50 is verified
# Block 51 is verified
# Block 52 is verified
# Block 53 is verified
# Block 54 is verified
# Block 55 is verified
# Block 56 is verified
# Block 57 is verified
# Block 58 is verified
# Block 59 is verified
# Block 60 is verified
# Block 61 is verified
# Block 62 is verified
# Block 63 is verified
# Block 64 is verified
# Block 65 is verified
# Block 66 is verified
# Block 67 is verified
# Block 68 is verified
# Block 69 is verified
# Block 70 is verified
# Block 71 is verified
# Block 72 is verified
# Block 73 is verified
# Block 74 is verified
# Block 75 is verified
# Block 76 is verified
# Block 77 is verified
# Block 78 is verified
# Block 79 is verified
# Block 80 is verified
# Block 81 is verified
# Block 82 is verified
# Block 83 is verified
# Block 84 is verified
# Block 85 is verified
# Block 86 is verified
# Block 87 is verified
# Block 88 is verified
# Block 89 is verified
# Block 90 is verified
# Block 91 is verified
# Block 92 is verified
# Block 93 is verified
# Block 94 is verified
# Block 95 is verified
# Block 96 is verified
# Block 97 is verified
# Block 98 is verified
# Block 99 is verified
# Block 100 is verified
# Block 101 is verified
# Block 102 is verified
# Block 103 is verified
# Block 104 is verified
# Block 105 is verified
# Block 106 is verified
# Block 107 is verified
# Block 108 is verified
# Block 109 is verified
# Block 110 is verified
# Block 111 is verified
# Block 112 is verified
# Block 113 is verified
# Block 114 is verified
# Block 115 is verified
# Block 116 is verified
# Block 117 is verified
# Block 118 is verified
# Block 119 is verified
# Block 120 is verified
# Block 121 is verified
# Block 122 is verified
# Block 123 is verified
# Block 124 is verified
# Block 125 is verified
# Block 126 is verified
# Block 127 is verified
# Block 128 is verified
# Block 129 is verified
# Block 130 is verified
# Block 131 is verified
# Block 132 is verified
# Block 133 is verified
# Block 134 is verified
# Block 135 is verified
# Block 136 is verified
# Block 137 is verified
# Block 138 is verified
# Block 139 is verified
# Block 140 is verified
# Block 141 is verified
# Block 142 is verified
# Block 143 is verified
# Block 144 is verified
# Block 145 is verified
# Block 146 is verified
# Block 147 is verified
# Block 148 is verified
# Block 149 is verified
# Block 150 is verified
# Block 151 is verified
# Block 152 is verified
# Block 153 is verified
# Block 154 is verified
# Block 155 is verified
# Block 156 is verified
# Block 157 is verified
# Block 158 is verified
# Block 159 is verified
# Block 160 is verified
# Block 161 is verified
# Block 162 is verified
# Block 163 is verified
# Block 164 is verified
# Block 165 is verified
# Block 166 is verified
# Block 167 is verified
# Block 168 is verified
# Block 169 is verified
# Block 170 is verified
# Block 171 is verified
# Block 172 is verified
# Block 173 is verified
# Block 174 is verified
# Block 175 is verified
# Block 176 is verified
# Block 177 is verified
# Block 178 is verified
# Block 179 is verified
# Block 180 is verified
# Block 181 is verified
# Block 182 is verified
# Block 183 is verified
# Block 184 is verified
# Block 185 is verified
# Block 186 is verified
# Block 187 is verified
# Block 188 is verified
# Block 189 is verified
# Block 190 is verified
# Block 191 is verified
# Block 192 is verified
# Block 193 is verified
# Block 194 is verified
# Block 195 is verified
# Block 196 is verified
# Block 197 is verified
# Block 198 is verified
# Block 199 is verified
# Block 200 is verified
# Block 201 is verified
# Block 202 is verified
# Block 203 is verified
# Block 204 is verified
# Block 205 is verified
# Block 206 is verified
# Block 207 is verified
# Block 208 is verified
# Block 209 is verified
# Block 210 is verified
# Block 211 is verified
# Block 212 is verified
# Block 213 is verified
# Block 214 is verified
# Block 215 is verified
# Block 216 is verified
# Block 217 is verified
# Block 218 is verified
# Block 219 is verified
# Block 220 is verified
# Block 221 is verified
# Block 222 is verified
# Block 223 is verified
# Block 224 is verified
# Block 225 is verified
# Block 226 is verified
# Block 227 is verified
# Block 228 is verified
# Block 229 is verified
# Block 230 is verified
# Block 231 is verified
# Block 232 is verified
# Block 233 is verified
# Block 234 is verified
# Block 235 is verified
# Block 236 is verified
# Block 237 is verified
# Block 238 is verified
# Block 239 is verified
# Block 240 is verified
# Block 241 is verified
# Block 242 is verified
# Block 243 is verified
# Block 244 is verified
# Block 245 is verified
# Block 246 is verified
# Block 247 is verified
# Block 248 is verified
# Block 249 is verified
# Block 250 is verified
# Block 251 is verified
# Block 252 is verified
# Block 253 is verified
# Block 254 is verified
# Block 255 is verified
# Block 256 is verified
# Block 257 is verified
# Block 258 is verified
# Block 259 is verified
# Block 260 is verified
# Block 261 is verified
# Block 262 is verified
# Block 263 is verified
# Block 264 is verified
# Block 265 is verified
# Block 266 is verified
# Block 267 is verified
# Block 268 is verified
# Block 269 is verified
# Block 270 is verified
# Block 271 is verified
# Block 272 is verified
# Block 273 is verified
# Block 274 is verified
# Block 275 is verified
# Block 276 is verified
# Block 277 is verified
# Block 278 is verified
# Block 279 is verified
# Block 280 is verified
# Block 281 is verified
# Block 282 is verified
# Block 283 is verified
# Block 284 is verified
# Block 285 is verified
# Block 286 is verified
# Block 287 is verified
# Block 288 is verified
# Block 289 is verified
# Block 290 is verified
# Block 291 is verified
# Block 292 is verified
# Block 293 is verified
# Block 294 is verified
# Block 295 is verified
# Block 296 is verified
# Block 297 is verified
# Block 298 is verified
# Block 299 is verified
# Block 300 is verified
# Block 301 is verified
# Block 302 is verified
# Block 303 is verified
# Block 304 is verified
# Block 305 is verified
# Block 306 is verified
# Block 307 is verified
# Block 308 is verified
# Block 309 is verified
# Block 310 is verified
# Block 311 is verified
# Block 312 is verified
# Block 313 is verified
# Block 314 is verified
# Block 315 is verified
# Block 316 is verified
# Block 317 is verified
# Block 318 is verified
# Block 319 is verified
# Block 320 is verified
# Block 321 is verified
# Block 322 is verified
# Block 323 is verified
# Block 324 is verified
# Block 325 is verified
# Block 326 is verified
# Block 327 is verified
# Block 328 is verified
# Block 329 is verified
# Block 330 is verified
# Block 331 is verified
# Block 332 is verified
# Block 333 is verified
# Block 334 is verified
# Block 335 is verified
# Block 336 is verified
# Block 337 is verified
# Block 338 is verified
# Block 339 is verified
# Block 340 is verified
# Block 341 is verified
# Block 342 is verified
# Block 343 is verified
# Block 344 is verified
# Block 345 is verified
# Block 346 is verified
# Block 347 is verified
# Block 348 is verified
# Block 349 is verified
# Block 350 is verified
# Block 351 is verified
# Block 352 is verified
# Block 353 is verified
# Block 354 is verified
# Block 355 is verified
# Block 356 is verified
# Block 357 is verified
# Block 358 is verified
# Block 359 is verified
# Block 360 is verified
# Block 361 is verified
# Block 362 is verified
# Block 363 is verified
# Block 364 is verified
# Block 365 is verified
# Block 366 is verified
# Block 367 is verified
# Block 368 is verified
# Block 369 is verified
# Block 370 is verified
# Block 371 is verified
# Block 372 is verified
# Block 373 is verified
# Block 374 is verified
# Block 375 is verified
# Block 376 is verified
# Block 377 is verified
# Block 378 is verified
# Block 379 is verified
# Block 380 is verified
# Block 381 is verified
# Block 382 is verified
# Block 383 is verified
# Block 384 is verified
# Block 385 is verified
# Block 386 is verified
# Block 387 is verified
# Block 388 is verified
# Block 389 is verified
# Block 390 is verified
# Block 391 is verified
# Block 392 is verified
# Block 393 is verified
# Block 394 is verified
# Block 395 is verified
# Block 396 is verified
# Block 397 is verified
# Block 398 is verified
# Block 399 is verified
# Block 400 is verified
# Block 401 is verified
# Block 402 is verified
# Block 403 is verified
# Block 404 is verified
# Block 405 is verified
# Block 406 is verified
# Block 407 is verified
# Block 408 is verified
# Block 409 is verified
# Block 410 is verified
# Block 411 is verified
# Block 412 is verified
# Block 413 is verified
# Block 414 is verified
# Block 415 is verified
# Block 416 is verified
# Block 417 is verified
# Block 418 is verified
# Block 419 is verified
# Block 420 is verified
# Block 421 is verified
# Block 422 is verified
# Block 423 is verified
# Block 424 is verified
# Block 425 is verified
# Block 426 is verified
# Block 427 is verified
# Block 428 is verified
# Block 429 is verified
# Block 430 is verified
# Block 431 is verified
# Block 432 is verified
# Block 433 is verified
# Block 434 is verified
# Block 435 is verified
# Block 436 is verified
# Block 437 is verified
# Block 438 is verified
# Block 439 is verified
# Block 440 is verified
# Block 441 is verified
# Block 442 is verified
# Block 443 is verified
# Block 444 is verified
# Block 445 is verified
# Block 446 is verified
# Block 447 is verified
# Block 448 is verified
# Block 449 is verified
# Block 450 is verified
# Block 451 is verified
# Block 452 is verified
# Block 453 is verified
# Block 454 is verified
# Block 455 is verified
# Block 456 is verified
# Block 457 is verified
# Block 458 is verified
# Block 459 is verified
# Block 460 is verified
# Block 461 is verified
# Block 462 is verified
# Block 463 is verified
# Block 464 is verified
# Block 465 is verified
# Block 466 is verified
# Block 467 is verified
# Block 468 is verified
# Block 469 is verified
# Block 470 is verified
# Block 471 is verified
# Block 515 is verified
# Block 516 is verified
# Block 517 is verified
# Block 518 is verified
# Block 519 is verified
# Block 520 is verified
# Block 521 is verified
# Block 522 is verified
# Block 523 is verified
# Block 524 is verified
# Block 525 is verified
# Block 526 is verified
# Block 527 is verified
# Block 528 is verified
# Block 529 is verified
# Block 530 is verified
# Block 531 is verified
# Block 532 is verified
# Block 533 is verified
# Block 534 is verified
# Block 535 is verified
# Block 536 is verified
# Block 537 is verified
# Block 538 is verified
# Block 539 is verified
# Block 540 is verified
# Block 541 is verified
# Block 542 is verified
# Block 543 is verified
# Block 544 is verified
# Block 545 is verified
# Block 546 is verified
# Block 547 is verified
# Block 548 is verified
# Block 549 is verified
# Block 550 is verified
# Block 551 is verified
# Block 552 is verified
# Block 553 is verified
# Block 554 is verified
# Block 555 is verified
# Block 556 is verified
# Block 557 is verified
# Block 558 is verified
# Block 559 is verified
# Block 560 is verified
# Block 561 is verified
# Block 562 is verified
# Block 563 is verified
# Block 564 is verified
# Block 565 is verified
# Block 566 is verified
# Block 567 is verified
# Block 568 is verified
# Block 569 is verified
# Block 570 is verified
# Block 571 is verified
# Block 572 is verified
# Block 573 is verified
# Block 574 is verified
# Block 614 is verified
# Block 615 is verified
# Block 616 is verified
# Block 617 is verified
# Block 618 is verified
# Block 619 is verified
# Block 620 is verified
# Block 621 is verified
# Block 622 is verified
# Block 623 is verified
# Block 624 is verified
# Block 625 is verified
# Block 626 is verified
# Block 627 is verified
# Block 628 is verified
# Block 629 is verified
# Block 630 is verified
# Block 631 is verified
# Block 632 is verified
# Block 633 is verified
# Block 634 is verified
# Block 635 is verified
# Block 636 is verified
# Block 637 is verified
# Block 638 is verified
# Block 639 is verified
# Block 640 is verified
# Block 641 is verified
# Block 642 is verified
# Block 643 is verified
# Block 644 is verified
# Block 645 is verified
# Block 646 is verified
# Block 647 is verified
# Block 648 is verified
# Block 649 is verified
# Block 650 is verified
# Block 651 is verified
# Block 652 is verified
# Block 653 is verified
# Block 654 is verified
# Block 655 is verified
# Block 656 is verified
# Block 657 is verified
# Block 658 is verified
# Block 659 is verified
# Block 660 is verified
# Block 661 is verified
# Block 662 is verified
# Block 663 is verified
# Block 664 is verified
# Block 665 is verified
# Block 666 is verified
# Block 667 is verified
# Block 668 is verified
# Block 669 is verified
# Block 670 is verified
# Block 671 is verified
# Block 672 is verified
# Block 673 is verified
# Block 713 is verified
# Block 714 is verified
# Block 715 is verified
# Block 716 is verified
# Block 717 is verified
# Block 718 is verified
# Block 719 is verified
# Block 720 is verified
# Block 721 is verified
# Block 722 is verified
# Block 723 is verified
# Block 724 is verified
# Block 725 is verified
# Block 726 is verified
# Block 727 is verified
# Block 728 is verified
# Block 729 is verified
# Block 730 is verified
# Block 731 is verified
# Block 732 is verified
# Block 733 is verified
# Block 734 is verified
# Block 735 is verified
# Block 736 is verified
# Block 737 is verified
# Block 738 is verified
# Block 739 is verified
# Block 740 is verified
# Block 741 is verified
# Block 742 is verified
# Block 743 is verified
# Block 744 is verified
# Block 745 is verified
# Block 746 is verified
# Block 747 is verified
# Block 748 is verified
# Block 749 is verified
# Block 750 is verified
# Block 751 is verified
# Block 752 is verified
# Block 753 is verified
# Block 754 is verified
# Block 755 is verified
# Block 756 is verified
# Block 757 is verified
# Block 758 is verified
# Block 759 is verified
# Block 760 is verified
# Block 761 is verified
# Block 762 is verified
# Block 763 is verified
# Block 764 is verified
# Block 765 is verified
# Block 766 is verified
# Block 767 is verified
# Block 768 is verified
# Block 769 is verified
# Block 770 is verified
# Block 771 is verified
# Block 772 is verified
# Block 814 is verified
# Block 815 is verified
# Block 816 is verified
# Block 817 is verified
# Block 818 is verified
# Block 819 is verified
# Block 820 is verified
# Block 821 is verified
# Block 822 is verified
# Block 823 is verified
# Block 824 is verified
# Block 825 is verified
# Block 826 is verified
# Block 827 is verified
# Block 828 is verified
# Block 829 is verified
# Block 830 is verified
# Block 831 is verified
# Block 832 is verified
# Block 833 is verified
# Block 834 is verified
# Block 835 is verified
# Block 836 is verified
# Block 837 is verified
# Block 838 is verified
# Block 839 is verified
# Block 840 is verified
# Block 841 is verified
# Block 842 is verified
# Block 843 is verified
# Block 844 is verified
# Block 845 is verified
# Block 846 is verified
# Block 847 is verified
# Block 848 is verified
# Block 849 is verified
# Block 850 is verified
# Block 851 is verified
# Block 852 is verified
# Block 853 is verified
# Block 854 is verified
# Block 855 is verified
# Block 856 is verified
# Block 857 is verified
# Block 858 is verified
# Block 859 is verified
# Block 860 is verified
# Block 861 is verified
# Block 862 is verified
# Block 863 is verified
# Block 864 is verified
# Block 865 is verified
# Block 866 is verified
# Block 867 is verified
# Block 868 is verified
# Block 869 is verified
# Block 870 is verified
# Block 871 is verified
# Block 872 is verified
# Block 873 is verified
# Block 922 is verified
# Block 923 is verified
# Block 924 is verified
# Block 925 is verified
# Block 926 is verified
# Block 927 is verified
# Block 928 is verified
# Block 929 is verified
# Block 930 is verified
# Block 931 is verified
# Block 932 is verified
# Block 933 is verified
# Block 934 is verified
# Block 935 is verified
# Block 936 is verified
# Block 937 is verified
# Block 938 is verified
# Block 939 is verified
# Block 940 is verified
# Block 941 is verified
# Block 942 is verified
# Block 943 is verified
# Block 944 is verified
# Block 945 is verified
# Block 946 is verified
# Block 947 is verified
# Block 948 is verified
# Block 949 is verified
# Block 950 is verified
# Block 951 is verified
# Block 952 is verified
# Block 953 is verified
# Block 954 is verified
# Block 955 is verified
# Block 956 is verified
# Block 957 is verified
# Block 958 is verified
# Block 959 is verified
# Block 960 is verified
# Block 961 is verified
# Block 962 is verified
# Block 963 is verified
# Block 964 is verified
# Block 965 is verified
# Block 966 is verified
# Block 967 is verified
# Block 968 is verified
# Block 969 is verified
# Block 970 is verified
# Block 971 is verified
# Block 972 is verified
# Block 973 is verified
# Block 974 is verified
# Block 975 is verified
# Block 976 is verified
# Block 977 is verified
# Block 978 is verified
# Block 979 is verified
# Block 980 is verified
# Block 981 is verified
# Block 1028 is verified
# Block 1029 is verified
# Block 1030 is verified
# Block 1031 is verified
# Block 1032 is verified
# Block 1033 is verified
# Block 1034 is verified
# Block 1035 is verified
# Block 1036 is verified
# Block 1037 is verified
# Block 1038 is verified
# Block 1039 is verified
# Block 1040 is verified
# Block 1041 is verified
# Block 1042 is verified
# Block 1043 is verified
# Block 1044 is verified
# Block 1045 is verified
# Block 1046 is verified
# Block 1047 is verified
# Block 1048 is verified
# Block 1049 is verified
# Block 1050 is verified
# Block 1051 is verified
# Block 1052 is verified
# Block 1053 is verified
# Block 1054 is verified
# Block 1055 is verified
# Block 1056 is verified
# Block 1057 is verified
# Block 1058 is verified
# Block 1059 is verified
# Block 1060 is verified
# Block 1061 is verified
# Block 1062 is verified
# Block 1063 is verified
# Block 1064 is verified
# Block 1065 is verified
# Block 1066 is verified
# Block 1067 is verified
# Block 1068 is verified
# Block 1069 is verified
# Block 1070 is verified
# Block 1071 is verified
# Block 1072 is verified
# Block 1073 is verified
# Block 1074 is verified
# Block 1075 is verified
# Block 1076 is verified
# Block 1077 is verified
# Block 1078 is verified
# Block 1079 is verified
# Block 1080 is verified
# Block 1081 is verified
# Block 1082 is verified
# Block 1083 is verified
# Block 1084 is verified
# Block 1085 is verified
# Block 1086 is verified
# Block 1087 is verified
# Block 1173 is verified
# Block 1174 is verified
# Block 1175 is verified
# Block 1176 is verified
# Block 1177 is verified
# Block 1178 is verified
# Block 1179 is verified
# Block 1180 is verified
# Block 1181 is verified
# Block 1182 is verified
# Block 1183 is verified
# Block 1184 is verified
# Block 1185 is verified
# Block 1186 is verified
# Block 1187 is verified
# Block 1188 is verified
# Block 1189 is verified
# Block 1190 is verified
# Block 1191 is verified
# Block 1192 is verified
# Block 1193 is verified
# Block 1194 is verified
# Block 1195 is verified
# Block 1196 is verified
# Block 1197 is verified
# Block 1198 is verified
# Block 1199 is verified
# Block 1200 is verified
# Block 1201 is verified
# Block 1202 is verified
# Block 1203 is verified
# Block 1204 is verified
# Block 1205 is verified
# Block 1206 is verified
# Block 1207 is verified
# Block 1208 is verified
# Block 1209 is verified
# Block 1210 is verified
# Block 1211 is verified
# Block 1212 is verified
# Block 1213 is verified
# Block 1214 is verified
# Block 1215 is verified
# Block 1216 is verified
# Block 1217 is verified
# Block 1218 is verified
# Block 1219 is verified
# Block 1220 is verified
# Block 1221 is verified
# Block 1222 is verified
# Block 1223 is verified
# Block 1224 is verified
# Block 1225 is verified
# Block 1226 is verified
# Block 1227 is verified
# Block 1228 is verified
# Block 1229 is verified
# Block 1230 is verified
# Block 1231 is verified
# Block 1232 is verified
# Block 1260 is verified
# Block 1261 is verified
# Block 1262 is verified
# Block 1263 is verified
# Block 1264 is verified
# Block 1265 is verified
# Block 1266 is verified
# Block 1267 is verified
# Block 1268 is verified
# Block 1269 is verified
# Block 1270 is verified
# Block 1271 is verified
# Block 1272 is verified
# Block 1273 is verified
# Block 1274 is verified
# Block 1275 is verified
# Block 1276 is verified
# Block 1277 is verified
# Block 1278 is verified
# Block 1279 is verified
# Block 1280 is verified
# Block 1281 is verified
# Block 1282 is verified
# Block 1283 is verified
# Block 1284 is verified
# Block 1285 is verified
# Block 1286 is verified
# Block 1287 is verified
# Block 1288 is verified
# Block 1289 is verified
# Block 1290 is verified
# Block 1291 is verified
# Block 1292 is verified
# Block 1293 is verified
# Block 1294 is verified
# Block 1295 is verified
# Block 1296 is verified
# Block 1297 is verified
# Block 1298 is verified
# Block 1299 is verified
# Block 1300 is verified
# Block 1301 is verified
# Block 1302 is verified
# Block 1303 is verified
# Block 1304 is verified
# Block 1305 is verified
# Block 1306 is verified
# Block 1307 is verified
# Block 1308 is verified
# Block 1309 is verified
# Block 1310 is verified
# Block 1311 is verified
# Block 1312 is verified
# Block 1313 is verified
# Block 1314 is verified
# Block 1315 is verified
# Block 1316 is verified
# Block 1317 is verified
# Block 1318 is verified
# Block 1319 is verified
# Block 1359 is verified
# Block 1360 is verified
# Block 1361 is verified
# Block 1362 is verified
# Block 1363 is verified
# Block 1364 is verified
# Block 1365 is verified
# Block 1366 is verified
# Block 1367 is verified
# Block 1368 is verified
# Block 1369 is verified
# Block 1370 is verified
# Block 1371 is verified
# Block 1372 is verified
# Block 1373 is verified
# Block 1374 is verified
# Block 1375 is verified
# Block 1376 is verified
# Block 1377 is verified
# Block 1378 is verified
# Block 1379 is verified
# Block 1380 is verified
# Block 1381 is verified
# Block 1382 is verified
# Block 1383 is verified
# Block 1384 is verified
# Block 1385 is verified
# Block 1386 is verified
# Block 1387 is verified
# Block 1388 is verified
# Block 1389 is verified
# Block 1390 is verified
# Block 1391 is verified
# Block 1392 is verified
# Block 1393 is verified
# Block 1394 is verified
# Block 1395 is verified
# Block 1396 is verified
# Block 1397 is verified
# Block 1398 is verified
# Block 1399 is verified
# Block 1400 is verified
# Block 1401 is verified
# Block 1402 is verified
# Block 1403 is verified
# Block 1404 is verified
# Block 1405 is verified
# Block 1406 is verified
# Block 1407 is verified
# Block 1408 is verified
# Block 1409 is verified
# Block 1410 is verified
# Block 1411 is verified
# Block 1412 is verified
# Block 1413 is verified
# Block 1414 is verified
# Block 1415 is verified
# Block 1416 is verified
# Block 1417 is verified
# Block 1418 is verified
# Block 1444 is verified
# Block 1445 is verified
# Block 1446 is verified
# Block 1447 is verified
# Block 1448 is verified
# Block 1449 is verified
# Block 1450 is verified
# Block 1451 is verified
# Block 1452 is verified
# Block 1453 is verified
# Block 1454 is verified
# Block 1455 is verified
# Block 1456 is verified
# Block 1457 is verified
# Block 1458 is verified
# Block 1459 is verified
# Block 1460 is verified
# Block 1461 is verified
# Block 1462 is verified
# Block 1463 is verified
# Block 1464 is verified
# Block 1465 is verified
# Block 1466 is verified
# Block 1467 is verified
# Block 1468 is verified
# Block 1469 is verified
# Block 1470 is verified
# Block 1471 is verified
# Block 1472 is verified
# Block 1473 is verified
# Block 1474 is verified
# Block 1475 is verified
# Block 1476 is verified
# Block 1477 is verified
# Block 1478 is verified
# Block 1479 is verified
# Block 1480 is verified
# Block 1481 is verified
# Block 1482 is verified
# Block 1483 is verified
# Block 1484 is verified
# Block 1485 is verified
# Block 1486 is verified
# Block 1487 is verified
# Block 1488 is verified
# Block 1489 is verified
# Block 1490 is verified
# Block 1491 is verified
# Block 1492 is verified
# Block 1493 is verified
# Block 1494 is verified
# Block 1495 is verified
# Block 1496 is verified
# Block 1497 is verified
# Block 1498 is verified
# Block 1499 is verified
# Block 1500 is verified
# Block 1501 is verified
# Block 1502 is verified
# Block 1503 is verified
# Block 1538 is verified
# Block 1539 is verified
# Block 1540 is verified
# Block 1541 is verified
# Block 1542 is verified
# Block 1543 is verified
# Block 1544 is verified
# Block 1545 is verified
# Block 1546 is verified
# Block 1547 is verified
# Block 1548 is verified
# Block 1549 is verified
# Block 1550 is verified
# Block 1551 is verified
# Block 1552 is verified
# Block 1553 is verified
# Block 1554 is verified
# Block 1555 is verified
# Block 1556 is verified
# Block 1557 is verified
# Block 1558 is verified
# Block 1559 is verified
# Block 1560 is verified
# Block 1561 is verified
# Block 1562 is verified
# Block 1563 is verified
# Block 1564 is verified
# Block 1565 is verified
# Block 1566 is verified
# Block 1567 is verified
# Block 1568 is verified
# Block 1569 is verified
# Block 1570 is verified
# Block 1571 is verified
# Block 1572 is verified
# Block 1573 is verified
# Block 1574 is verified
# Block 1575 is verified
# Block 1576 is verified
# Block 1577 is verified
# Block 1578 is verified
# Block 1579 is verified
# Block 1580 is verified
# Block 1581 is verified
# Block 1582 is verified
# Block 1583 is verified
# Block 1584 is verified
# Block 1585 is verified
# Block 1586 is verified
# Block 1587 is verified
# Block 1588 is verified
# Block 1589 is verified
# Block 1590 is verified
# Block 1591 is verified
# Block 1592 is verified
# Block 1593 is verified
# Block 1594 is verified
# Block 1595 is verified
# Block 1596 is verified
# Block 1597 is verified
# Block 1620 is verified
# Block 1621 is verified
# Block 1622 is verified
# Block 1623 is verified
# Block 1624 is verified
# Block 1625 is verified
# Block 1626 is verified
# Block 1627 is verified
# Block 1628 is verified
# Block 1629 is verified
# Block 1630 is verified
# Block 1631 is verified
# Block 1632 is verified
# Block 1633 is verified
# Block 1634 is verified
# Block 1635 is verified
# Block 1636 is verified
# Block 1637 is verified
# Block 1638 is verified
# Block 1639 is verified
# Block 1640 is verified
# Block 1641 is verified
# Block 1642 is verified
# Block 1643 is verified
# Block 1644 is verified
# Block 1645 is verified
# Block 1646 is verified
# Block 1647 is verified
# Block 1648 is verified
# Block 1649 is verified
# Block 1650 is verified
# Block 1651 is verified
# Block 1652 is verified
# Block 1653 is verified
# Block 1654 is verified
# Block 1655 is verified
# Block 1656 is verified
# Block 1657 is verified
# Block 1658 is verified
# Block 1659 is verified
# Block 1660 is verified
# Block 1661 is verified
# Block 1662 is verified
# Block 1663 is verified
# Block 1664 is verified
# Block 1665 is verified
# Block 1666 is verified
# Block 1667 is verified
# Block 1668 is verified
# Block 1669 is verified
# Block 1670 is verified
# Block 1671 is verified
# Block 1672 is verified
# Block 1673 is verified
# Block 1674 is verified
# Block 1675 is verified
# Block 1676 is verified
# Block 1677 is verified
# Block 1678 is verified
# Block 1679 is verified
# Block 1720 is verified
# Block 1721 is verified
# Block 1722 is verified
# Block 1723 is verified
# Block 1724 is verified
# Block 1725 is verified
# Block 1726 is verified
# Block 1727 is verified
# Block 1728 is verified
# Block 1729 is verified
# Block 1730 is verified
# Block 1731 is verified
# Block 1732 is verified
# Block 1733 is verified
# Block 1734 is verified
# Block 1735 is verified
# Block 1736 is verified
# Block 1737 is verified
# Block 1738 is verified
# Block 1739 is verified
# Block 1740 is verified
# Block 1741 is verified
# Block 1742 is verified
# Block 1743 is verified
# Block 1744 is verified
# Block 1745 is verified
# Block 1746 is verified
# Block 1747 is verified
# Block 1748 is verified
# Block 1749 is verified
# Block 1750 is verified
# Block 1751 is verified
# Block 1752 is verified
# Block 1753 is verified
# Block 1754 is verified
# Block 1755 is verified
# Block 1756 is verified
# Block 1757 is verified
# Block 1758 is verified
# Block 1759 is verified
# Block 1760 is verified
# Block 1761 is verified
# Block 1762 is verified
# Block 1763 is verified
# Block 1764 is verified
# Block 1765 is verified
# Block 1766 is verified
# Block 1767 is verified
# Block 1768 is verified
# Block 1769 is verified
# Block 1770 is verified
# Block 1771 is verified
# Block 1772 is verified
# Block 1773 is verified
# Block 1774 is verified
# Block 1775 is verified
# Block 1776 is verified
# Block 1777 is verified
# Block 1778 is verified
# Block 1779 is verified
# Block 1839 is verified
# Block 1840 is verified
# Block 1841 is verified
# Block 1842 is verified
# Block 1843 is verified
# Block 1844 is verified
# Block 1845 is verified
# Block 1846 is verified
# Block 1847 is verified
# Complete message: This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# ...
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  bloity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
# This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.This test shows  2D integrity check is better than  blockwise integrity.
#
#
# Receiving Time: 16.283191442489624 seconds
# Goodput (useful data received): 1290496 bits
