# %%
import socket
import rawpy
import time
import numpy as np
from PIL import Image
import hmac



# Divide the image into into 920 bit chunks
def divide_image_into_pixel_groups(image_path, group_pixel_count=30):
    # Step 1: Loading the Image
    with Image.open(image_path).convert('RGB') as img:
        width, height = img.size
        

        # Step 2: Calculating Group Dimensions
        # Find a suitable width and height for the groups that would approximately contain 1024 pixels
        group_width = int(np.sqrt(group_pixel_count))
        group_height = group_pixel_count // group_width

        # Adjust group_height in case group_width * group_height < 1024
        if group_width * group_height < group_pixel_count:
            group_height += 1

        groups = []

        # Step 3: Dividing the Image
        for y in range(0, height, group_height):
            for x in range(0, width, group_width):
                # Define the bounding box for each group
                box = (x, y, x + group_width, y + group_height)
                # Crop the image to the box to get the group
                group = img.crop(box)
                groups.append(group)

        return groups


def send_bmp_image(file_path, ip, port, p):
    groups = divide_image_into_pixel_groups(file_path)
    

    # Create a UDP socket
    sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)

    i =0
    try:
        for pixel_group in groups:
  
            chunk = pixel_group.tobytes()
            # Send chunk index and chunk data
            if np.random.rand() < p:
                mac = hmac.new(b'key', chunk, 'sha384').digest()
                sock.sendto(i.to_bytes(4, 'big') + chunk + mac , (ip, port))
                time.sleep(0.0001)
            else:
                print("modify, sequence number = ", i)
                mac = hmac.new(b'key', b'modified', 'sha384').digest()
                if np.random.rand() < .5:
                    sock.sendto(i.to_bytes(4, 'big') + chunk + mac, (ip, port))
                time.sleep(0.0001)
            if i % 10000 == 0:
                print("Sent chunk ", i, " of ", len(groups))
            i += 1
            

        # Send a final message indicating completion
        sock.sendto(b'END', (ip, port))
    finally:
        print("Image sent")
        sock.close()
    return i

# Example usage
file_path = 'output.png'
destination_ip = '0.0.0.0'
destination_port = 23423


# packet success probability
p = .9
send_bmp_image(file_path, destination_ip, destination_port, p = p)
# Out:
# Sent chunk  0  of  78012
# modify, sequence number =  3
# modify, sequence number =  14
# modify, sequence number =  16
# modify, sequence number =  45
# modify, sequence number =  54
# modify, sequence number =  55
# modify, sequence number =  60
# modify, sequence number =  74
# modify, sequence number =  81
# modify, sequence number =  89
# modify, sequence number =  108
# modify, sequence number =  109
# modify, sequence number =  120
# modify, sequence number =  141
# modify, sequence number =  158
# modify, sequence number =  159
# modify, sequence number =  183
# modify, sequence number =  188
# modify, sequence number =  218
# modify, sequence number =  226
# modify, sequence number =  252
# modify, sequence number =  258
# modify, sequence number =  272
# modify, sequence number =  277
# modify, sequence number =  279
# modify, sequence number =  281
# modify, sequence number =  287
# modify, sequence number =  290
# modify, sequence number =  294
# modify, sequence number =  317
# modify, sequence number =  325
# modify, sequence number =  336
# modify, sequence number =  343
# modify, sequence number =  350
# modify, sequence number =  366
# modify, sequence number =  372
# modify, sequence number =  375
# modify, sequence number =  395
# modify, sequence number =  411
# modify, sequence number =  420
# modify, sequence number =  434
# modify, sequence number =  445
# modify, sequence number =  456
# modify, sequence number =  472
# modify, sequence number =  500
# modify, sequence number =  513
# modify, sequence number =  521
# modify, sequence number =  525
# modify, sequence number =  531
# modify, sequence number =  534
# modify, sequence number =  539
# modify, sequence number =  544
# modify, sequence number =  587
# modify, sequence number =  635
# modify, sequence number =  639
# modify, sequence number =  645
# modify, sequence number =  650
# modify, sequence number =  661
# modify, sequence number =  664
# modify, sequence number =  673
# modify, sequence number =  677
# modify, sequence number =  681
# modify, sequence number =  700
# modify, sequence number =  716
# modify, sequence number =  726
# modify, sequence number =  727
# modify, sequence number =  733
# modify, sequence number =  752
# modify, sequence number =  758
# modify, sequence number =  763
# modify, sequence number =  764
# modify, sequence number =  772
# modify, sequence number =  793
# modify, sequence number =  798
# modify, sequence number =  800
# modify, sequence number =  802
# modify, sequence number =  807
# modify, sequence number =  811
# modify, sequence number =  814
# modify, sequence number =  818
# modify, sequence number =  825
# modify, sequence number =  843
# modify, sequence number =  847
# modify, sequence number =  849
# modify, sequence number =  870
# modify, sequence number =  875
# modify, sequence number =  876
# modify, sequence number =  878
# modify, sequence number =  884
# modify, sequence number =  890
# modify, sequence number =  892
# modify, sequence number =  932
# modify, sequence number =  946
# modify, sequence number =  955
# modify, sequence number =  977
# modify, sequence number =  982
# modify, sequence number =  983
# modify, sequence number =  998
# modify, sequence number =  1004
# modify, sequence number =  1021
# modify, sequence number =  1022
# modify, sequence number =  1028
# modify, sequence number =  1030
# modify, sequence number =  1038
# modify, sequence number =  1041
# modify, sequence number =  1043
# modify, sequence number =  1048
# modify, sequence number =  1052
# modify, sequence number =  1068
# modify, sequence number =  1069
# modify, sequence number =  1072
# modify, sequence number =  1079
# modify, sequence number =  1092
# modify, sequence number =  1097
# modify, sequence number =  1102
# modify, sequence number =  1103
# modify, sequence number =  1129
# modify, sequence number =  1144
# modify, sequence number =  1165
# modify, sequence number =  1177
# modify, sequence number =  1205
# modify, sequence number =  1219
# modify, sequence number =  1228
# modify, sequence number =  1244
# modify, sequence number =  1255
# modify, sequence number =  1258
# modify, sequence number =  1262
# modify, sequence number =  1292
# modify, sequence number =  1301
# modify, sequence number =  1311
# modify, sequence number =  1320
# modify, sequence number =  1325
# modify, sequence number =  1329
# modify, sequence number =  1338
# modify, sequence number =  1363
# modify, sequence number =  1365
# modify, sequence number =  1370
# modify, sequence number =  1386
# modify, sequence number =  1406
# modify, sequence number =  1408
# modify, sequence number =  1440
# modify, sequence number =  1444
# modify, sequence number =  1453
# modify, sequence number =  1458
# modify, sequence number =  1463
# modify, sequence number =  1467
# modify, sequence number =  1474
# modify, sequence number =  1491
# modify, sequence number =  1500
# modify, sequence number =  1511
# modify, sequence number =  1518
# modify, sequence number =  1524
# modify, sequence number =  1544
# modify, sequence number =  1562
# modify, sequence number =  1569
# modify, sequence number =  1578
# modify, sequence number =  1585
# modify, sequence number =  1586
# modify, sequence number =  1590
# modify, sequence number =  1607
# modify, sequence number =  1613
# modify, sequence number =  1615
# modify, sequence number =  1620
# modify, sequence number =  1621
# modify, sequence number =  1623
# modify, sequence number =  1630
# modify, sequence number =  1638
# modify, sequence number =  1657
# modify, sequence number =  1668
# modify, sequence number =  1681
# modify, sequence number =  1685
# modify, sequence number =  1703
# modify, sequence number =  1708
# modify, sequence number =  1714
# modify, sequence number =  1718
# modify, sequence number =  1737
# modify, sequence number =  1738
# modify, sequence number =  1740
# modify, sequence number =  1752
# modify, sequence number =  1765
# modify, sequence number =  1783
# modify, sequence number =  1784
# modify, sequence number =  1806
# modify, sequence number =  1807
# modify, sequence number =  1814
# modify, sequence number =  1824
# modify, sequence number =  1839
# modify, sequence number =  1843
# modify, sequence number =  1862
# modify, sequence number =  1868
# modify, sequence number =  1877
# modify, sequence number =  1882
# modify, sequence number =  1912
# modify, sequence number =  1915
# modify, sequence number =  1946
# modify, sequence number =  1965
# modify, sequence number =  1986
# modify, sequence number =  1995
# modify, sequence number =  1996
# modify, sequence number =  2003
# modify, sequence number =  2017
# modify, sequence number =  2048
# modify, sequence number =  2075
# modify, sequence number =  2080
# modify, sequence number =  2094
# modify, sequence number =  2111
# modify, sequence number =  2117
# modify, sequence number =  2122
# modify, sequence number =  2126
# modify, sequence number =  2130
# modify, sequence number =  2138
# modify, sequence number =  2162
# modify, sequence number =  2186
# modify, sequence number =  2201
# modify, sequence number =  2210
# modify, sequence number =  2213
# modify, sequence number =  2227
# modify, sequence number =  2235
# modify, sequence number =  2238
# modify, sequence number =  2259
# modify, sequence number =  2284
# modify, sequence number =  2285
# modify, sequence number =  2297
# modify, sequence number =  2326
# modify, sequence number =  2328
# modify, sequence number =  2336
# modify, sequence number =  2338
# modify, sequence number =  2339
# modify, sequence number =  2353
# modify, sequence number =  2360
# modify, sequence number =  2369
# modify, sequence number =  2371
# modify, sequence number =  2398
# modify, sequence number =  2405
# modify, sequence number =  2441
# modify, sequence number =  2461
# modify, sequence number =  2463
# modify, sequence number =  2476
# modify, sequence number =  2481
# modify, sequence number =  2484
# modify, sequence number =  2489
# modify, sequence number =  2491
# modify, sequence number =  2494
# modify, sequence number =  2495
# modify, sequence number =  2496
# modify, sequence number =  2503
# modify, sequence number =  2507
# modify, sequence number =  2518
# modify, sequence number =  2526
# modify, sequence number =  2527
# modify, sequence number =  2550
# modify, sequence number =  2560
# modify, sequence number =  2575
# modify, sequence number =  2609
# modify, sequence number =  2612
# modify, sequence number =  2626
# modify, sequence number =  2635
# modify, sequence number =  2639
# modify, sequence number =  2642
# modify, sequence number =  2656
# modify, sequence number =  2680
# modify, sequence number =  2685
# modify, sequence number =  2710
# modify, sequence number =  2719
# modify, sequence number =  2724
# modify, sequence number =  2726
# modify, sequence number =  2730
# modify, sequence number =  2742
# modify, sequence number =  2757
# modify, sequence number =  2763
# modify, sequence number =  2769
# modify, sequence number =  2778
# modify, sequence number =  2806
# modify, sequence number =  2811
# modify, sequence number =  2817
# modify, sequence number =  2818
# modify, sequence number =  2820
# modify, sequence number =  2821
# modify, sequence number =  2826
# modify, sequence number =  2836
# modify, sequence number =  2842
# modify, sequence number =  2848
# modify, sequence number =  2855
# modify, sequence number =  2864
# modify, sequence number =  2879
# modify, sequence number =  2882
# modify, sequence number =  2892
# modify, sequence number =  2898
# modify, sequence number =  2899
# modify, sequence number =  2903
# modify, sequence number =  2906
# modify, sequence number =  2922
# modify, sequence number =  2924
# modify, sequence number =  2926
# modify, sequence number =  2928
# modify, sequence number =  2947
# modify, sequence number =  2949
# modify, sequence number =  2951
# modify, sequence number =  2957
# modify, sequence number =  2974
# modify, sequence number =  2987
# modify, sequence number =  2991
# modify, sequence number =  3003
# modify, sequence number =  3007
# modify, sequence number =  3024
# modify, sequence number =  3030
# modify, sequence number =  3059
# modify, sequence number =  3063
# modify, sequence number =  3068
# modify, sequence number =  3076
# modify, sequence number =  3086
# modify, sequence number =  3088
# modify, sequence number =  3093
# modify, sequence number =  3097
# modify, sequence number =  3102
# modify, sequence number =  3104
# modify, sequence number =  3122
# modify, sequence number =  3150
# modify, sequence number =  3177
# modify, sequence number =  3180
# modify, sequence number =  3211
# modify, sequence number =  3213
# modify, sequence number =  3216
# modify, sequence number =  3235
# modify, sequence number =  3237
# modify, sequence number =  3246
# modify, sequence number =  3252
# modify, sequence number =  3278
# modify, sequence number =  3284
# modify, sequence number =  3302
# modify, sequence number =  3320
# modify, sequence number =  3328
# modify, sequence number =  3333
# modify, sequence number =  3361
# modify, sequence number =  3367
# modify, sequence number =  3401
# modify, sequence number =  3423
# modify, sequence number =  3438
# modify, sequence number =  3439
# modify, sequence number =  3445
# modify, sequence number =  3448
# modify, sequence number =  3462
# modify, sequence number =  3497
# modify, sequence number =  3515
# modify, sequence number =  3531
# modify, sequence number =  3533
# modify, sequence number =  3558
# modify, sequence number =  3583
# modify, sequence number =  3590
# modify, sequence number =  3604
# modify, sequence number =  3625
# modify, sequence number =  3627
# modify, sequence number =  3628
# modify, sequence number =  3633
# modify, sequence number =  3651
# modify, sequence number =  3653
# modify, sequence number =  3675
# modify, sequence number =  3694
# modify, sequence number =  3703
# modify, sequence number =  3721
# modify, sequence number =  3725
# modify, sequence number =  3726
# modify, sequence number =  3729
# modify, sequence number =  3737
# modify, sequence number =  3738
# modify, sequence number =  3746
# modify, sequence number =  3748
# modify, sequence number =  3755
# modify, sequence number =  3772
# modify, sequence number =  3781
# modify, sequence number =  3782
# modify, sequence number =  3785
# modify, sequence number =  3789
# modify, sequence number =  3795
# modify, sequence number =  3796
# modify, sequence number =  3811
# modify, sequence number =  3822
# modify, sequence number =  3837
# modify, sequence number =  3847
# modify, sequence number =  3859
# modify, sequence number =  3874
# modify, sequence number =  3902
# modify, sequence number =  3903
# modify, sequence number =  3916
# modify, sequence number =  3919
# modify, sequence number =  3921
# modify, sequence number =  3930
# modify, sequence number =  3937
# modify, sequence number =  3944
# modify, sequence number =  3945
# modify, sequence number =  3949
# modify, sequence number =  3952
# modify, sequence number =  3953
# modify, sequence number =  3957
# modify, sequence number =  3958
# modify, sequence number =  4004
# modify, sequence number =  4007
# modify, sequence number =  4023
# modify, sequence number =  4027
# modify, sequence number =  4028
# modify, sequence number =  4033
# modify, sequence number =  4051
# modify, sequence number =  4083
# modify, sequence number =  4104
# modify, sequence number =  4117
# modify, sequence number =  4119
# modify, sequence number =  4120
# modify, sequence number =  4122
# modify, sequence number =  4135
# modify, sequence number =  4143
# modify, sequence number =  4145
# modify, sequence number =  4148
# modify, sequence number =  4154
# modify, sequence number =  4159
# modify, sequence number =  4164
# modify, sequence number =  4175
# modify, sequence number =  4178
# modify, sequence number =  4191
# modify, sequence number =  4209
# modify, sequence number =  4246
# modify, sequence number =  4253
# modify, sequence number =  4270
# modify, sequence number =  4276
# modify, sequence number =  4278
# modify, sequence number =  4280
# modify, sequence number =  4289
# modify, sequence number =  4296
# modify, sequence number =  4317
# modify, sequence number =  4322
# modify, sequence number =  4327
# modify, sequence number =  4342
# modify, sequence number =  4362
# modify, sequence number =  4364
# modify, sequence number =  4371
# modify, sequence number =  4384
# modify, sequence number =  4387
# modify, sequence number =  4389
# modify, sequence number =  4390
# modify, sequence number =  4391
# modify, sequence number =  4393
# modify, sequence number =  4399
# modify, sequence number =  4404
# modify, sequence number =  4406
# modify, sequence number =  4409
# modify, sequence number =  4410
# modify, sequence number =  4418
# modify, sequence number =  4435
# modify, sequence number =  4440
# modify, sequence number =  4442
# modify, sequence number =  4443
# modify, sequence number =  4444
# modify, sequence number =  4455
# modify, sequence number =  4463
# modify, sequence number =  4492
# modify, sequence number =  4493
# modify, sequence number =  4496
# modify, sequence number =  4508
# modify, sequence number =  4520
# modify, sequence number =  4532
# modify, sequence number =  4537
# modify, sequence number =  4551
# modify, sequence number =  4561
# modify, sequence number =  4568
# modify, sequence number =  4569
# modify, sequence number =  4581
# modify, sequence number =  4591
# modify, sequence number =  4628
# modify, sequence number =  4642
# modify, sequence number =  4659
# modify, sequence number =  4660
# modify, sequence number =  4664
# modify, sequence number =  4695
# modify, sequence number =  4712
# modify, sequence number =  4716
# modify, sequence number =  4790
# modify, sequence number =  4791
# modify, sequence number =  4801
# modify, sequence number =  4817
# modify, sequence number =  4828
# modify, sequence number =  4832
# modify, sequence number =  4844
# modify, sequence number =  4850
# modify, sequence number =  4874
# modify, sequence number =  4897
# modify, sequence number =  4911
# modify, sequence number =  4928
# modify, sequence number =  4940
# modify, sequence number =  4942
# modify, sequence number =  4946
# modify, sequence number =  4955
# modify, sequence number =  4959
# modify, sequence number =  4996
# modify, sequence number =  5011
# modify, sequence number =  5021
# modify, sequence number =  5033
# modify, sequence number =  5040
# modify, sequence number =  5046
# modify, sequence number =  5049
# modify, sequence number =  5059
# modify, sequence number =  5109
# modify, sequence number =  5111
# modify, sequence number =  5118
# modify, sequence number =  5127
# modify, sequence number =  5129
# modify, sequence number =  5131
# modify, sequence number =  5134
# modify, sequence number =  5149
# modify, sequence number =  5152
# modify, sequence number =  5161
# modify, sequence number =  5200
# modify, sequence number =  5224
# modify, sequence number =  5230
# modify, sequence number =  5231
# modify, sequence number =  5249
# modify, sequence number =  5250
# modify, sequence number =  5274
# modify, sequence number =  5309
# modify, sequence number =  5313
# modify, sequence number =  5319
# modify, sequence number =  5336
# modify, sequence number =  5337
# modify, sequence number =  5348
# modify, sequence number =  5355
# modify, sequence number =  5365
# modify, sequence number =  5392
# modify, sequence number =  5421
# modify, sequence number =  5445
# modify, sequence number =  5460
# modify, sequence number =  5466
# modify, sequence number =  5485
# modify, sequence number =  5491
# modify, sequence number =  5495
# modify, sequence number =  5544
# modify, sequence number =  5555
# modify, sequence number =  5564
# modify, sequence number =  5583
# modify, sequence number =  5594
# modify, sequence number =  5646
# modify, sequence number =  5649
# modify, sequence number =  5661
# modify, sequence number =  5666
# modify, sequence number =  5667
# modify, sequence number =  5671
# modify, sequence number =  5678
# modify, sequence number =  5687
# modify, sequence number =  5692
# modify, sequence number =  5704
# modify, sequence number =  5708
# modify, sequence number =  5715
# modify, sequence number =  5740
# modify, sequence number =  5749
# modify, sequence number =  5756
# modify, sequence number =  5757
# modify, sequence number =  5780
# modify, sequence number =  5782
# modify, sequence number =  5785
# modify, sequence number =  5834
# modify, sequence number =  5853
# modify, sequence number =  5860
# modify, sequence number =  5868
# modify, sequence number =  5869
# modify, sequence number =  5870
# modify, sequence number =  5882
# modify, sequence number =  5884
# modify, sequence number =  5896
# modify, sequence number =  5904
# modify, sequence number =  5908
# modify, sequence number =  5910
# modify, sequence number =  5913
# modify, sequence number =  5919
# modify, sequence number =  5933
# modify, sequence number =  5941
# modify, sequence number =  5960
# modify, sequence number =  5965
# modify, sequence number =  5967
# modify, sequence number =  5973
# modify, sequence number =  5988
# modify, sequence number =  6001
# modify, sequence number =  6010
# modify, sequence number =  6048
# modify, sequence number =  6050
# modify, sequence number =  6061
# modify, sequence number =  6080
# modify, sequence number =  6081
# modify, sequence number =  6085
# modify, sequence number =  6104
# modify, sequence number =  6106
# modify, sequence number =  6116
# modify, sequence number =  6135
# modify, sequence number =  6144
# modify, sequence number =  6148
# modify, sequence number =  6164
# modify, sequence number =  6176
# modify, sequence number =  6180
# modify, sequence number =  6181
# modify, sequence number =  6183
# modify, sequence number =  6191
# modify, sequence number =  6211
# modify, sequence number =  6215
# modify, sequence number =  6228
# modify, sequence number =  6263
# modify, sequence number =  6266
# modify, sequence number =  6275
# modify, sequence number =  6280
# modify, sequence number =  6281
# modify, sequence number =  6282
# modify, sequence number =  6283
# modify, sequence number =  6299
# modify, sequence number =  6323
# modify, sequence number =  6343
# modify, sequence number =  6346
# modify, sequence number =  6357
# modify, sequence number =  6358
# modify, sequence number =  6365
# modify, sequence number =  6366
# modify, sequence number =  6371
# modify, sequence number =  6374
# modify, sequence number =  6384
# modify, sequence number =  6392
# modify, sequence number =  6394
# modify, sequence number =  6402
# modify, sequence number =  6403
# modify, sequence number =  6406
# modify, sequence number =  6414
# modify, sequence number =  6434
# modify, sequence number =  6450
# modify, sequence number =  6459
# modify, sequence number =  6465
# modify, sequence number =  6466
# modify, sequence number =  6471
# modify, sequence number =  6501
# modify, sequence number =  6513
# modify, sequence number =  6522
# modify, sequence number =  6523
# modify, sequence number =  6526
# modify, sequence number =  6547
# modify, sequence number =  6548
# modify, sequence number =  6551
# modify, sequence number =  6553
# modify, sequence number =  6556
# modify, sequence number =  6568
# modify, sequence number =  6582
# modify, sequence number =  6589
# modify, sequence number =  6597
# modify, sequence number =  6600
# modify, sequence number =  6618
# modify, sequence number =  6627
# modify, sequence number =  6628
# modify, sequence number =  6629
# modify, sequence number =  6654
# modify, sequence number =  6668
# modify, sequence number =  6670
# modify, sequence number =  6709
# modify, sequence number =  6721
# modify, sequence number =  6735
# modify, sequence number =  6751
# modify, sequence number =  6768
# modify, sequence number =  6769
# modify, sequence number =  6771
# modify, sequence number =  6777
# modify, sequence number =  6779
# modify, sequence number =  6780
# modify, sequence number =  6814
# modify, sequence number =  6823
# modify, sequence number =  6848
# modify, sequence number =  6864
# modify, sequence number =  6877
# modify, sequence number =  6919
# modify, sequence number =  6921
# modify, sequence number =  6929
# modify, sequence number =  6934
# modify, sequence number =  6953
# modify, sequence number =  6956
# modify, sequence number =  6958
# modify, sequence number =  6967
# modify, sequence number =  6992
# modify, sequence number =  7009
# modify, sequence number =  7011
# modify, sequence number =  7036
# modify, sequence number =  7066
# modify, sequence number =  7080
# modify, sequence number =  7090
# modify, sequence number =  7103
# modify, sequence number =  7118
# modify, sequence number =  7127
# modify, sequence number =  7128
# modify, sequence number =  7162
# modify, sequence number =  7173
# modify, sequence number =  7179
# modify, sequence number =  7180
# modify, sequence number =  7194
# modify, sequence number =  7209
# modify, sequence number =  7214
# modify, sequence number =  7218
# modify, sequence number =  7224
# modify, sequence number =  7226
# modify, sequence number =  7228
# modify, sequence number =  7242
# modify, sequence number =  7247
# modify, sequence number =  7248
# modify, sequence number =  7252
# modify, sequence number =  7256
# modify, sequence number =  7263
# modify, sequence number =  7268
# modify, sequence number =  7272
# modify, sequence number =  7295
# modify, sequence number =  7316
# modify, sequence number =  7325
# modify, sequence number =  7327
# modify, sequence number =  7332
# modify, sequence number =  7359
# modify, sequence number =  7361
# modify, sequence number =  7364
# modify, sequence number =  7376
# modify, sequence number =  7384
# modify, sequence number =  7416
# modify, sequence number =  7423
# modify, sequence number =  7436
# modify, sequence number =  7444
# modify, sequence number =  7447
# modify, sequence number =  7455
# modify, sequence number =  7456
# modify, sequence number =  7476
# modify, sequence number =  7497
# modify, sequence number =  7510
# modify, sequence number =  7511
# modify, sequence number =  7521
# modify, sequence number =  7535
# modify, sequence number =  7548
# modify, sequence number =  7559
# modify, sequence number =  7571
# modify, sequence number =  7572
# modify, sequence number =  7579
# modify, sequence number =  7586
# modify, sequence number =  7589
# modify, sequence number =  7604
# modify, sequence number =  7610
# modify, sequence number =  7611
# modify, sequence number =  7612
# modify, sequence number =  7614
# modify, sequence number =  7624
# modify, sequence number =  7641
# modify, sequence number =  7649
# modify, sequence number =  7650
# modify, sequence number =  7655
# modify, sequence number =  7686
# modify, sequence number =  7696
# modify, sequence number =  7705
# modify, sequence number =  7708
# modify, sequence number =  7725
# modify, sequence number =  7731
# modify, sequence number =  7750
# modify, sequence number =  7752
# modify, sequence number =  7753
# modify, sequence number =  7754
# modify, sequence number =  7768
# modify, sequence number =  7785
# modify, sequence number =  7791
# modify, sequence number =  7804
# modify, sequence number =  7831
# modify, sequence number =  7833
# modify, sequence number =  7838
# modify, sequence number =  7839
# modify, sequence number =  7840
# modify, sequence number =  7848
# modify, sequence number =  7849
# modify, sequence number =  7860
# modify, sequence number =  7863
# modify, sequence number =  7867
# modify, sequence number =  7876
# modify, sequence number =  7886
# modify, sequence number =  7897
# modify, sequence number =  7907
# modify, sequence number =  7912
# modify, sequence number =  7915
# modify, sequence number =  7917
# modify, sequence number =  7930
# modify, sequence number =  7949
# modify, sequence number =  7950
# modify, sequence number =  7971
# modify, sequence number =  7978
# modify, sequence number =  7980
# modify, sequence number =  7998
# modify, sequence number =  8001
# modify, sequence number =  8014
# modify, sequence number =  8026
# modify, sequence number =  8039
# modify, sequence number =  8050
# modify, sequence number =  8080
# modify, sequence number =  8083
# modify, sequence number =  8097
# modify, sequence number =  8098
# modify, sequence number =  8102
# modify, sequence number =  8107
# modify, sequence number =  8109
# modify, sequence number =  8154
# modify, sequence number =  8155
# modify, sequence number =  8161
# modify, sequence number =  8193
# modify, sequence number =  8212
# modify, sequence number =  8221
# modify, sequence number =  8231
# modify, sequence number =  8236
# modify, sequence number =  8237
# modify, sequence number =  8247
# modify, sequence number =  8256
# modify, sequence number =  8257
# modify, sequence number =  8265
# modify, sequence number =  8267
# modify, sequence number =  8272
# modify, sequence number =  8290
# modify, sequence number =  8306
# modify, sequence number =  8312
# modify, sequence number =  8319
# modify, sequence number =  8321
# modify, sequence number =  8324
# modify, sequence number =  8331
# modify, sequence number =  8350
# modify, sequence number =  8373
# modify, sequence number =  8384
# modify, sequence number =  8393
# modify, sequence number =  8410
# modify, sequence number =  8413
# modify, sequence number =  8419
# modify, sequence number =  8422
# modify, sequence number =  8428
# modify, sequence number =  8434
# modify, sequence number =  8436
# modify, sequence number =  8447
# modify, sequence number =  8472
# modify, sequence number =  8483
# modify, sequence number =  8486
# modify, sequence number =  8498
# modify, sequence number =  8501
# modify, sequence number =  8530
# modify, sequence number =  8545
# modify, sequence number =  8552
# modify, sequence number =  8558
# modify, sequence number =  8560
# modify, sequence number =  8565
# modify, sequence number =  8568
# modify, sequence number =  8582
# modify, sequence number =  8596
# modify, sequence number =  8600
# modify, sequence number =  8604
# modify, sequence number =  8605
# modify, sequence number =  8615
# modify, sequence number =  8629
# modify, sequence number =  8631
# modify, sequence number =  8635
# modify, sequence number =  8643
# modify, sequence number =  8651
# modify, sequence number =  8654
# modify, sequence number =  8661
# modify, sequence number =  8678
# modify, sequence number =  8683
# modify, sequence number =  8684
# modify, sequence number =  8686
# modify, sequence number =  8697
# modify, sequence number =  8698
# modify, sequence number =  8711
# modify, sequence number =  8721
# modify, sequence number =  8738
# modify, sequence number =  8751
# modify, sequence number =  8763
# modify, sequence number =  8772
# modify, sequence number =  8777
# modify, sequence number =  8787
# modify, sequence number =  8811
# modify, sequence number =  8817
# modify, sequence number =  8824
# modify, sequence number =  8851
# modify, sequence number =  8867
# modify, sequence number =  8890
# modify, sequence number =  8900
# modify, sequence number =  8912
# modify, sequence number =  8930
# modify, sequence number =  8940
# modify, sequence number =  8965
# modify, sequence number =  8970
# modify, sequence number =  8971
# modify, sequence number =  8982
# modify, sequence number =  8988
# modify, sequence number =  8989
# modify, sequence number =  8999
# modify, sequence number =  9000
# modify, sequence number =  9003
# modify, sequence number =  9004
# modify, sequence number =  9005
# modify, sequence number =  9019
# modify, sequence number =  9023
# modify, sequence number =  9047
# modify, sequence number =  9062
# modify, sequence number =  9073
# modify, sequence number =  9079
# modify, sequence number =  9085
# modify, sequence number =  9092
# modify, sequence number =  9099
# modify, sequence number =  9104
# modify, sequence number =  9117
# modify, sequence number =  9127
# modify, sequence number =  9137
# modify, sequence number =  9142
# modify, sequence number =  9162
# modify, sequence number =  9174
# modify, sequence number =  9191
# modify, sequence number =  9198
# modify, sequence number =  9202
# modify, sequence number =  9204
# modify, sequence number =  9214
# modify, sequence number =  9215
# modify, sequence number =  9221
# modify, sequence number =  9225
# modify, sequence number =  9253
# modify, sequence number =  9259
# modify, sequence number =  9260
# modify, sequence number =  9265
# modify, sequence number =  9275
# modify, sequence number =  9292
# modify, sequence number =  9293
# modify, sequence number =  9295
# modify, sequence number =  9302
# modify, sequence number =  9317
# modify, sequence number =  9318
# modify, sequence number =  9319
# modify, sequence number =  9320
# modify, sequence number =  9322
# modify, sequence number =  9323
# modify, sequence number =  9330
# modify, sequence number =  9339
# modify, sequence number =  9341
# modify, sequence number =  9351
# modify, sequence number =  9353
# modify, sequence number =  9359
# modify, sequence number =  9372
# modify, sequence number =  9373
# modify, sequence number =  9383
# modify, sequence number =  9400
# modify, sequence number =  9402
# modify, sequence number =  9411
# modify, sequence number =  9419
# modify, sequence number =  9428
# modify, sequence number =  9447
# modify, sequence number =  9462
# modify, sequence number =  9484
# modify, sequence number =  9502
# modify, sequence number =  9512
# modify, sequence number =  9516
# modify, sequence number =  9523
# modify, sequence number =  9528
# modify, sequence number =  9544
# modify, sequence number =  9545
# modify, sequence number =  9566
# modify, sequence number =  9570
# modify, sequence number =  9571
# modify, sequence number =  9580
# modify, sequence number =  9593
# modify, sequence number =  9599
# modify, sequence number =  9614
# modify, sequence number =  9615
# modify, sequence number =  9636
# modify, sequence number =  9650
# modify, sequence number =  9651
# modify, sequence number =  9662
# modify, sequence number =  9664
# modify, sequence number =  9674
# modify, sequence number =  9701
# modify, sequence number =  9710
# modify, sequence number =  9715
# modify, sequence number =  9732
# modify, sequence number =  9763
# modify, sequence number =  9790
# modify, sequence number =  9806
# modify, sequence number =  9807
# modify, sequence number =  9833
# modify, sequence number =  9842
# modify, sequence number =  9844
# modify, sequence number =  9845
# modify, sequence number =  9862
# modify, sequence number =  9871
# modify, sequence number =  9882
# modify, sequence number =  9888
# modify, sequence number =  9905
# modify, sequence number =  9908
# modify, sequence number =  9933
# modify, sequence number =  9935
# modify, sequence number =  9937
# modify, sequence number =  9941
# modify, sequence number =  9943
# modify, sequence number =  9957
# modify, sequence number =  9958
# modify, sequence number =  9965
# modify, sequence number =  9967
# modify, sequence number =  9991
# modify, sequence number =  9995
# Sent chunk  10000  of  78012
# modify, sequence number =  10001
# modify, sequence number =  10009
# modify, sequence number =  10012
# modify, sequence number =  10025
# modify, sequence number =  10029
# modify, sequence number =  10034
# modify, sequence number =  10046
# modify, sequence number =  10048
# modify, sequence number =  10064
# modify, sequence number =  10074
# modify, sequence number =  10104
# modify, sequence number =  10117
# modify, sequence number =  10122
# modify, sequence number =  10127
# modify, sequence number =  10146
# modify, sequence number =  10160
# modify, sequence number =  10163
# modify, sequence number =  10169
# modify, sequence number =  10189
# modify, sequence number =  10191
# modify, sequence number =  10193
# modify, sequence number =  10262
# modify, sequence number =  10264
# modify, sequence number =  10266
# modify, sequence number =  10284
# modify, sequence number =  10285
# modify, sequence number =  10289
# modify, sequence number =  10298
# modify, sequence number =  10302
# modify, sequence number =  10320
# modify, sequence number =  10321
# modify, sequence number =  10328
# modify, sequence number =  10343
# modify, sequence number =  10362
# modify, sequence number =  10367
# modify, sequence number =  10370
# modify, sequence number =  10373
# modify, sequence number =  10374
# modify, sequence number =  10382
# modify, sequence number =  10386
# modify, sequence number =  10395
# modify, sequence number =  10396
# modify, sequence number =  10433
# modify, sequence number =  10436
# modify, sequence number =  10446
# modify, sequence number =  10458
# modify, sequence number =  10465
# modify, sequence number =  10474
# modify, sequence number =  10479
# modify, sequence number =  10503
# modify, sequence number =  10504
# modify, sequence number =  10519
# modify, sequence number =  10540
# modify, sequence number =  10541
# modify, sequence number =  10552
# modify, sequence number =  10554
# modify, sequence number =  10559
# modify, sequence number =  10560
# modify, sequence number =  10561
# modify, sequence number =  10568
# modify, sequence number =  10575
# modify, sequence number =  10580
# modify, sequence number =  10592
# modify, sequence number =  10594
# modify, sequence number =  10600
# modify, sequence number =  10621
# modify, sequence number =  10629
# modify, sequence number =  10632
# modify, sequence number =  10649
# modify, sequence number =  10658
# modify, sequence number =  10683
# modify, sequence number =  10690
# modify, sequence number =  10704
# modify, sequence number =  10721
# modify, sequence number =  10725
# modify, sequence number =  10742
# modify, sequence number =  10744
# modify, sequence number =  10756
# modify, sequence number =  10758
# modify, sequence number =  10762
# modify, sequence number =  10775
# modify, sequence number =  10776
# modify, sequence number =  10800
# modify, sequence number =  10812
# modify, sequence number =  10821
# modify, sequence number =  10851
# modify, sequence number =  10866
# modify, sequence number =  10878
# modify, sequence number =  10896
# modify, sequence number =  10919
# modify, sequence number =  10924
# modify, sequence number =  10937
# modify, sequence number =  10944
# modify, sequence number =  10969
# modify, sequence number =  10976
# modify, sequence number =  10998
# modify, sequence number =  11000
# modify, sequence number =  11013
# modify, sequence number =  11016
# modify, sequence number =  11028
# modify, sequence number =  11043
# modify, sequence number =  11066
# modify, sequence number =  11068
# modify, sequence number =  11069
# modify, sequence number =  11081
# modify, sequence number =  11082
# modify, sequence number =  11115
# modify, sequence number =  11118
# modify, sequence number =  11122
# modify, sequence number =  11124
# modify, sequence number =  11126
# modify, sequence number =  11127
# modify, sequence number =  11129
# modify, sequence number =  11131
# modify, sequence number =  11156
# modify, sequence number =  11163
# modify, sequence number =  11196
# modify, sequence number =  11200
# modify, sequence number =  11206
# modify, sequence number =  11219
# modify, sequence number =  11229
# modify, sequence number =  11230
# modify, sequence number =  11240
# modify, sequence number =  11257
# modify, sequence number =  11265
# modify, sequence number =  11281
# modify, sequence number =  11290
# modify, sequence number =  11297
# modify, sequence number =  11299
# modify, sequence number =  11308
# modify, sequence number =  11320
# modify, sequence number =  11326
# modify, sequence number =  11354
# modify, sequence number =  11381
# modify, sequence number =  11395
# modify, sequence number =  11396
# modify, sequence number =  11424
# modify, sequence number =  11432
# modify, sequence number =  11449
# modify, sequence number =  11451
# modify, sequence number =  11452
# modify, sequence number =  11453
# modify, sequence number =  11462
# modify, sequence number =  11510
# modify, sequence number =  11515
# modify, sequence number =  11523
# modify, sequence number =  11528
# modify, sequence number =  11550
# modify, sequence number =  11555
# modify, sequence number =  11566
# modify, sequence number =  11580
# modify, sequence number =  11584
# modify, sequence number =  11613
# modify, sequence number =  11625
# modify, sequence number =  11632
# modify, sequence number =  11637
# modify, sequence number =  11640
# modify, sequence number =  11688
# modify, sequence number =  11709
# modify, sequence number =  11712
# modify, sequence number =  11716
# modify, sequence number =  11726
# modify, sequence number =  11732
# modify, sequence number =  11742
# modify, sequence number =  11747
# modify, sequence number =  11752
# modify, sequence number =  11763
# modify, sequence number =  11770
# modify, sequence number =  11785
# modify, sequence number =  11792
# modify, sequence number =  11798
# modify, sequence number =  11800
# modify, sequence number =  11802
# modify, sequence number =  11810
# modify, sequence number =  11814
# modify, sequence number =  11855
# modify, sequence number =  11885
# modify, sequence number =  11893
# modify, sequence number =  11915
# modify, sequence number =  11928
# modify, sequence number =  11942
# modify, sequence number =  11943
# modify, sequence number =  11948
# modify, sequence number =  11950
# modify, sequence number =  11954
# modify, sequence number =  11962
# modify, sequence number =  11981
# modify, sequence number =  11985
# modify, sequence number =  11991
# modify, sequence number =  12003
# modify, sequence number =  12015
# modify, sequence number =  12017
# modify, sequence number =  12018
# modify, sequence number =  12020
# modify, sequence number =  12024
# modify, sequence number =  12030
# modify, sequence number =  12032
# modify, sequence number =  12037
# modify, sequence number =  12038
# modify, sequence number =  12044
# modify, sequence number =  12058
# modify, sequence number =  12064
# modify, sequence number =  12081
# modify, sequence number =  12094
# modify, sequence number =  12111
# modify, sequence number =  12118
# modify, sequence number =  12119
# modify, sequence number =  12132
# modify, sequence number =  12133
# modify, sequence number =  12142
# modify, sequence number =  12154
# modify, sequence number =  12155
# modify, sequence number =  12169
# modify, sequence number =  12189
# modify, sequence number =  12210
# modify, sequence number =  12226
# modify, sequence number =  12235
# modify, sequence number =  12242
# modify, sequence number =  12248
# modify, sequence number =  12259
# modify, sequence number =  12265
# modify, sequence number =  12266
# modify, sequence number =  12269
# modify, sequence number =  12282
# modify, sequence number =  12287
# modify, sequence number =  12292
# modify, sequence number =  12293
# modify, sequence number =  12300
# modify, sequence number =  12310
# modify, sequence number =  12313
# modify, sequence number =  12315
# modify, sequence number =  12321
# modify, sequence number =  12322
# modify, sequence number =  12328
# modify, sequence number =  12335
# modify, sequence number =  12339
# modify, sequence number =  12343
# modify, sequence number =  12349
# modify, sequence number =  12353
# modify, sequence number =  12374
# modify, sequence number =  12375
# modify, sequence number =  12395
# modify, sequence number =  12408
# modify, sequence number =  12418
# modify, sequence number =  12432
# modify, sequence number =  12447
# modify, sequence number =  12449
# modify, sequence number =  12456
# modify, sequence number =  12457
# modify, sequence number =  12469
# modify, sequence number =  12473
# modify, sequence number =  12486
# modify, sequence number =  12488
# modify, sequence number =  12507
# modify, sequence number =  12508
# modify, sequence number =  12537
# modify, sequence number =  12549
# modify, sequence number =  12571
# modify, sequence number =  12572
# modify, sequence number =  12585
# modify, sequence number =  12602
# modify, sequence number =  12605
# modify, sequence number =  12621
# modify, sequence number =  12625
# modify, sequence number =  12626
# modify, sequence number =  12628
# modify, sequence number =  12634
# modify, sequence number =  12636
# modify, sequence number =  12661
# modify, sequence number =  12688
# modify, sequence number =  12696
# modify, sequence number =  12730
# modify, sequence number =  12743
# modify, sequence number =  12749
# modify, sequence number =  12767
# modify, sequence number =  12778
# modify, sequence number =  12780
# modify, sequence number =  12794
# modify, sequence number =  12796
# modify, sequence number =  12802
# modify, sequence number =  12813
# modify, sequence number =  12817
# modify, sequence number =  12820
# modify, sequence number =  12833
# modify, sequence number =  12838
# modify, sequence number =  12840
# modify, sequence number =  12848
# modify, sequence number =  12849
# modify, sequence number =  12866
# modify, sequence number =  12876
# modify, sequence number =  12878
# modify, sequence number =  12912
# modify, sequence number =  12917
# modify, sequence number =  12941
# modify, sequence number =  12943
# modify, sequence number =  12957
# modify, sequence number =  12961
# modify, sequence number =  12964
# modify, sequence number =  12978
# modify, sequence number =  12982
# modify, sequence number =  12995
# modify, sequence number =  13009
# modify, sequence number =  13015
# modify, sequence number =  13018
# modify, sequence number =  13021
# modify, sequence number =  13030
# modify, sequence number =  13046
# modify, sequence number =  13050
# modify, sequence number =  13052
# modify, sequence number =  13062
# modify, sequence number =  13098
# modify, sequence number =  13102
# modify, sequence number =  13142
# modify, sequence number =  13152
# modify, sequence number =  13155
# modify, sequence number =  13156
# modify, sequence number =  13159
# modify, sequence number =  13172
# modify, sequence number =  13186
# modify, sequence number =  13191
# modify, sequence number =  13213
# modify, sequence number =  13218
# modify, sequence number =  13220
# modify, sequence number =  13229
# modify, sequence number =  13238
# modify, sequence number =  13276
# modify, sequence number =  13278
# modify, sequence number =  13333
# modify, sequence number =  13357
# modify, sequence number =  13382
# modify, sequence number =  13387
# modify, sequence number =  13405
# modify, sequence number =  13408
# modify, sequence number =  13409
# modify, sequence number =  13412
# modify, sequence number =  13424
# modify, sequence number =  13436
# modify, sequence number =  13457
# modify, sequence number =  13461
# modify, sequence number =  13482
# modify, sequence number =  13507
# modify, sequence number =  13525
# modify, sequence number =  13536
# modify, sequence number =  13544
# modify, sequence number =  13553
# modify, sequence number =  13560
# modify, sequence number =  13565
# modify, sequence number =  13570
# modify, sequence number =  13576
# modify, sequence number =  13580
# modify, sequence number =  13590
# modify, sequence number =  13599
# modify, sequence number =  13610
# modify, sequence number =  13619
# modify, sequence number =  13628
# modify, sequence number =  13633
# modify, sequence number =  13680
# modify, sequence number =  13683
# modify, sequence number =  13686
# modify, sequence number =  13688
# modify, sequence number =  13689
# modify, sequence number =  13694
# modify, sequence number =  13706
# modify, sequence number =  13715
# modify, sequence number =  13727
# modify, sequence number =  13728
# modify, sequence number =  13741
# modify, sequence number =  13742
# modify, sequence number =  13761
# modify, sequence number =  13764
# modify, sequence number =  13765
# modify, sequence number =  13776
# modify, sequence number =  13779
# modify, sequence number =  13809
# modify, sequence number =  13811
# modify, sequence number =  13822
# modify, sequence number =  13826
# modify, sequence number =  13840
# modify, sequence number =  13843
# modify, sequence number =  13855
# modify, sequence number =  13868
# modify, sequence number =  13882
# modify, sequence number =  13922
# modify, sequence number =  13925
# modify, sequence number =  13940
# modify, sequence number =  13952
# modify, sequence number =  13961
# modify, sequence number =  13971
# modify, sequence number =  13985
# modify, sequence number =  13988
# modify, sequence number =  13989
# modify, sequence number =  13992
# modify, sequence number =  13998
# modify, sequence number =  14006
# modify, sequence number =  14020
# modify, sequence number =  14031
# modify, sequence number =  14034
# modify, sequence number =  14040
# modify, sequence number =  14043
# modify, sequence number =  14058
# modify, sequence number =  14059
# modify, sequence number =  14076
# modify, sequence number =  14092
# modify, sequence number =  14094
# modify, sequence number =  14101
# modify, sequence number =  14113
# modify, sequence number =  14126
# modify, sequence number =  14128
# modify, sequence number =  14133
# modify, sequence number =  14139
# modify, sequence number =  14160
# modify, sequence number =  14192
# modify, sequence number =  14195
# modify, sequence number =  14198
# modify, sequence number =  14210
# modify, sequence number =  14216
# modify, sequence number =  14217
# modify, sequence number =  14223
# modify, sequence number =  14251
# modify, sequence number =  14253
# modify, sequence number =  14264
# modify, sequence number =  14272
# modify, sequence number =  14285
# modify, sequence number =  14294
# modify, sequence number =  14297
# modify, sequence number =  14302
# modify, sequence number =  14325
# modify, sequence number =  14327
# modify, sequence number =  14339
# modify, sequence number =  14372
# modify, sequence number =  14373
# modify, sequence number =  14380
# modify, sequence number =  14381
# modify, sequence number =  14386
# modify, sequence number =  14395
# modify, sequence number =  14401
# modify, sequence number =  14424
# modify, sequence number =  14445
# modify, sequence number =  14447
# modify, sequence number =  14466
# modify, sequence number =  14474
# modify, sequence number =  14476
# modify, sequence number =  14482
# modify, sequence number =  14485
# modify, sequence number =  14489
# modify, sequence number =  14504
# modify, sequence number =  14524
# modify, sequence number =  14533
# modify, sequence number =  14536
# modify, sequence number =  14545
# modify, sequence number =  14549
# modify, sequence number =  14566
# modify, sequence number =  14570
# modify, sequence number =  14580
# modify, sequence number =  14588
# modify, sequence number =  14591
# modify, sequence number =  14592
# modify, sequence number =  14598
# modify, sequence number =  14608
# modify, sequence number =  14609
# modify, sequence number =  14610
# modify, sequence number =  14643
# modify, sequence number =  14651
# modify, sequence number =  14658
# modify, sequence number =  14684
# modify, sequence number =  14689
# modify, sequence number =  14690
# modify, sequence number =  14707
# modify, sequence number =  14711
# modify, sequence number =  14714
# modify, sequence number =  14728
# modify, sequence number =  14752
# modify, sequence number =  14796
# modify, sequence number =  14800
# modify, sequence number =  14804
# modify, sequence number =  14807
# modify, sequence number =  14823
# modify, sequence number =  14827
# modify, sequence number =  14840
# modify, sequence number =  14860
# modify, sequence number =  14866
# modify, sequence number =  14868
# modify, sequence number =  14889
# modify, sequence number =  14904
# modify, sequence number =  14909
# modify, sequence number =  14915
# modify, sequence number =  14931
# modify, sequence number =  14934
# modify, sequence number =  14936
# modify, sequence number =  14976
# modify, sequence number =  14977
# ...
# modify, sequence number =  73473
# modify, sequence number =  73477
# modify, sequence number =  73478
# modify, sequence number =  73529
# modify, sequence number =  73535
# modify, sequence number =  73536
# modify, sequence number =  73554
# modify, sequence number =  73572
# modify, sequence number =  73588
# modify, sequence number =  73592
# modify, sequence number =  73594
# modify, sequence number =  73599
# modify, sequence number =  73600
# modify, sequence number =  73617
# modify, sequence number =  73620
# modify, sequence number =  73623
# modify, sequence number =  73636
# modify, sequence number =  73641
# modify, sequence number =  73644
# modify, sequence number =  73645
# modify, sequence number =  73658
# modify, sequence number =  73662
# modify, sequence number =  73670
# modify, sequence number =  73672
# modify, sequence number =  73686
# modify, sequence number =  73698
# modify, sequence number =  73704
# modify, sequence number =  73707
# modify, sequence number =  73718
# modify, sequence number =  73722
# modify, sequence number =  73725
# modify, sequence number =  73727
# modify, sequence number =  73732
# modify, sequence number =  73745
# modify, sequence number =  73752
# modify, sequence number =  73758
# modify, sequence number =  73761
# modify, sequence number =  73762
# modify, sequence number =  73771
# modify, sequence number =  73777
# modify, sequence number =  73778
# modify, sequence number =  73780
# modify, sequence number =  73788
# modify, sequence number =  73789
# modify, sequence number =  73811
# modify, sequence number =  73812
# modify, sequence number =  73824
# modify, sequence number =  73828
# modify, sequence number =  73832
# modify, sequence number =  73838
# modify, sequence number =  73844
# modify, sequence number =  73847
# modify, sequence number =  73848
# modify, sequence number =  73859
# modify, sequence number =  73862
# modify, sequence number =  73864
# modify, sequence number =  73865
# modify, sequence number =  73866
# modify, sequence number =  73893
# modify, sequence number =  73908
# modify, sequence number =  73913
# modify, sequence number =  73925
# modify, sequence number =  73926
# modify, sequence number =  73928
# modify, sequence number =  73935
# modify, sequence number =  73941
# modify, sequence number =  73947
# modify, sequence number =  73974
# modify, sequence number =  73975
# modify, sequence number =  73996
# modify, sequence number =  73997
# modify, sequence number =  74005
# modify, sequence number =  74011
# modify, sequence number =  74012
# modify, sequence number =  74015
# modify, sequence number =  74025
# modify, sequence number =  74026
# modify, sequence number =  74058
# modify, sequence number =  74060
# modify, sequence number =  74067
# modify, sequence number =  74068
# modify, sequence number =  74090
# modify, sequence number =  74096
# modify, sequence number =  74097
# modify, sequence number =  74122
# modify, sequence number =  74124
# modify, sequence number =  74132
# modify, sequence number =  74138
# modify, sequence number =  74140
# modify, sequence number =  74157
# modify, sequence number =  74170
# modify, sequence number =  74179
# modify, sequence number =  74186
# modify, sequence number =  74187
# modify, sequence number =  74190
# modify, sequence number =  74204
# modify, sequence number =  74207
# modify, sequence number =  74211
# modify, sequence number =  74222
# modify, sequence number =  74225
# modify, sequence number =  74234
# modify, sequence number =  74243
# modify, sequence number =  74247
# modify, sequence number =  74249
# modify, sequence number =  74263
# modify, sequence number =  74270
# modify, sequence number =  74281
# modify, sequence number =  74297
# modify, sequence number =  74316
# modify, sequence number =  74319
# modify, sequence number =  74326
# modify, sequence number =  74333
# modify, sequence number =  74352
# modify, sequence number =  74359
# modify, sequence number =  74373
# modify, sequence number =  74384
# modify, sequence number =  74387
# modify, sequence number =  74396
# modify, sequence number =  74408
# modify, sequence number =  74415
# modify, sequence number =  74427
# modify, sequence number =  74428
# modify, sequence number =  74432
# modify, sequence number =  74436
# modify, sequence number =  74460
# modify, sequence number =  74470
# modify, sequence number =  74493
# modify, sequence number =  74533
# modify, sequence number =  74539
# modify, sequence number =  74541
# modify, sequence number =  74547
# modify, sequence number =  74578
# modify, sequence number =  74579
# modify, sequence number =  74581
# modify, sequence number =  74606
# modify, sequence number =  74615
# modify, sequence number =  74623
# modify, sequence number =  74639
# modify, sequence number =  74641
# modify, sequence number =  74644
# modify, sequence number =  74647
# modify, sequence number =  74654
# modify, sequence number =  74657
# modify, sequence number =  74676
# modify, sequence number =  74678
# modify, sequence number =  74682
# modify, sequence number =  74686
# modify, sequence number =  74716
# modify, sequence number =  74720
# modify, sequence number =  74727
# modify, sequence number =  74731
# modify, sequence number =  74732
# modify, sequence number =  74733
# modify, sequence number =  74734
# modify, sequence number =  74735
# modify, sequence number =  74738
# modify, sequence number =  74759
# modify, sequence number =  74779
# modify, sequence number =  74795
# modify, sequence number =  74809
# modify, sequence number =  74812
# modify, sequence number =  74827
# modify, sequence number =  74833
# modify, sequence number =  74834
# modify, sequence number =  74843
# modify, sequence number =  74848
# modify, sequence number =  74849
# modify, sequence number =  74857
# modify, sequence number =  74863
# modify, sequence number =  74866
# modify, sequence number =  74879
# modify, sequence number =  74895
# modify, sequence number =  74919
# modify, sequence number =  74945
# modify, sequence number =  74961
# modify, sequence number =  74963
# modify, sequence number =  74970
# modify, sequence number =  74981
# modify, sequence number =  74982
# modify, sequence number =  74987
# modify, sequence number =  74996
# modify, sequence number =  75000
# modify, sequence number =  75007
# modify, sequence number =  75009
# modify, sequence number =  75011
# modify, sequence number =  75017
# modify, sequence number =  75054
# modify, sequence number =  75073
# modify, sequence number =  75075
# modify, sequence number =  75076
# modify, sequence number =  75087
# modify, sequence number =  75093
# modify, sequence number =  75100
# modify, sequence number =  75111
# modify, sequence number =  75122
# modify, sequence number =  75124
# modify, sequence number =  75147
# modify, sequence number =  75161
# modify, sequence number =  75179
# modify, sequence number =  75187
# modify, sequence number =  75203
# modify, sequence number =  75208
# modify, sequence number =  75247
# modify, sequence number =  75259
# modify, sequence number =  75261
# modify, sequence number =  75270
# modify, sequence number =  75277
# modify, sequence number =  75298
# modify, sequence number =  75332
# modify, sequence number =  75360
# modify, sequence number =  75361
# modify, sequence number =  75378
# modify, sequence number =  75386
# modify, sequence number =  75391
# modify, sequence number =  75410
# modify, sequence number =  75423
# modify, sequence number =  75452
# modify, sequence number =  75484
# modify, sequence number =  75491
# modify, sequence number =  75494
# modify, sequence number =  75540
# modify, sequence number =  75550
# modify, sequence number =  75554
# modify, sequence number =  75564
# modify, sequence number =  75572
# modify, sequence number =  75574
# modify, sequence number =  75577
# modify, sequence number =  75613
# modify, sequence number =  75617
# modify, sequence number =  75624
# modify, sequence number =  75644
# modify, sequence number =  75651
# modify, sequence number =  75658
# modify, sequence number =  75665
# modify, sequence number =  75687
# modify, sequence number =  75689
# modify, sequence number =  75707
# modify, sequence number =  75717
# modify, sequence number =  75718
# modify, sequence number =  75722
# modify, sequence number =  75724
# modify, sequence number =  75731
# modify, sequence number =  75742
# modify, sequence number =  75747
# modify, sequence number =  75778
# modify, sequence number =  75781
# modify, sequence number =  75793
# modify, sequence number =  75801
# modify, sequence number =  75809
# modify, sequence number =  75823
# modify, sequence number =  75825
# modify, sequence number =  75850
# modify, sequence number =  75852
# modify, sequence number =  75856
# modify, sequence number =  75865
# modify, sequence number =  75867
# modify, sequence number =  75868
# modify, sequence number =  75870
# modify, sequence number =  75886
# modify, sequence number =  75891
# modify, sequence number =  75903
# modify, sequence number =  75904
# modify, sequence number =  75916
# modify, sequence number =  75935
# modify, sequence number =  75949
# modify, sequence number =  75950
# modify, sequence number =  75965
# modify, sequence number =  75971
# modify, sequence number =  75980
# modify, sequence number =  75987
# modify, sequence number =  75992
# modify, sequence number =  76035
# modify, sequence number =  76036
# modify, sequence number =  76079
# modify, sequence number =  76083
# modify, sequence number =  76094
# modify, sequence number =  76099
# modify, sequence number =  76116
# modify, sequence number =  76135
# modify, sequence number =  76142
# modify, sequence number =  76161
# modify, sequence number =  76182
# modify, sequence number =  76189
# modify, sequence number =  76204
# modify, sequence number =  76209
# modify, sequence number =  76213
# modify, sequence number =  76214
# modify, sequence number =  76219
# modify, sequence number =  76220
# modify, sequence number =  76225
# modify, sequence number =  76228
# modify, sequence number =  76242
# modify, sequence number =  76273
# modify, sequence number =  76295
# modify, sequence number =  76296
# modify, sequence number =  76308
# modify, sequence number =  76313
# modify, sequence number =  76342
# modify, sequence number =  76348
# modify, sequence number =  76350
# modify, sequence number =  76359
# modify, sequence number =  76362
# modify, sequence number =  76382
# modify, sequence number =  76383
# modify, sequence number =  76385
# modify, sequence number =  76389
# modify, sequence number =  76403
# modify, sequence number =  76417
# modify, sequence number =  76420
# modify, sequence number =  76426
# modify, sequence number =  76430
# modify, sequence number =  76455
# modify, sequence number =  76458
# modify, sequence number =  76459
# modify, sequence number =  76470
# modify, sequence number =  76484
# modify, sequence number =  76489
# modify, sequence number =  76504
# modify, sequence number =  76507
# modify, sequence number =  76509
# modify, sequence number =  76510
# modify, sequence number =  76511
# modify, sequence number =  76518
# modify, sequence number =  76526
# modify, sequence number =  76528
# modify, sequence number =  76534
# modify, sequence number =  76571
# modify, sequence number =  76581
# modify, sequence number =  76582
# modify, sequence number =  76587
# modify, sequence number =  76613
# modify, sequence number =  76620
# modify, sequence number =  76638
# modify, sequence number =  76651
# modify, sequence number =  76656
# modify, sequence number =  76669
# modify, sequence number =  76688
# modify, sequence number =  76708
# modify, sequence number =  76711
# modify, sequence number =  76715
# modify, sequence number =  76718
# modify, sequence number =  76728
# modify, sequence number =  76730
# modify, sequence number =  76741
# modify, sequence number =  76750
# modify, sequence number =  76753
# modify, sequence number =  76756
# modify, sequence number =  76774
# modify, sequence number =  76792
# modify, sequence number =  76796
# modify, sequence number =  76801
# modify, sequence number =  76819
# modify, sequence number =  76822
# modify, sequence number =  76833
# modify, sequence number =  76852
# modify, sequence number =  76854
# modify, sequence number =  76858
# modify, sequence number =  76864
# modify, sequence number =  76868
# modify, sequence number =  76869
# modify, sequence number =  76872
# modify, sequence number =  76915
# modify, sequence number =  76922
# modify, sequence number =  76930
# modify, sequence number =  76932
# modify, sequence number =  76942
# modify, sequence number =  76948
# modify, sequence number =  76949
# modify, sequence number =  76960
# modify, sequence number =  76970
# modify, sequence number =  76973
# modify, sequence number =  76974
# modify, sequence number =  76987
# modify, sequence number =  76991
# modify, sequence number =  76995
# modify, sequence number =  77003
# modify, sequence number =  77020
# modify, sequence number =  77021
# modify, sequence number =  77033
# modify, sequence number =  77036
# modify, sequence number =  77042
# modify, sequence number =  77049
# modify, sequence number =  77053
# modify, sequence number =  77066
# modify, sequence number =  77089
# modify, sequence number =  77092
# modify, sequence number =  77098
# modify, sequence number =  77116
# modify, sequence number =  77121
# modify, sequence number =  77131
# modify, sequence number =  77148
# modify, sequence number =  77160
# modify, sequence number =  77174
# modify, sequence number =  77175
# modify, sequence number =  77177
# modify, sequence number =  77195
# modify, sequence number =  77210
# modify, sequence number =  77213
# modify, sequence number =  77219
# modify, sequence number =  77232
# modify, sequence number =  77246
# modify, sequence number =  77256
# modify, sequence number =  77269
# modify, sequence number =  77277
# modify, sequence number =  77293
# modify, sequence number =  77296
# modify, sequence number =  77302
# modify, sequence number =  77316
# modify, sequence number =  77335
# modify, sequence number =  77342
# modify, sequence number =  77348
# modify, sequence number =  77352
# modify, sequence number =  77363
# modify, sequence number =  77367
# modify, sequence number =  77368
# modify, sequence number =  77375
# modify, sequence number =  77395
# modify, sequence number =  77410
# modify, sequence number =  77419
# modify, sequence number =  77425
# modify, sequence number =  77428
# modify, sequence number =  77431
# modify, sequence number =  77436
# modify, sequence number =  77446
# modify, sequence number =  77450
# modify, sequence number =  77455
# modify, sequence number =  77460
# modify, sequence number =  77464
# modify, sequence number =  77474
# modify, sequence number =  77489
# modify, sequence number =  77498
# modify, sequence number =  77502
# modify, sequence number =  77507
# modify, sequence number =  77510
# modify, sequence number =  77519
# modify, sequence number =  77520
# modify, sequence number =  77544
# modify, sequence number =  77566
# modify, sequence number =  77604
# modify, sequence number =  77608
# modify, sequence number =  77612
# modify, sequence number =  77619
# modify, sequence number =  77620
# modify, sequence number =  77629
# modify, sequence number =  77635
# modify, sequence number =  77638
# modify, sequence number =  77648
# modify, sequence number =  77651
# modify, sequence number =  77663
# modify, sequence number =  77667
# modify, sequence number =  77671
# modify, sequence number =  77681
# modify, sequence number =  77685
# modify, sequence number =  77714
# modify, sequence number =  77717
# modify, sequence number =  77753
# modify, sequence number =  77790
# modify, sequence number =  77807
# modify, sequence number =  77818
# modify, sequence number =  77821
# modify, sequence number =  77840
# modify, sequence number =  77841
# modify, sequence number =  77844
# modify, sequence number =  77846
# modify, sequence number =  77849
# modify, sequence number =  77882
# modify, sequence number =  77892
# modify, sequence number =  77894
# modify, sequence number =  77901
# modify, sequence number =  77910
# modify, sequence number =  77925
# modify, sequence number =  77935
# modify, sequence number =  77941
# modify, sequence number =  77944
# modify, sequence number =  77949
# modify, sequence number =  77959
# modify, sequence number =  77966
# modify, sequence number =  77977
# modify, sequence number =  77980
# modify, sequence number =  77984
# modify, sequence number =  77987
# modify, sequence number =  77996
# modify, sequence number =  78000
# modify, sequence number =  78004
# Image sent
# 78012

# %%
groups = divide_image_into_pixel_groups("output.png", group_pixel_count=30)
# combine the groups into a single image

len(groups)
# Out:
# 78012

# %%
# groups[0] = Image.fromarray(np.zeros(np.array(groups[1]).shape, dtype=np.uint8))
# groups[0]
np.array(groups[1]).shape
# Out:
# (6, 5, 3)

# %%
import hmac

len(hmac.new(b'key', b'message', 'sha384').digest())
# Out:
# 48
