# %%
import socket
import rawpy
import time
import numpy as np
from PIL import Image
import hmac



# Divide the image into into 920 bit chunks
def divide_image_into_pixel_groups(image_path, group_pixel_count=30):
    # Step 1: Loading the Image
    with Image.open(image_path).convert('RGB') as img:
        width, height = img.size
        

        # Step 2: Calculating Group Dimensions
        # Find a suitable width and height for the groups that would approximately contain 1024 pixels
        group_width = int(np.sqrt(group_pixel_count))
        group_height = group_pixel_count // group_width

        # Adjust group_height in case group_width * group_height < 1024
        if group_width * group_height < group_pixel_count:
            group_height += 1

        groups = []

        # Step 3: Dividing the Image
        for y in range(0, height, group_height):
            for x in range(0, width, group_width):
                # Define the bounding box for each group
                box = (x, y, x + group_width, y + group_height)
                # Crop the image to the box to get the group
                group = img.crop(box)
                groups.append(group)

        return groups


def send_bmp_image(file_path, ip, port, p):
    groups = divide_image_into_pixel_groups(file_path)
    

    # Create a UDP socket
    sock = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)

    i =0
    try:
        for pixel_group in groups:
  
            chunk = pixel_group.tobytes()
            # Send chunk index and chunk data
            if np.random.rand() < p:
                mac = hmac.new(b'key', chunk, 'sha384').digest()
                sock.sendto(i.to_bytes(4, 'big') + chunk + mac , (ip, port))
                time.sleep(0.0001)
            else:
                print("modify, sequence number = ", i)
                mac = hmac.new(b'key', b'modified', 'sha384').digest()
                if np.random.rand() < .5:
                    sock.sendto(i.to_bytes(4, 'big') + chunk + mac, (ip, port))
                time.sleep(0.0001)
            if i % 10000 == 0:
                print("Sent chunk ", i, " of ", len(groups))
            i += 1
            

        # Send a final message indicating completion
        sock.sendto(b'END', (ip, port))
    finally:
        print("Image sent")
        sock.close()
    return i

# Example usage
file_path = 'output.png'
destination_ip = '0.0.0.0'
destination_port = 23423


# packet success probability
p = .9
send_bmp_image(file_path, destination_ip, destination_port, p = p)
# Out:
# Sent chunk  0  of  78012
# modify, sequence number =  7
# modify, sequence number =  16
# modify, sequence number =  39
# modify, sequence number =  43
# modify, sequence number =  58
# modify, sequence number =  81
# modify, sequence number =  84
# modify, sequence number =  91
# modify, sequence number =  95
# modify, sequence number =  115
# modify, sequence number =  123
# modify, sequence number =  144
# modify, sequence number =  172
# modify, sequence number =  176
# modify, sequence number =  178
# modify, sequence number =  196
# modify, sequence number =  198
# modify, sequence number =  215
# modify, sequence number =  222
# modify, sequence number =  227
# modify, sequence number =  233
# modify, sequence number =  244
# modify, sequence number =  250
# modify, sequence number =  251
# modify, sequence number =  255
# modify, sequence number =  261
# modify, sequence number =  262
# modify, sequence number =  281
# modify, sequence number =  302
# modify, sequence number =  309
# modify, sequence number =  312
# modify, sequence number =  315
# modify, sequence number =  334
# modify, sequence number =  336
# modify, sequence number =  339
# modify, sequence number =  359
# modify, sequence number =  369
# modify, sequence number =  404
# modify, sequence number =  414
# modify, sequence number =  425
# modify, sequence number =  475
# modify, sequence number =  478
# modify, sequence number =  481
# modify, sequence number =  483
# modify, sequence number =  501
# modify, sequence number =  517
# modify, sequence number =  523
# modify, sequence number =  529
# modify, sequence number =  534
# modify, sequence number =  547
# modify, sequence number =  551
# modify, sequence number =  556
# modify, sequence number =  603
# modify, sequence number =  612
# modify, sequence number =  622
# modify, sequence number =  627
# modify, sequence number =  630
# modify, sequence number =  635
# modify, sequence number =  675
# modify, sequence number =  684
# modify, sequence number =  691
# modify, sequence number =  693
# modify, sequence number =  700
# modify, sequence number =  708
# modify, sequence number =  718
# modify, sequence number =  721
# modify, sequence number =  739
# modify, sequence number =  757
# modify, sequence number =  761
# modify, sequence number =  766
# modify, sequence number =  772
# modify, sequence number =  790
# modify, sequence number =  795
# modify, sequence number =  810
# modify, sequence number =  818
# modify, sequence number =  820
# modify, sequence number =  825
# modify, sequence number =  844
# modify, sequence number =  859
# modify, sequence number =  860
# modify, sequence number =  863
# modify, sequence number =  881
# modify, sequence number =  897
# modify, sequence number =  901
# modify, sequence number =  913
# modify, sequence number =  917
# modify, sequence number =  919
# modify, sequence number =  922
# modify, sequence number =  929
# modify, sequence number =  938
# modify, sequence number =  939
# modify, sequence number =  940
# modify, sequence number =  946
# modify, sequence number =  976
# modify, sequence number =  1002
# modify, sequence number =  1004
# modify, sequence number =  1007
# modify, sequence number =  1009
# modify, sequence number =  1012
# modify, sequence number =  1014
# modify, sequence number =  1031
# modify, sequence number =  1035
# modify, sequence number =  1043
# modify, sequence number =  1044
# modify, sequence number =  1057
# modify, sequence number =  1068
# modify, sequence number =  1080
# modify, sequence number =  1096
# modify, sequence number =  1101
# modify, sequence number =  1103
# modify, sequence number =  1131
# modify, sequence number =  1153
# modify, sequence number =  1155
# modify, sequence number =  1169
# modify, sequence number =  1175
# modify, sequence number =  1193
# modify, sequence number =  1197
# modify, sequence number =  1200
# modify, sequence number =  1214
# modify, sequence number =  1234
# modify, sequence number =  1247
# modify, sequence number =  1255
# modify, sequence number =  1260
# modify, sequence number =  1268
# modify, sequence number =  1275
# modify, sequence number =  1280
# modify, sequence number =  1281
# modify, sequence number =  1289
# modify, sequence number =  1291
# modify, sequence number =  1303
# modify, sequence number =  1306
# modify, sequence number =  1310
# modify, sequence number =  1312
# modify, sequence number =  1356
# modify, sequence number =  1366
# modify, sequence number =  1374
# modify, sequence number =  1379
# modify, sequence number =  1403
# modify, sequence number =  1413
# modify, sequence number =  1418
# modify, sequence number =  1424
# modify, sequence number =  1427
# modify, sequence number =  1429
# modify, sequence number =  1434
# modify, sequence number =  1439
# modify, sequence number =  1468
# modify, sequence number =  1473
# modify, sequence number =  1502
# modify, sequence number =  1506
# modify, sequence number =  1515
# modify, sequence number =  1521
# modify, sequence number =  1529
# modify, sequence number =  1532
# modify, sequence number =  1538
# modify, sequence number =  1543
# modify, sequence number =  1545
# modify, sequence number =  1553
# modify, sequence number =  1560
# modify, sequence number =  1562
# modify, sequence number =  1564
# modify, sequence number =  1572
# modify, sequence number =  1602
# modify, sequence number =  1614
# modify, sequence number =  1623
# modify, sequence number =  1629
# modify, sequence number =  1632
# modify, sequence number =  1637
# modify, sequence number =  1639
# modify, sequence number =  1647
# modify, sequence number =  1660
# modify, sequence number =  1665
# modify, sequence number =  1668
# modify, sequence number =  1672
# modify, sequence number =  1681
# modify, sequence number =  1683
# modify, sequence number =  1690
# modify, sequence number =  1703
# modify, sequence number =  1704
# modify, sequence number =  1711
# modify, sequence number =  1717
# modify, sequence number =  1725
# modify, sequence number =  1729
# modify, sequence number =  1736
# modify, sequence number =  1746
# modify, sequence number =  1747
# modify, sequence number =  1751
# modify, sequence number =  1763
# modify, sequence number =  1773
# modify, sequence number =  1836
# modify, sequence number =  1846
# modify, sequence number =  1877
# modify, sequence number =  1905
# modify, sequence number =  1907
# modify, sequence number =  1908
# modify, sequence number =  1930
# modify, sequence number =  1933
# modify, sequence number =  1942
# modify, sequence number =  1948
# modify, sequence number =  1958
# modify, sequence number =  1963
# modify, sequence number =  1978
# modify, sequence number =  1982
# modify, sequence number =  1994
# modify, sequence number =  2012
# modify, sequence number =  2015
# modify, sequence number =  2016
# modify, sequence number =  2022
# modify, sequence number =  2025
# modify, sequence number =  2044
# modify, sequence number =  2078
# modify, sequence number =  2088
# modify, sequence number =  2092
# modify, sequence number =  2094
# modify, sequence number =  2096
# modify, sequence number =  2101
# modify, sequence number =  2118
# modify, sequence number =  2127
# modify, sequence number =  2142
# modify, sequence number =  2150
# modify, sequence number =  2164
# modify, sequence number =  2165
# modify, sequence number =  2167
# modify, sequence number =  2170
# modify, sequence number =  2173
# modify, sequence number =  2190
# modify, sequence number =  2209
# modify, sequence number =  2224
# modify, sequence number =  2251
# modify, sequence number =  2254
# modify, sequence number =  2260
# modify, sequence number =  2264
# modify, sequence number =  2265
# modify, sequence number =  2273
# modify, sequence number =  2275
# modify, sequence number =  2300
# modify, sequence number =  2301
# modify, sequence number =  2324
# modify, sequence number =  2338
# modify, sequence number =  2344
# modify, sequence number =  2353
# modify, sequence number =  2360
# modify, sequence number =  2369
# modify, sequence number =  2372
# modify, sequence number =  2398
# modify, sequence number =  2403
# modify, sequence number =  2408
# modify, sequence number =  2423
# modify, sequence number =  2427
# modify, sequence number =  2439
# modify, sequence number =  2442
# modify, sequence number =  2444
# modify, sequence number =  2449
# modify, sequence number =  2460
# modify, sequence number =  2469
# modify, sequence number =  2481
# modify, sequence number =  2499
# modify, sequence number =  2512
# modify, sequence number =  2522
# modify, sequence number =  2538
# modify, sequence number =  2540
# modify, sequence number =  2545
# modify, sequence number =  2565
# modify, sequence number =  2587
# modify, sequence number =  2588
# modify, sequence number =  2591
# modify, sequence number =  2594
# modify, sequence number =  2598
# modify, sequence number =  2615
# modify, sequence number =  2628
# modify, sequence number =  2633
# modify, sequence number =  2635
# modify, sequence number =  2643
# modify, sequence number =  2648
# modify, sequence number =  2654
# modify, sequence number =  2657
# modify, sequence number =  2659
# modify, sequence number =  2676
# modify, sequence number =  2677
# modify, sequence number =  2690
# modify, sequence number =  2697
# modify, sequence number =  2699
# modify, sequence number =  2709
# modify, sequence number =  2716
# modify, sequence number =  2720
# modify, sequence number =  2724
# modify, sequence number =  2730
# modify, sequence number =  2732
# modify, sequence number =  2740
# modify, sequence number =  2743
# modify, sequence number =  2746
# modify, sequence number =  2763
# modify, sequence number =  2770
# modify, sequence number =  2780
# modify, sequence number =  2818
# modify, sequence number =  2846
# modify, sequence number =  2853
# modify, sequence number =  2859
# modify, sequence number =  2869
# modify, sequence number =  2874
# modify, sequence number =  2880
# modify, sequence number =  2886
# modify, sequence number =  2889
# modify, sequence number =  2899
# modify, sequence number =  2915
# modify, sequence number =  2919
# modify, sequence number =  2921
# modify, sequence number =  2930
# modify, sequence number =  2945
# modify, sequence number =  2946
# modify, sequence number =  2957
# modify, sequence number =  2971
# modify, sequence number =  2981
# modify, sequence number =  3016
# modify, sequence number =  3020
# modify, sequence number =  3037
# modify, sequence number =  3047
# modify, sequence number =  3057
# modify, sequence number =  3063
# modify, sequence number =  3069
# modify, sequence number =  3075
# modify, sequence number =  3086
# modify, sequence number =  3089
# modify, sequence number =  3132
# modify, sequence number =  3141
# modify, sequence number =  3147
# modify, sequence number =  3155
# modify, sequence number =  3156
# modify, sequence number =  3196
# modify, sequence number =  3200
# modify, sequence number =  3201
# modify, sequence number =  3203
# modify, sequence number =  3207
# modify, sequence number =  3224
# modify, sequence number =  3235
# modify, sequence number =  3246
# modify, sequence number =  3253
# modify, sequence number =  3261
# modify, sequence number =  3266
# modify, sequence number =  3269
# modify, sequence number =  3272
# modify, sequence number =  3277
# modify, sequence number =  3316
# modify, sequence number =  3329
# modify, sequence number =  3332
# modify, sequence number =  3342
# modify, sequence number =  3345
# modify, sequence number =  3351
# modify, sequence number =  3366
# modify, sequence number =  3381
# modify, sequence number =  3394
# modify, sequence number =  3435
# modify, sequence number =  3448
# modify, sequence number =  3463
# modify, sequence number =  3492
# modify, sequence number =  3520
# modify, sequence number =  3533
# modify, sequence number =  3545
# modify, sequence number =  3555
# modify, sequence number =  3579
# modify, sequence number =  3611
# modify, sequence number =  3615
# modify, sequence number =  3640
# modify, sequence number =  3643
# modify, sequence number =  3683
# modify, sequence number =  3684
# modify, sequence number =  3687
# modify, sequence number =  3703
# modify, sequence number =  3719
# modify, sequence number =  3720
# modify, sequence number =  3726
# modify, sequence number =  3737
# modify, sequence number =  3762
# modify, sequence number =  3768
# modify, sequence number =  3769
# modify, sequence number =  3770
# modify, sequence number =  3778
# modify, sequence number =  3779
# modify, sequence number =  3781
# modify, sequence number =  3794
# modify, sequence number =  3800
# modify, sequence number =  3808
# modify, sequence number =  3814
# modify, sequence number =  3817
# modify, sequence number =  3823
# modify, sequence number =  3851
# modify, sequence number =  3877
# modify, sequence number =  3884
# modify, sequence number =  3885
# modify, sequence number =  3892
# modify, sequence number =  3897
# modify, sequence number =  3905
# modify, sequence number =  3910
# modify, sequence number =  3920
# modify, sequence number =  3926
# modify, sequence number =  3942
# modify, sequence number =  3950
# modify, sequence number =  3953
# modify, sequence number =  3976
# modify, sequence number =  3980
# modify, sequence number =  3989
# modify, sequence number =  4003
# modify, sequence number =  4010
# modify, sequence number =  4014
# modify, sequence number =  4015
# modify, sequence number =  4028
# modify, sequence number =  4054
# modify, sequence number =  4062
# modify, sequence number =  4068
# modify, sequence number =  4070
# modify, sequence number =  4087
# modify, sequence number =  4088
# modify, sequence number =  4093
# modify, sequence number =  4114
# modify, sequence number =  4115
# modify, sequence number =  4124
# modify, sequence number =  4130
# modify, sequence number =  4149
# modify, sequence number =  4153
# modify, sequence number =  4156
# modify, sequence number =  4164
# modify, sequence number =  4175
# modify, sequence number =  4187
# modify, sequence number =  4192
# modify, sequence number =  4199
# modify, sequence number =  4208
# modify, sequence number =  4230
# modify, sequence number =  4254
# modify, sequence number =  4266
# modify, sequence number =  4292
# modify, sequence number =  4313
# modify, sequence number =  4321
# modify, sequence number =  4323
# modify, sequence number =  4333
# modify, sequence number =  4341
# modify, sequence number =  4346
# modify, sequence number =  4358
# modify, sequence number =  4361
# modify, sequence number =  4364
# modify, sequence number =  4380
# modify, sequence number =  4381
# modify, sequence number =  4432
# modify, sequence number =  4437
# modify, sequence number =  4440
# modify, sequence number =  4448
# modify, sequence number =  4449
# modify, sequence number =  4455
# modify, sequence number =  4468
# modify, sequence number =  4471
# modify, sequence number =  4475
# modify, sequence number =  4481
# modify, sequence number =  4501
# modify, sequence number =  4512
# modify, sequence number =  4513
# modify, sequence number =  4514
# modify, sequence number =  4521
# modify, sequence number =  4537
# modify, sequence number =  4544
# modify, sequence number =  4548
# modify, sequence number =  4562
# modify, sequence number =  4567
# modify, sequence number =  4575
# modify, sequence number =  4584
# modify, sequence number =  4586
# modify, sequence number =  4589
# modify, sequence number =  4594
# modify, sequence number =  4598
# modify, sequence number =  4602
# modify, sequence number =  4620
# modify, sequence number =  4621
# modify, sequence number =  4633
# modify, sequence number =  4634
# modify, sequence number =  4637
# modify, sequence number =  4642
# modify, sequence number =  4645
# modify, sequence number =  4654
# modify, sequence number =  4668
# modify, sequence number =  4677
# modify, sequence number =  4695
# modify, sequence number =  4703
# modify, sequence number =  4705
# modify, sequence number =  4726
# modify, sequence number =  4731
# modify, sequence number =  4741
# modify, sequence number =  4745
# modify, sequence number =  4769
# modify, sequence number =  4771
# modify, sequence number =  4797
# modify, sequence number =  4805
# modify, sequence number =  4837
# modify, sequence number =  4877
# modify, sequence number =  4882
# modify, sequence number =  4885
# modify, sequence number =  4888
# modify, sequence number =  4898
# modify, sequence number =  4903
# modify, sequence number =  4907
# modify, sequence number =  4908
# modify, sequence number =  4922
# modify, sequence number =  4924
# modify, sequence number =  4933
# modify, sequence number =  4939
# modify, sequence number =  4942
# modify, sequence number =  4949
# modify, sequence number =  4958
# modify, sequence number =  4968
# modify, sequence number =  4969
# modify, sequence number =  4980
# modify, sequence number =  5003
# modify, sequence number =  5018
# modify, sequence number =  5023
# modify, sequence number =  5025
# modify, sequence number =  5026
# modify, sequence number =  5029
# modify, sequence number =  5036
# modify, sequence number =  5038
# modify, sequence number =  5039
# modify, sequence number =  5049
# modify, sequence number =  5050
# modify, sequence number =  5052
# modify, sequence number =  5067
# modify, sequence number =  5072
# modify, sequence number =  5077
# modify, sequence number =  5099
# modify, sequence number =  5112
# modify, sequence number =  5121
# modify, sequence number =  5135
# modify, sequence number =  5137
# modify, sequence number =  5140
# modify, sequence number =  5141
# modify, sequence number =  5145
# modify, sequence number =  5173
# modify, sequence number =  5182
# modify, sequence number =  5189
# modify, sequence number =  5210
# modify, sequence number =  5223
# modify, sequence number =  5224
# modify, sequence number =  5228
# modify, sequence number =  5230
# modify, sequence number =  5231
# modify, sequence number =  5237
# modify, sequence number =  5248
# modify, sequence number =  5253
# modify, sequence number =  5254
# modify, sequence number =  5255
# modify, sequence number =  5257
# modify, sequence number =  5270
# modify, sequence number =  5272
# modify, sequence number =  5277
# modify, sequence number =  5283
# modify, sequence number =  5293
# modify, sequence number =  5314
# modify, sequence number =  5319
# modify, sequence number =  5330
# modify, sequence number =  5334
# modify, sequence number =  5352
# modify, sequence number =  5353
# modify, sequence number =  5358
# modify, sequence number =  5366
# modify, sequence number =  5438
# modify, sequence number =  5456
# modify, sequence number =  5468
# modify, sequence number =  5476
# modify, sequence number =  5495
# modify, sequence number =  5511
# modify, sequence number =  5515
# modify, sequence number =  5524
# modify, sequence number =  5530
# modify, sequence number =  5548
# modify, sequence number =  5561
# modify, sequence number =  5562
# modify, sequence number =  5566
# modify, sequence number =  5590
# modify, sequence number =  5600
# modify, sequence number =  5601
# modify, sequence number =  5608
# modify, sequence number =  5611
# modify, sequence number =  5628
# modify, sequence number =  5653
# modify, sequence number =  5658
# modify, sequence number =  5665
# modify, sequence number =  5670
# modify, sequence number =  5680
# modify, sequence number =  5693
# modify, sequence number =  5715
# modify, sequence number =  5716
# modify, sequence number =  5720
# modify, sequence number =  5727
# modify, sequence number =  5731
# modify, sequence number =  5739
# modify, sequence number =  5746
# modify, sequence number =  5750
# modify, sequence number =  5755
# modify, sequence number =  5764
# modify, sequence number =  5777
# modify, sequence number =  5780
# modify, sequence number =  5789
# modify, sequence number =  5794
# modify, sequence number =  5799
# modify, sequence number =  5835
# modify, sequence number =  5844
# modify, sequence number =  5853
# modify, sequence number =  5865
# modify, sequence number =  5880
# modify, sequence number =  5883
# modify, sequence number =  5885
# modify, sequence number =  5892
# modify, sequence number =  5907
# modify, sequence number =  5911
# modify, sequence number =  5921
# modify, sequence number =  5949
# modify, sequence number =  5957
# modify, sequence number =  5958
# modify, sequence number =  5976
# modify, sequence number =  5977
# modify, sequence number =  5984
# modify, sequence number =  5998
# modify, sequence number =  6002
# modify, sequence number =  6017
# modify, sequence number =  6027
# modify, sequence number =  6030
# modify, sequence number =  6038
# modify, sequence number =  6048
# modify, sequence number =  6073
# modify, sequence number =  6081
# modify, sequence number =  6105
# modify, sequence number =  6106
# modify, sequence number =  6114
# modify, sequence number =  6125
# modify, sequence number =  6142
# modify, sequence number =  6143
# modify, sequence number =  6154
# modify, sequence number =  6164
# modify, sequence number =  6165
# modify, sequence number =  6169
# modify, sequence number =  6207
# modify, sequence number =  6209
# modify, sequence number =  6212
# modify, sequence number =  6214
# modify, sequence number =  6223
# modify, sequence number =  6225
# modify, sequence number =  6264
# modify, sequence number =  6266
# modify, sequence number =  6268
# modify, sequence number =  6270
# modify, sequence number =  6277
# modify, sequence number =  6286
# modify, sequence number =  6290
# modify, sequence number =  6294
# modify, sequence number =  6296
# modify, sequence number =  6308
# modify, sequence number =  6339
# modify, sequence number =  6344
# modify, sequence number =  6351
# modify, sequence number =  6375
# modify, sequence number =  6393
# modify, sequence number =  6398
# modify, sequence number =  6401
# modify, sequence number =  6410
# modify, sequence number =  6419
# modify, sequence number =  6428
# modify, sequence number =  6429
# modify, sequence number =  6437
# modify, sequence number =  6438
# modify, sequence number =  6440
# modify, sequence number =  6453
# modify, sequence number =  6458
# modify, sequence number =  6473
# modify, sequence number =  6477
# modify, sequence number =  6478
# modify, sequence number =  6488
# modify, sequence number =  6491
# modify, sequence number =  6505
# modify, sequence number =  6509
# modify, sequence number =  6514
# modify, sequence number =  6517
# modify, sequence number =  6529
# modify, sequence number =  6531
# modify, sequence number =  6537
# modify, sequence number =  6554
# modify, sequence number =  6563
# modify, sequence number =  6576
# modify, sequence number =  6580
# modify, sequence number =  6583
# modify, sequence number =  6609
# modify, sequence number =  6621
# modify, sequence number =  6643
# modify, sequence number =  6648
# modify, sequence number =  6650
# modify, sequence number =  6654
# modify, sequence number =  6662
# modify, sequence number =  6664
# modify, sequence number =  6684
# modify, sequence number =  6695
# modify, sequence number =  6702
# modify, sequence number =  6712
# modify, sequence number =  6724
# modify, sequence number =  6728
# modify, sequence number =  6736
# modify, sequence number =  6752
# modify, sequence number =  6757
# modify, sequence number =  6760
# modify, sequence number =  6773
# modify, sequence number =  6788
# modify, sequence number =  6808
# modify, sequence number =  6830
# modify, sequence number =  6832
# modify, sequence number =  6836
# modify, sequence number =  6842
# modify, sequence number =  6850
# modify, sequence number =  6851
# modify, sequence number =  6855
# modify, sequence number =  6860
# modify, sequence number =  6865
# modify, sequence number =  6872
# modify, sequence number =  6877
# modify, sequence number =  6882
# modify, sequence number =  6884
# modify, sequence number =  6885
# modify, sequence number =  6901
# modify, sequence number =  6918
# modify, sequence number =  6936
# modify, sequence number =  6942
# modify, sequence number =  6943
# modify, sequence number =  6944
# modify, sequence number =  7014
# modify, sequence number =  7019
# modify, sequence number =  7038
# modify, sequence number =  7045
# modify, sequence number =  7048
# modify, sequence number =  7083
# modify, sequence number =  7113
# modify, sequence number =  7114
# modify, sequence number =  7120
# modify, sequence number =  7138
# modify, sequence number =  7152
# modify, sequence number =  7153
# modify, sequence number =  7155
# modify, sequence number =  7171
# modify, sequence number =  7190
# modify, sequence number =  7204
# modify, sequence number =  7205
# modify, sequence number =  7214
# modify, sequence number =  7244
# modify, sequence number =  7245
# modify, sequence number =  7250
# modify, sequence number =  7252
# modify, sequence number =  7255
# modify, sequence number =  7262
# modify, sequence number =  7267
# modify, sequence number =  7269
# modify, sequence number =  7287
# modify, sequence number =  7289
# modify, sequence number =  7305
# modify, sequence number =  7313
# modify, sequence number =  7318
# modify, sequence number =  7343
# modify, sequence number =  7345
# modify, sequence number =  7356
# modify, sequence number =  7357
# modify, sequence number =  7362
# modify, sequence number =  7371
# modify, sequence number =  7388
# modify, sequence number =  7404
# modify, sequence number =  7410
# modify, sequence number =  7416
# modify, sequence number =  7423
# modify, sequence number =  7433
# modify, sequence number =  7453
# modify, sequence number =  7479
# modify, sequence number =  7491
# modify, sequence number =  7498
# modify, sequence number =  7503
# modify, sequence number =  7515
# modify, sequence number =  7518
# modify, sequence number =  7523
# modify, sequence number =  7535
# modify, sequence number =  7548
# modify, sequence number =  7551
# modify, sequence number =  7567
# modify, sequence number =  7585
# modify, sequence number =  7586
# modify, sequence number =  7591
# modify, sequence number =  7597
# modify, sequence number =  7609
# modify, sequence number =  7611
# modify, sequence number =  7614
# modify, sequence number =  7632
# modify, sequence number =  7649
# modify, sequence number =  7651
# modify, sequence number =  7653
# modify, sequence number =  7662
# modify, sequence number =  7668
# modify, sequence number =  7679
# modify, sequence number =  7680
# modify, sequence number =  7683
# modify, sequence number =  7690
# modify, sequence number =  7700
# modify, sequence number =  7707
# modify, sequence number =  7720
# modify, sequence number =  7721
# modify, sequence number =  7725
# modify, sequence number =  7743
# modify, sequence number =  7752
# modify, sequence number =  7764
# modify, sequence number =  7765
# modify, sequence number =  7781
# modify, sequence number =  7783
# modify, sequence number =  7784
# modify, sequence number =  7794
# modify, sequence number =  7819
# modify, sequence number =  7840
# modify, sequence number =  7871
# modify, sequence number =  7880
# modify, sequence number =  7895
# modify, sequence number =  7914
# modify, sequence number =  7933
# modify, sequence number =  7949
# modify, sequence number =  7951
# modify, sequence number =  7965
# modify, sequence number =  7966
# modify, sequence number =  7972
# modify, sequence number =  7981
# modify, sequence number =  8032
# modify, sequence number =  8045
# modify, sequence number =  8046
# modify, sequence number =  8057
# modify, sequence number =  8061
# modify, sequence number =  8069
# modify, sequence number =  8071
# modify, sequence number =  8095
# modify, sequence number =  8096
# modify, sequence number =  8110
# modify, sequence number =  8122
# modify, sequence number =  8128
# modify, sequence number =  8135
# modify, sequence number =  8136
# modify, sequence number =  8162
# modify, sequence number =  8163
# modify, sequence number =  8192
# modify, sequence number =  8193
# modify, sequence number =  8198
# modify, sequence number =  8208
# modify, sequence number =  8212
# modify, sequence number =  8215
# modify, sequence number =  8218
# modify, sequence number =  8221
# modify, sequence number =  8267
# modify, sequence number =  8268
# modify, sequence number =  8278
# modify, sequence number =  8286
# modify, sequence number =  8312
# modify, sequence number =  8322
# modify, sequence number =  8325
# modify, sequence number =  8334
# modify, sequence number =  8336
# modify, sequence number =  8370
# modify, sequence number =  8376
# modify, sequence number =  8378
# modify, sequence number =  8390
# modify, sequence number =  8400
# modify, sequence number =  8413
# modify, sequence number =  8423
# modify, sequence number =  8456
# modify, sequence number =  8460
# modify, sequence number =  8465
# modify, sequence number =  8466
# modify, sequence number =  8481
# modify, sequence number =  8482
# modify, sequence number =  8490
# modify, sequence number =  8492
# modify, sequence number =  8493
# modify, sequence number =  8499
# modify, sequence number =  8515
# modify, sequence number =  8518
# modify, sequence number =  8523
# modify, sequence number =  8527
# modify, sequence number =  8530
# modify, sequence number =  8536
# modify, sequence number =  8552
# modify, sequence number =  8566
# modify, sequence number =  8575
# modify, sequence number =  8576
# modify, sequence number =  8588
# modify, sequence number =  8597
# modify, sequence number =  8600
# modify, sequence number =  8606
# modify, sequence number =  8612
# modify, sequence number =  8620
# modify, sequence number =  8627
# modify, sequence number =  8651
# modify, sequence number =  8659
# modify, sequence number =  8675
# modify, sequence number =  8719
# modify, sequence number =  8726
# modify, sequence number =  8727
# modify, sequence number =  8741
# modify, sequence number =  8759
# modify, sequence number =  8770
# modify, sequence number =  8771
# modify, sequence number =  8773
# modify, sequence number =  8792
# modify, sequence number =  8823
# modify, sequence number =  8831
# modify, sequence number =  8875
# modify, sequence number =  8878
# modify, sequence number =  8879
# modify, sequence number =  8896
# modify, sequence number =  8905
# modify, sequence number =  8919
# modify, sequence number =  8920
# modify, sequence number =  8925
# modify, sequence number =  8933
# modify, sequence number =  8935
# modify, sequence number =  8944
# modify, sequence number =  8949
# modify, sequence number =  8952
# modify, sequence number =  8953
# modify, sequence number =  8959
# modify, sequence number =  8964
# modify, sequence number =  8967
# modify, sequence number =  8969
# modify, sequence number =  8973
# modify, sequence number =  8981
# modify, sequence number =  8987
# modify, sequence number =  8996
# modify, sequence number =  9000
# modify, sequence number =  9006
# modify, sequence number =  9018
# modify, sequence number =  9043
# modify, sequence number =  9048
# modify, sequence number =  9049
# modify, sequence number =  9059
# modify, sequence number =  9082
# modify, sequence number =  9091
# modify, sequence number =  9095
# modify, sequence number =  9109
# modify, sequence number =  9133
# modify, sequence number =  9145
# modify, sequence number =  9146
# modify, sequence number =  9158
# modify, sequence number =  9160
# modify, sequence number =  9167
# modify, sequence number =  9171
# modify, sequence number =  9203
# modify, sequence number =  9207
# modify, sequence number =  9219
# modify, sequence number =  9223
# modify, sequence number =  9252
# modify, sequence number =  9280
# modify, sequence number =  9285
# modify, sequence number =  9302
# modify, sequence number =  9310
# modify, sequence number =  9320
# modify, sequence number =  9334
# modify, sequence number =  9335
# modify, sequence number =  9351
# modify, sequence number =  9358
# modify, sequence number =  9376
# modify, sequence number =  9387
# modify, sequence number =  9393
# modify, sequence number =  9394
# modify, sequence number =  9404
# modify, sequence number =  9410
# modify, sequence number =  9413
# modify, sequence number =  9417
# modify, sequence number =  9429
# modify, sequence number =  9430
# modify, sequence number =  9432
# modify, sequence number =  9434
# modify, sequence number =  9439
# modify, sequence number =  9464
# modify, sequence number =  9469
# modify, sequence number =  9488
# modify, sequence number =  9513
# modify, sequence number =  9523
# modify, sequence number =  9524
# modify, sequence number =  9532
# modify, sequence number =  9535
# modify, sequence number =  9537
# modify, sequence number =  9558
# modify, sequence number =  9566
# modify, sequence number =  9574
# modify, sequence number =  9578
# modify, sequence number =  9585
# modify, sequence number =  9608
# modify, sequence number =  9610
# modify, sequence number =  9614
# modify, sequence number =  9621
# modify, sequence number =  9623
# modify, sequence number =  9631
# modify, sequence number =  9681
# modify, sequence number =  9688
# modify, sequence number =  9699
# modify, sequence number =  9722
# modify, sequence number =  9744
# modify, sequence number =  9746
# modify, sequence number =  9759
# modify, sequence number =  9821
# modify, sequence number =  9831
# modify, sequence number =  9843
# modify, sequence number =  9883
# modify, sequence number =  9888
# modify, sequence number =  9893
# modify, sequence number =  9895
# modify, sequence number =  9910
# modify, sequence number =  9916
# modify, sequence number =  9920
# modify, sequence number =  9963
# modify, sequence number =  9986
# modify, sequence number =  9991
# modify, sequence number =  10000
# Sent chunk  10000  of  78012
# modify, sequence number =  10025
# modify, sequence number =  10031
# modify, sequence number =  10048
# modify, sequence number =  10083
# modify, sequence number =  10088
# modify, sequence number =  10095
# modify, sequence number =  10100
# modify, sequence number =  10114
# modify, sequence number =  10136
# modify, sequence number =  10154
# modify, sequence number =  10165
# modify, sequence number =  10170
# modify, sequence number =  10178
# modify, sequence number =  10181
# modify, sequence number =  10189
# modify, sequence number =  10194
# modify, sequence number =  10196
# modify, sequence number =  10208
# modify, sequence number =  10258
# modify, sequence number =  10262
# modify, sequence number =  10294
# modify, sequence number =  10298
# modify, sequence number =  10310
# modify, sequence number =  10316
# modify, sequence number =  10323
# modify, sequence number =  10335
# modify, sequence number =  10337
# modify, sequence number =  10338
# modify, sequence number =  10344
# modify, sequence number =  10351
# modify, sequence number =  10356
# modify, sequence number =  10381
# modify, sequence number =  10407
# modify, sequence number =  10412
# modify, sequence number =  10461
# modify, sequence number =  10462
# modify, sequence number =  10466
# modify, sequence number =  10498
# modify, sequence number =  10510
# modify, sequence number =  10521
# modify, sequence number =  10531
# modify, sequence number =  10536
# modify, sequence number =  10544
# modify, sequence number =  10546
# modify, sequence number =  10557
# modify, sequence number =  10569
# modify, sequence number =  10574
# modify, sequence number =  10595
# modify, sequence number =  10596
# modify, sequence number =  10603
# modify, sequence number =  10608
# modify, sequence number =  10612
# modify, sequence number =  10618
# modify, sequence number =  10630
# modify, sequence number =  10635
# modify, sequence number =  10636
# modify, sequence number =  10661
# modify, sequence number =  10670
# modify, sequence number =  10681
# modify, sequence number =  10684
# modify, sequence number =  10704
# modify, sequence number =  10716
# modify, sequence number =  10733
# modify, sequence number =  10753
# modify, sequence number =  10769
# modify, sequence number =  10775
# modify, sequence number =  10779
# modify, sequence number =  10788
# modify, sequence number =  10789
# modify, sequence number =  10791
# modify, sequence number =  10794
# modify, sequence number =  10806
# modify, sequence number =  10813
# modify, sequence number =  10814
# modify, sequence number =  10818
# modify, sequence number =  10821
# modify, sequence number =  10822
# modify, sequence number =  10823
# modify, sequence number =  10840
# modify, sequence number =  10843
# modify, sequence number =  10865
# modify, sequence number =  10869
# modify, sequence number =  10870
# modify, sequence number =  10885
# modify, sequence number =  10905
# modify, sequence number =  10911
# modify, sequence number =  10929
# modify, sequence number =  10930
# modify, sequence number =  10947
# modify, sequence number =  10956
# modify, sequence number =  10974
# modify, sequence number =  10996
# modify, sequence number =  11000
# modify, sequence number =  11002
# modify, sequence number =  11005
# modify, sequence number =  11015
# modify, sequence number =  11024
# modify, sequence number =  11041
# modify, sequence number =  11051
# modify, sequence number =  11054
# modify, sequence number =  11056
# modify, sequence number =  11064
# modify, sequence number =  11089
# modify, sequence number =  11109
# modify, sequence number =  11116
# modify, sequence number =  11142
# modify, sequence number =  11143
# modify, sequence number =  11147
# modify, sequence number =  11152
# modify, sequence number =  11154
# modify, sequence number =  11170
# modify, sequence number =  11174
# modify, sequence number =  11178
# modify, sequence number =  11180
# modify, sequence number =  11181
# modify, sequence number =  11190
# modify, sequence number =  11192
# modify, sequence number =  11197
# modify, sequence number =  11201
# modify, sequence number =  11204
# modify, sequence number =  11215
# modify, sequence number =  11233
# modify, sequence number =  11242
# modify, sequence number =  11246
# modify, sequence number =  11248
# modify, sequence number =  11267
# modify, sequence number =  11268
# modify, sequence number =  11272
# modify, sequence number =  11279
# modify, sequence number =  11286
# modify, sequence number =  11327
# modify, sequence number =  11329
# modify, sequence number =  11331
# modify, sequence number =  11342
# modify, sequence number =  11344
# modify, sequence number =  11345
# modify, sequence number =  11346
# modify, sequence number =  11358
# modify, sequence number =  11365
# modify, sequence number =  11370
# modify, sequence number =  11372
# modify, sequence number =  11392
# modify, sequence number =  11444
# modify, sequence number =  11475
# modify, sequence number =  11499
# modify, sequence number =  11500
# modify, sequence number =  11502
# modify, sequence number =  11507
# modify, sequence number =  11517
# modify, sequence number =  11530
# modify, sequence number =  11542
# modify, sequence number =  11543
# modify, sequence number =  11561
# modify, sequence number =  11570
# modify, sequence number =  11576
# modify, sequence number =  11580
# modify, sequence number =  11601
# modify, sequence number =  11612
# modify, sequence number =  11621
# modify, sequence number =  11626
# modify, sequence number =  11628
# modify, sequence number =  11677
# modify, sequence number =  11679
# modify, sequence number =  11698
# modify, sequence number =  11715
# modify, sequence number =  11728
# modify, sequence number =  11733
# modify, sequence number =  11753
# modify, sequence number =  11759
# modify, sequence number =  11772
# modify, sequence number =  11777
# modify, sequence number =  11787
# modify, sequence number =  11798
# modify, sequence number =  11799
# modify, sequence number =  11819
# modify, sequence number =  11856
# modify, sequence number =  11873
# modify, sequence number =  11877
# modify, sequence number =  11887
# modify, sequence number =  11909
# modify, sequence number =  11911
# modify, sequence number =  11925
# modify, sequence number =  11942
# modify, sequence number =  11952
# modify, sequence number =  11955
# modify, sequence number =  11993
# modify, sequence number =  11999
# modify, sequence number =  12000
# modify, sequence number =  12021
# modify, sequence number =  12022
# modify, sequence number =  12024
# modify, sequence number =  12039
# modify, sequence number =  12042
# modify, sequence number =  12056
# modify, sequence number =  12079
# modify, sequence number =  12114
# modify, sequence number =  12117
# modify, sequence number =  12127
# modify, sequence number =  12151
# modify, sequence number =  12158
# modify, sequence number =  12161
# modify, sequence number =  12176
# modify, sequence number =  12182
# modify, sequence number =  12190
# modify, sequence number =  12195
# modify, sequence number =  12202
# modify, sequence number =  12214
# modify, sequence number =  12219
# modify, sequence number =  12234
# modify, sequence number =  12239
# modify, sequence number =  12260
# modify, sequence number =  12269
# modify, sequence number =  12272
# modify, sequence number =  12281
# modify, sequence number =  12300
# modify, sequence number =  12304
# modify, sequence number =  12305
# modify, sequence number =  12307
# modify, sequence number =  12310
# modify, sequence number =  12314
# modify, sequence number =  12318
# modify, sequence number =  12319
# modify, sequence number =  12323
# modify, sequence number =  12344
# modify, sequence number =  12346
# modify, sequence number =  12349
# modify, sequence number =  12352
# modify, sequence number =  12355
# modify, sequence number =  12357
# modify, sequence number =  12362
# modify, sequence number =  12367
# modify, sequence number =  12373
# modify, sequence number =  12411
# modify, sequence number =  12430
# modify, sequence number =  12447
# modify, sequence number =  12456
# modify, sequence number =  12466
# modify, sequence number =  12468
# modify, sequence number =  12501
# modify, sequence number =  12517
# modify, sequence number =  12542
# modify, sequence number =  12550
# modify, sequence number =  12551
# modify, sequence number =  12560
# modify, sequence number =  12564
# modify, sequence number =  12571
# modify, sequence number =  12572
# modify, sequence number =  12577
# modify, sequence number =  12599
# modify, sequence number =  12602
# modify, sequence number =  12603
# modify, sequence number =  12625
# modify, sequence number =  12632
# modify, sequence number =  12659
# modify, sequence number =  12662
# modify, sequence number =  12671
# modify, sequence number =  12686
# modify, sequence number =  12698
# modify, sequence number =  12701
# modify, sequence number =  12703
# modify, sequence number =  12717
# modify, sequence number =  12722
# modify, sequence number =  12729
# modify, sequence number =  12730
# modify, sequence number =  12744
# modify, sequence number =  12748
# modify, sequence number =  12756
# modify, sequence number =  12759
# modify, sequence number =  12770
# modify, sequence number =  12775
# modify, sequence number =  12800
# modify, sequence number =  12802
# modify, sequence number =  12803
# modify, sequence number =  12820
# modify, sequence number =  12825
# modify, sequence number =  12828
# modify, sequence number =  12836
# modify, sequence number =  12849
# modify, sequence number =  12850
# modify, sequence number =  12860
# modify, sequence number =  12880
# modify, sequence number =  12881
# modify, sequence number =  12896
# modify, sequence number =  12899
# modify, sequence number =  12906
# modify, sequence number =  12908
# modify, sequence number =  12909
# modify, sequence number =  12913
# modify, sequence number =  12916
# modify, sequence number =  12924
# modify, sequence number =  12930
# modify, sequence number =  12932
# modify, sequence number =  12941
# modify, sequence number =  12946
# modify, sequence number =  12953
# modify, sequence number =  12956
# modify, sequence number =  12959
# modify, sequence number =  12967
# modify, sequence number =  12980
# modify, sequence number =  13001
# modify, sequence number =  13021
# modify, sequence number =  13025
# modify, sequence number =  13030
# modify, sequence number =  13031
# modify, sequence number =  13036
# modify, sequence number =  13037
# modify, sequence number =  13039
# modify, sequence number =  13057
# modify, sequence number =  13067
# modify, sequence number =  13073
# modify, sequence number =  13081
# modify, sequence number =  13091
# modify, sequence number =  13102
# modify, sequence number =  13117
# modify, sequence number =  13133
# modify, sequence number =  13138
# modify, sequence number =  13143
# modify, sequence number =  13149
# modify, sequence number =  13154
# modify, sequence number =  13166
# modify, sequence number =  13168
# modify, sequence number =  13169
# modify, sequence number =  13175
# modify, sequence number =  13194
# modify, sequence number =  13202
# modify, sequence number =  13223
# modify, sequence number =  13227
# modify, sequence number =  13232
# modify, sequence number =  13237
# modify, sequence number =  13239
# modify, sequence number =  13255
# modify, sequence number =  13256
# modify, sequence number =  13271
# modify, sequence number =  13294
# modify, sequence number =  13315
# modify, sequence number =  13339
# modify, sequence number =  13345
# modify, sequence number =  13354
# modify, sequence number =  13368
# modify, sequence number =  13371
# modify, sequence number =  13374
# modify, sequence number =  13389
# modify, sequence number =  13404
# modify, sequence number =  13410
# modify, sequence number =  13418
# modify, sequence number =  13422
# modify, sequence number =  13425
# modify, sequence number =  13431
# modify, sequence number =  13439
# modify, sequence number =  13441
# modify, sequence number =  13451
# modify, sequence number =  13476
# modify, sequence number =  13487
# modify, sequence number =  13493
# modify, sequence number =  13497
# modify, sequence number =  13501
# modify, sequence number =  13503
# modify, sequence number =  13507
# modify, sequence number =  13536
# modify, sequence number =  13555
# modify, sequence number =  13560
# modify, sequence number =  13561
# modify, sequence number =  13568
# modify, sequence number =  13572
# modify, sequence number =  13629
# modify, sequence number =  13664
# modify, sequence number =  13676
# modify, sequence number =  13678
# modify, sequence number =  13681
# modify, sequence number =  13696
# modify, sequence number =  13714
# modify, sequence number =  13728
# modify, sequence number =  13734
# modify, sequence number =  13755
# modify, sequence number =  13771
# modify, sequence number =  13778
# modify, sequence number =  13796
# modify, sequence number =  13799
# modify, sequence number =  13801
# modify, sequence number =  13805
# modify, sequence number =  13806
# modify, sequence number =  13808
# modify, sequence number =  13809
# modify, sequence number =  13830
# modify, sequence number =  13831
# modify, sequence number =  13833
# modify, sequence number =  13837
# modify, sequence number =  13854
# modify, sequence number =  13856
# modify, sequence number =  13872
# modify, sequence number =  13875
# modify, sequence number =  13910
# modify, sequence number =  13915
# modify, sequence number =  13918
# modify, sequence number =  13919
# modify, sequence number =  13923
# modify, sequence number =  13928
# modify, sequence number =  13937
# modify, sequence number =  13945
# modify, sequence number =  13950
# modify, sequence number =  13960
# modify, sequence number =  13976
# modify, sequence number =  13983
# modify, sequence number =  14002
# modify, sequence number =  14003
# modify, sequence number =  14005
# modify, sequence number =  14008
# modify, sequence number =  14029
# modify, sequence number =  14059
# modify, sequence number =  14069
# modify, sequence number =  14073
# modify, sequence number =  14074
# modify, sequence number =  14077
# modify, sequence number =  14090
# modify, sequence number =  14098
# modify, sequence number =  14118
# modify, sequence number =  14128
# modify, sequence number =  14153
# modify, sequence number =  14179
# modify, sequence number =  14189
# modify, sequence number =  14210
# modify, sequence number =  14214
# modify, sequence number =  14217
# modify, sequence number =  14239
# modify, sequence number =  14245
# modify, sequence number =  14253
# modify, sequence number =  14260
# modify, sequence number =  14263
# modify, sequence number =  14277
# modify, sequence number =  14292
# modify, sequence number =  14294
# modify, sequence number =  14311
# modify, sequence number =  14316
# modify, sequence number =  14331
# modify, sequence number =  14361
# modify, sequence number =  14363
# modify, sequence number =  14369
# modify, sequence number =  14385
# modify, sequence number =  14389
# modify, sequence number =  14395
# modify, sequence number =  14396
# modify, sequence number =  14400
# modify, sequence number =  14405
# modify, sequence number =  14429
# modify, sequence number =  14440
# modify, sequence number =  14442
# modify, sequence number =  14444
# modify, sequence number =  14459
# modify, sequence number =  14474
# modify, sequence number =  14488
# modify, sequence number =  14502
# modify, sequence number =  14507
# modify, sequence number =  14522
# modify, sequence number =  14536
# modify, sequence number =  14559
# modify, sequence number =  14562
# modify, sequence number =  14568
# modify, sequence number =  14572
# modify, sequence number =  14594
# modify, sequence number =  14597
# modify, sequence number =  14610
# modify, sequence number =  14617
# modify, sequence number =  14624
# modify, sequence number =  14638
# modify, sequence number =  14640
# modify, sequence number =  14647
# modify, sequence number =  14656
# modify, sequence number =  14669
# modify, sequence number =  14684
# modify, sequence number =  14700
# modify, sequence number =  14712
# modify, sequence number =  14714
# modify, sequence number =  14718
# modify, sequence number =  14731
# modify, sequence number =  14740
# ...
# modify, sequence number =  73279
# modify, sequence number =  73290
# modify, sequence number =  73294
# modify, sequence number =  73303
# modify, sequence number =  73307
# modify, sequence number =  73310
# modify, sequence number =  73318
# modify, sequence number =  73331
# modify, sequence number =  73344
# modify, sequence number =  73371
# modify, sequence number =  73376
# modify, sequence number =  73386
# modify, sequence number =  73408
# modify, sequence number =  73409
# modify, sequence number =  73411
# modify, sequence number =  73420
# modify, sequence number =  73430
# modify, sequence number =  73432
# modify, sequence number =  73436
# modify, sequence number =  73446
# modify, sequence number =  73459
# modify, sequence number =  73460
# modify, sequence number =  73480
# modify, sequence number =  73492
# modify, sequence number =  73494
# modify, sequence number =  73495
# modify, sequence number =  73504
# modify, sequence number =  73548
# modify, sequence number =  73568
# modify, sequence number =  73572
# modify, sequence number =  73580
# modify, sequence number =  73603
# modify, sequence number =  73629
# modify, sequence number =  73632
# modify, sequence number =  73653
# modify, sequence number =  73656
# modify, sequence number =  73663
# modify, sequence number =  73667
# modify, sequence number =  73672
# modify, sequence number =  73676
# modify, sequence number =  73680
# modify, sequence number =  73684
# modify, sequence number =  73691
# modify, sequence number =  73694
# modify, sequence number =  73696
# modify, sequence number =  73698
# modify, sequence number =  73708
# modify, sequence number =  73711
# modify, sequence number =  73715
# modify, sequence number =  73729
# modify, sequence number =  73736
# modify, sequence number =  73749
# modify, sequence number =  73755
# modify, sequence number =  73756
# modify, sequence number =  73763
# modify, sequence number =  73769
# modify, sequence number =  73778
# modify, sequence number =  73783
# modify, sequence number =  73787
# modify, sequence number =  73788
# modify, sequence number =  73792
# modify, sequence number =  73805
# modify, sequence number =  73826
# modify, sequence number =  73859
# modify, sequence number =  73863
# modify, sequence number =  73894
# modify, sequence number =  73907
# modify, sequence number =  73911
# modify, sequence number =  73929
# modify, sequence number =  73932
# modify, sequence number =  73947
# modify, sequence number =  73956
# modify, sequence number =  73963
# modify, sequence number =  73968
# modify, sequence number =  73978
# modify, sequence number =  73979
# modify, sequence number =  73985
# modify, sequence number =  74003
# modify, sequence number =  74010
# modify, sequence number =  74030
# modify, sequence number =  74032
# modify, sequence number =  74050
# modify, sequence number =  74055
# modify, sequence number =  74064
# modify, sequence number =  74065
# modify, sequence number =  74074
# modify, sequence number =  74077
# modify, sequence number =  74088
# modify, sequence number =  74098
# modify, sequence number =  74108
# modify, sequence number =  74116
# modify, sequence number =  74139
# modify, sequence number =  74144
# modify, sequence number =  74174
# modify, sequence number =  74176
# modify, sequence number =  74197
# modify, sequence number =  74208
# modify, sequence number =  74210
# modify, sequence number =  74237
# modify, sequence number =  74238
# modify, sequence number =  74242
# modify, sequence number =  74249
# modify, sequence number =  74252
# modify, sequence number =  74255
# modify, sequence number =  74260
# modify, sequence number =  74264
# modify, sequence number =  74269
# modify, sequence number =  74285
# modify, sequence number =  74286
# modify, sequence number =  74292
# modify, sequence number =  74296
# modify, sequence number =  74321
# modify, sequence number =  74326
# modify, sequence number =  74332
# modify, sequence number =  74334
# modify, sequence number =  74344
# modify, sequence number =  74350
# modify, sequence number =  74351
# modify, sequence number =  74371
# modify, sequence number =  74372
# modify, sequence number =  74376
# modify, sequence number =  74409
# modify, sequence number =  74412
# modify, sequence number =  74417
# modify, sequence number =  74426
# modify, sequence number =  74429
# modify, sequence number =  74439
# modify, sequence number =  74442
# modify, sequence number =  74465
# modify, sequence number =  74466
# modify, sequence number =  74485
# modify, sequence number =  74499
# modify, sequence number =  74507
# modify, sequence number =  74515
# modify, sequence number =  74516
# modify, sequence number =  74521
# modify, sequence number =  74533
# modify, sequence number =  74541
# modify, sequence number =  74542
# modify, sequence number =  74543
# modify, sequence number =  74551
# modify, sequence number =  74554
# modify, sequence number =  74568
# modify, sequence number =  74575
# modify, sequence number =  74588
# modify, sequence number =  74590
# modify, sequence number =  74600
# modify, sequence number =  74608
# modify, sequence number =  74621
# modify, sequence number =  74642
# modify, sequence number =  74651
# modify, sequence number =  74666
# modify, sequence number =  74667
# modify, sequence number =  74668
# modify, sequence number =  74670
# modify, sequence number =  74704
# modify, sequence number =  74723
# modify, sequence number =  74731
# modify, sequence number =  74736
# modify, sequence number =  74738
# modify, sequence number =  74747
# modify, sequence number =  74756
# modify, sequence number =  74758
# modify, sequence number =  74780
# modify, sequence number =  74781
# modify, sequence number =  74789
# modify, sequence number =  74798
# modify, sequence number =  74812
# modify, sequence number =  74830
# modify, sequence number =  74832
# modify, sequence number =  74833
# modify, sequence number =  74885
# modify, sequence number =  74889
# modify, sequence number =  74895
# modify, sequence number =  74901
# modify, sequence number =  74915
# modify, sequence number =  74923
# modify, sequence number =  74925
# modify, sequence number =  74926
# modify, sequence number =  74932
# modify, sequence number =  74937
# modify, sequence number =  74942
# modify, sequence number =  74947
# modify, sequence number =  74951
# modify, sequence number =  74958
# modify, sequence number =  74966
# modify, sequence number =  74981
# modify, sequence number =  74984
# modify, sequence number =  74985
# modify, sequence number =  74986
# modify, sequence number =  74992
# modify, sequence number =  75007
# modify, sequence number =  75022
# modify, sequence number =  75041
# modify, sequence number =  75051
# modify, sequence number =  75066
# modify, sequence number =  75072
# modify, sequence number =  75082
# modify, sequence number =  75110
# modify, sequence number =  75117
# modify, sequence number =  75118
# modify, sequence number =  75119
# modify, sequence number =  75124
# modify, sequence number =  75135
# modify, sequence number =  75139
# modify, sequence number =  75146
# modify, sequence number =  75148
# modify, sequence number =  75170
# modify, sequence number =  75181
# modify, sequence number =  75187
# modify, sequence number =  75205
# modify, sequence number =  75232
# modify, sequence number =  75254
# modify, sequence number =  75255
# modify, sequence number =  75270
# modify, sequence number =  75273
# modify, sequence number =  75281
# modify, sequence number =  75284
# modify, sequence number =  75314
# modify, sequence number =  75324
# modify, sequence number =  75326
# modify, sequence number =  75334
# modify, sequence number =  75347
# modify, sequence number =  75350
# modify, sequence number =  75371
# modify, sequence number =  75392
# modify, sequence number =  75436
# modify, sequence number =  75450
# modify, sequence number =  75455
# modify, sequence number =  75463
# modify, sequence number =  75469
# modify, sequence number =  75485
# modify, sequence number =  75538
# modify, sequence number =  75540
# modify, sequence number =  75549
# modify, sequence number =  75561
# modify, sequence number =  75602
# modify, sequence number =  75603
# modify, sequence number =  75607
# modify, sequence number =  75608
# modify, sequence number =  75623
# modify, sequence number =  75634
# modify, sequence number =  75643
# modify, sequence number =  75648
# modify, sequence number =  75682
# modify, sequence number =  75684
# modify, sequence number =  75690
# modify, sequence number =  75691
# modify, sequence number =  75692
# modify, sequence number =  75719
# modify, sequence number =  75723
# modify, sequence number =  75724
# modify, sequence number =  75732
# modify, sequence number =  75756
# modify, sequence number =  75765
# modify, sequence number =  75767
# modify, sequence number =  75781
# modify, sequence number =  75782
# modify, sequence number =  75783
# modify, sequence number =  75789
# modify, sequence number =  75790
# modify, sequence number =  75809
# modify, sequence number =  75817
# modify, sequence number =  75829
# modify, sequence number =  75848
# modify, sequence number =  75864
# modify, sequence number =  75866
# modify, sequence number =  75873
# modify, sequence number =  75896
# modify, sequence number =  75902
# modify, sequence number =  75907
# modify, sequence number =  75910
# modify, sequence number =  75918
# modify, sequence number =  75926
# modify, sequence number =  75935
# modify, sequence number =  75943
# modify, sequence number =  75956
# modify, sequence number =  75963
# modify, sequence number =  75981
# modify, sequence number =  76017
# modify, sequence number =  76020
# modify, sequence number =  76031
# modify, sequence number =  76032
# modify, sequence number =  76035
# modify, sequence number =  76040
# modify, sequence number =  76046
# modify, sequence number =  76050
# modify, sequence number =  76057
# modify, sequence number =  76058
# modify, sequence number =  76081
# modify, sequence number =  76082
# modify, sequence number =  76095
# modify, sequence number =  76096
# modify, sequence number =  76108
# modify, sequence number =  76109
# modify, sequence number =  76113
# modify, sequence number =  76137
# modify, sequence number =  76151
# modify, sequence number =  76161
# modify, sequence number =  76171
# modify, sequence number =  76177
# modify, sequence number =  76182
# modify, sequence number =  76205
# modify, sequence number =  76223
# modify, sequence number =  76234
# modify, sequence number =  76246
# modify, sequence number =  76256
# modify, sequence number =  76257
# modify, sequence number =  76271
# modify, sequence number =  76279
# modify, sequence number =  76286
# modify, sequence number =  76289
# modify, sequence number =  76292
# modify, sequence number =  76296
# modify, sequence number =  76306
# modify, sequence number =  76312
# modify, sequence number =  76313
# modify, sequence number =  76314
# modify, sequence number =  76316
# modify, sequence number =  76323
# modify, sequence number =  76327
# modify, sequence number =  76337
# modify, sequence number =  76342
# modify, sequence number =  76374
# modify, sequence number =  76393
# modify, sequence number =  76395
# modify, sequence number =  76396
# modify, sequence number =  76402
# modify, sequence number =  76403
# modify, sequence number =  76410
# modify, sequence number =  76416
# modify, sequence number =  76429
# modify, sequence number =  76433
# modify, sequence number =  76446
# modify, sequence number =  76447
# modify, sequence number =  76449
# modify, sequence number =  76453
# modify, sequence number =  76475
# modify, sequence number =  76482
# modify, sequence number =  76498
# modify, sequence number =  76508
# modify, sequence number =  76525
# modify, sequence number =  76549
# modify, sequence number =  76565
# modify, sequence number =  76573
# modify, sequence number =  76602
# modify, sequence number =  76609
# modify, sequence number =  76612
# modify, sequence number =  76618
# modify, sequence number =  76629
# modify, sequence number =  76632
# modify, sequence number =  76633
# modify, sequence number =  76638
# modify, sequence number =  76645
# modify, sequence number =  76649
# modify, sequence number =  76656
# modify, sequence number =  76659
# modify, sequence number =  76673
# modify, sequence number =  76676
# modify, sequence number =  76680
# modify, sequence number =  76685
# modify, sequence number =  76686
# modify, sequence number =  76706
# modify, sequence number =  76712
# modify, sequence number =  76744
# modify, sequence number =  76756
# modify, sequence number =  76767
# modify, sequence number =  76771
# modify, sequence number =  76812
# modify, sequence number =  76840
# modify, sequence number =  76846
# modify, sequence number =  76850
# modify, sequence number =  76865
# modify, sequence number =  76868
# modify, sequence number =  76871
# modify, sequence number =  76881
# modify, sequence number =  76882
# modify, sequence number =  76888
# modify, sequence number =  76899
# modify, sequence number =  76901
# modify, sequence number =  76913
# modify, sequence number =  76921
# modify, sequence number =  76930
# modify, sequence number =  76937
# modify, sequence number =  76938
# modify, sequence number =  76946
# modify, sequence number =  76969
# modify, sequence number =  76973
# modify, sequence number =  76985
# modify, sequence number =  77004
# modify, sequence number =  77005
# modify, sequence number =  77013
# modify, sequence number =  77024
# modify, sequence number =  77025
# modify, sequence number =  77031
# modify, sequence number =  77043
# modify, sequence number =  77044
# modify, sequence number =  77093
# modify, sequence number =  77096
# modify, sequence number =  77106
# modify, sequence number =  77112
# modify, sequence number =  77119
# modify, sequence number =  77132
# modify, sequence number =  77145
# modify, sequence number =  77165
# modify, sequence number =  77168
# modify, sequence number =  77169
# modify, sequence number =  77171
# modify, sequence number =  77179
# modify, sequence number =  77180
# modify, sequence number =  77195
# modify, sequence number =  77204
# modify, sequence number =  77250
# modify, sequence number =  77254
# modify, sequence number =  77267
# modify, sequence number =  77282
# modify, sequence number =  77291
# modify, sequence number =  77306
# modify, sequence number =  77316
# modify, sequence number =  77317
# modify, sequence number =  77326
# modify, sequence number =  77340
# modify, sequence number =  77344
# modify, sequence number =  77347
# modify, sequence number =  77351
# modify, sequence number =  77354
# modify, sequence number =  77360
# modify, sequence number =  77382
# modify, sequence number =  77387
# modify, sequence number =  77388
# modify, sequence number =  77391
# modify, sequence number =  77410
# modify, sequence number =  77420
# modify, sequence number =  77421
# modify, sequence number =  77443
# modify, sequence number =  77451
# modify, sequence number =  77469
# modify, sequence number =  77474
# modify, sequence number =  77477
# modify, sequence number =  77496
# modify, sequence number =  77497
# modify, sequence number =  77503
# modify, sequence number =  77509
# modify, sequence number =  77550
# modify, sequence number =  77552
# modify, sequence number =  77556
# modify, sequence number =  77561
# modify, sequence number =  77565
# modify, sequence number =  77578
# modify, sequence number =  77586
# modify, sequence number =  77604
# modify, sequence number =  77605
# modify, sequence number =  77606
# modify, sequence number =  77618
# modify, sequence number =  77625
# modify, sequence number =  77631
# modify, sequence number =  77637
# modify, sequence number =  77645
# modify, sequence number =  77668
# modify, sequence number =  77676
# modify, sequence number =  77681
# modify, sequence number =  77685
# modify, sequence number =  77696
# modify, sequence number =  77724
# modify, sequence number =  77772
# modify, sequence number =  77790
# modify, sequence number =  77799
# modify, sequence number =  77809
# modify, sequence number =  77813
# modify, sequence number =  77822
# modify, sequence number =  77829
# modify, sequence number =  77832
# modify, sequence number =  77834
# modify, sequence number =  77845
# modify, sequence number =  77862
# modify, sequence number =  77871
# modify, sequence number =  77874
# modify, sequence number =  77895
# modify, sequence number =  77899
# modify, sequence number =  77900
# modify, sequence number =  77945
# modify, sequence number =  77955
# modify, sequence number =  77971
# modify, sequence number =  77999
# Image sent
# 78012

# %%
groups = divide_image_into_pixel_groups("output.png", group_pixel_count=30)
# combine the groups into a single image

len(groups)
# Out:
# 78012

# %%
# groups[0] = Image.fromarray(np.zeros(np.array(groups[1]).shape, dtype=np.uint8))
# groups[0]
np.array(groups[1]).shape
# Out:
# (6, 5, 3)

# %%
import hmac

len(hmac.new(b'key', b'message', 'sha384').digest())
# Out:
# 48
