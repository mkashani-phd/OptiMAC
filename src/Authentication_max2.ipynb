# %% [markdown]
# # Original Objective function
# $$
# E(A_{i}) = \sum_{j \in \{1, \ldots, n\}}^{\text{tag}} k_{ij} q_j \prod_{i' \in \{1, \ldots, m\}}^{\text{msg}} \left( k_{i'j} p_{i'} + 0^{k_{i'j}} \right)
# $$

# %% [markdown]
# ### Simplification assumption
# We assume probobility of recieving a tag $q_{j}$ is equal to probobility of recieving message $p_{i}$
# $$q_{j} = p_{i} = p$$

# %% [markdown]
# ### C1 : Using all tags
# Each tag must verify at least one message
# $$
# \sum_{i=1}^{m} k_{ij} \geq 1 \quad \text{for each } j \in \{1, 2, \ldots, \text{|T|}\}
# $$
# ### C2: Using all messages
# Each message must be signed with at least one tag
# $$
# \sum_{j=1}^{n} k_{ij} \geq 1 \quad \text{for each } i \in \{1, 2, \ldots, \text{|M|}\}
# $$

# %% [markdown]
# ### C3: Define auxiliary varible for number of messages each tag signs
# we define number of messages that each tag signs as an auxiliray variable to use later in transforming objective function to a linear model
# $$
# z_j = \sum_{i=1}^{n} k_{ij} \quad \text{for each } j \in \{1, 2, \ldots, \text{tags}\}
# $$
# $$
# z_j \geq 1 \quad \text{for each } j \in \{1, 2, \ldots, \text{tags}\}
# $$

# %% [markdown]
# ### C4: Re-writing the product part in linear
# After simplifying all probobilities to be equal the product part could be linearized using some auxiliary variable and constraints as follow:
#
# $$
# \prod_{i' \in \{1, \ldots, m\}}^{\text{msg}} \left( k_{i'j} p_{i'} + 0^{k_{i'j}} \right) =  \sum_{i' \in \{1, \ldots, m\}}^{\text{msg}} w_{ji'} p^{i'}
# $$
#
#
# Now the next constraint should be define to force the correcponding $w_{ji'} = 1$ which can be done as follow

# %% [markdown]
# 1. **Link $ z[j] $ and $ y[j,i] $ using big-M constraints:**
#
# $$
# z[j] - i \leq M(1 - y[j,i])
# $$
#
# $$
# i - z[j] \leq M(1 - y[j,i])
# $$
#
# 2. **Ensure $ y[j,i] $ selects only one $ i $:**
#
# $$
# \sum_{i} y[j,i] = 1
# $$
#
# 3. **Link $ w[j,i] $ to $ y[j,i] $:**
#
# $$
# w[j,i] \leq y[j,i]
# $$
#
# $$
# w[j,i] \geq y[j,i] - (1 - y[j,i])
# $$
#
# $$
# \sum_{i} w[j,i] = 1
# $$

# %% [markdown]
# The final part is linearizing the product of the two binary variables $k_{ij}w_{j}$ which could be done this way:
#
# $$x_{mij} \leq k_{ij} $$
# $$x_{mij} \leq w_{ji'} $$
# $$x_{mij} \geq k_{ij} + w_{ji'} -1 $$
# $$x_{mij}\in \{0,1\}$$

# %% [markdown]
# ## Simplified Objective function
# With linearizing product part, the objective function could be rewritten as:
#
# $$
# E(A_{i}) = \sum_{j \in \{1, \ldots, n\}}^{\text{tag}} k_{ij} p \text{ } * y_{j}
# $$

# %%
import numpy as np
import pandas as pd
from pulp import *

# %%
def max_expected_A(n_tags, m_msgs, p):
   
    # Create a PuLP problem with maximization
    prob = LpProblem("Maximize_Expected_A", LpMaximize)

    # Define the binary variables k indexed by (i, j)
    k = {(i, j): LpVariable(f'k_{i}_{j}', cat='Binary') for i in range(1, m_msgs+1) for j in range(1, n_tags+1)}

    # Define the binary variables w indexed by (j,i)
    w = {(j, i): LpVariable(f'w_{j}_{i}', cat='Binary') for j in range(1, n_tags+1) for i in range(1, m_msgs+1)}

    # Define the binary variables x indexed by (i, j)
    x = {(i, j, m): LpVariable(f'x_{i}_{j}_{m}', cat='Binary') for i in range(1, m_msgs+1) for j in range(1, n_tags+1) for m in range(1, m_msgs+1)}

    # Define the binary variables y indexed by j
    y = {(j, i): LpVariable(f'y_{j}_{i}', cat='Binary') for j in range(1, n_tags+1) for i in range(1, m_msgs+1)}

    # Define the continuous variables z indexed by j
    z = {j: LpVariable(f'z_{j}', cat='Integer', lowBound=0) for j in range(1, n_tags+1)}

    # Constraints
    # for j in range(1, n_tags+1):
    #     prob += lpSum(k[i, j] for i in range(1, m_msgs+1)) >= 1, f"Tag_{j}_constraint"

    # for i in range(1, m_msgs+1):
    #     prob += lpSum(k[i, j] for j in range(1, n_tags+1)) >= 1, f"Message_{i}_constraint"

    for j in range(1, n_tags+1):
        prob += z[j] == lpSum(k[i, j] for i in range(1, m_msgs+1)), f"Z_{j}_definition"
        #prob += z[j] >= 1, f"Z_{j}_non_zero"
        
    for j in range(1, n_tags+1):
        prob += lpSum(w[j, i] for i in range(1, m_msgs+1)) == 1, f"Sum_w_{j}_equals_1"

    for j in range(1, n_tags+1):
        for i in range(1, m_msgs+1):
            prob += z[j] - i <= M * (1 - y[j,i]), f"BigM_1_{j}_{i}"
            prob += i - z[j] <= M * (1 - y[j,i]), f"BigM_2_{j}_{i}"

    for j in range(1, n_tags+1):
        prob += lpSum(y[j, i] for i in range(1, m_msgs+1)) == 1, f"y_{j}_{i}_equals_one"
    
    for j in range(1, n_tags+1):
        prob += lpSum(w[j, i] for i in range(1, m_msgs+1)) == 1, f"w_{j}_{i}_equals_one"

    for j in range(1, n_tags+1):
        for i in range(1, m_msgs+1):
            prob += w[j, i]  <= y[j, i] , f"w_{j}_{i}_less_y_{j}_{i}"

    for j in range(1, n_tags+1):
        for i in range(1, m_msgs+1):
            prob += w[j,i] >= y[j, i] - (1 - y[j,i])  , f"y_{j}_{i}_w_{j}_{i}"


    for i in range(1, m_msgs+1):
        for j in range(1, n_tags+1):
            for m in range(1, m_msgs+1):
                prob += x[i,j, m] <= k[i, j], f"x_{i}_{j}_{m}_leq_k_{i}_{j}"
                prob += x[i,j, m] <= w[j,m], f"x_{i}_{j}_{m}_leq_w_{j}_{m}"
                prob += x[i,j, m] >= k[i, j] + w[j,m] - 1, f"x_{i}_{j}_{m}_geq_k_{i}_{j}_plus_w_{j}_{m}_minus_1"


    # Objective Function
    #prob += lpSum(x[i, j] * P[j+1] for i in range(1, m_msgs+1) for j in range(1, n_tags+1)), "Maximize_E_A"
    prob += lpSum(x[i,j,m]*P[m+1] for i in range(1, m_msgs+1) for j in range(1, n_tags+1)for m in range(1, m_msgs+1)), "Maximize_E_A"

    # Solve the problem
    #solver = pulp.PULP_CBC_CMD(timeLimit=120)
    #prob.solve(solver)
    prob.solve()

    # Extract the optimal values of k_{ij}
    k_values = np.zeros((m_msgs, n_tags), dtype=int)
    for i in range(1, m_msgs+1):
        for j in range(1, n_tags+1):
            k_values[i-1, j-1] = value(k[i, j])


    k_df = pd.DataFrame(k_values, columns=[f'k_{j}' for j in range(1, n_tags+1)], index=[f'Msg_{i}' for i in range(1, m_msgs+1)])
    k_df.columns = [f't{i}' for i in range(1,n_tags+1)]
    k_df.index = [f'm{i}' for i in range(1,m_msgs+1)]


    sum_row = k_df.sum()
    k_df.loc['Sum'] = sum_row


    # Print the variable values
    for v in prob.variables():
        print(f"{v.name} = {v.varValue}")

    # Print the objective value
    print(f"Objective value: {value(prob.objective)}")


    return k_df

# %%
n_tags = 6
n_msgs = 8
p = 0.7
P = {i: p**i for i in range(1, n_msgs+2)}  # p^i coefficients
M = 1000     # A sufficiently large number for the constraints

# %%
max_expected_A(n_tags, n_msgs, p)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/jv/12n64fl91y1d9jr6561fpx2c0000gn/T/6e77f5e89b634543be3a58dd1f5f68f3-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/jv/12n64fl91y1d9jr6561fpx2c0000gn/T/6e77f5e89b634543be3a58dd1f5f68f3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1373 COLUMNS
# At line 6096 RHS
# At line 7465 BOUNDS
# At line 8000 ENDATA
# Problem MODEL has 1368 rows, 534 columns and 3270 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 23.471 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 378 strengthened rows, 192 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 715 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 715 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 705 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 640 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 593 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 503 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 406 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 267 strengthened rows, 0 substitutions
# Cgl0004I processed model has 970 rows, 438 columns (438 integer (432 of which binary)) and 6294 elements
# Cbc0038I Initial state - 147 integers unsatisfied sum - 11.5898
# Cbc0038I Pass   1: suminf.    0.33789 (98) obj. -11.812 iterations 457
# Cbc0038I Pass   2: suminf.    0.13522 (43) obj. -5.993 iterations 195
# Cbc0038I Pass   3: suminf.    0.13522 (43) obj. -5.993 iterations 21
# Cbc0038I Pass   4: suminf.    2.04713 (35) obj. -2.9653 iterations 90
# Cbc0038I Pass   5: suminf.    1.44713 (28) obj. -2.9653 iterations 15
# Cbc0038I Pass   6: suminf.    1.33285 (30) obj. -2.9653 iterations 2
# Cbc0038I Pass   7: suminf.    0.01000 (2) obj. -1.61414 iterations 60
# Cbc0038I Pass   8: suminf.    0.01000 (2) obj. -1.61414 iterations 8
# Cbc0038I Pass   9: suminf.    0.01200 (2) obj. -1.61414 iterations 3
# Cbc0038I Pass  10: suminf.    0.00200 (2) obj. -1.61414 iterations 1
# Cbc0038I Pass  11: suminf.   11.41198 (71) obj. -1.73203 iterations 168
# Cbc0038I Pass  12: suminf.    6.01044 (60) obj. -1.15837 iterations 132
# Cbc0038I Pass  13: suminf.    3.68910 (37) obj. -1.15837 iterations 49
# Cbc0038I Pass  14: suminf.    3.30815 (42) obj. -1.15837 iterations 12
# Cbc0038I Pass  15: suminf.    1.43444 (30) obj. -1.15837 iterations 21
# Cbc0038I Pass  16: suminf.    1.32015 (32) obj. -1.15837 iterations 4
# Cbc0038I Pass  17: suminf.    0.03044 (25) obj. -1.15837 iterations 13
# Cbc0038I Pass  18: suminf.    0.03044 (25) obj. -1.15837 iterations 2
# Cbc0038I Pass  19: suminf.    2.02800 (20) obj. -0.812829 iterations 24
# Cbc0038I Pass  20: suminf.    2.02800 (20) obj. -0.812829 iterations 3
# Cbc0038I Pass  21: suminf.    0.02001 (8) obj. -0.812829 iterations 33
# Cbc0038I Pass  22: suminf.    0.02000 (8) obj. -0.812829 iterations 2
# Cbc0038I Pass  23: suminf.    0.04203 (8) obj. -0.812829 iterations 5
# Cbc0038I Pass  24: suminf.    0.02400 (8) obj. -0.812829 iterations 3
# Cbc0038I Pass  25: suminf.    7.21244 (47) obj. -2.24547 iterations 120
# Cbc0038I Pass  26: suminf.    3.88263 (45) obj. -1.77567 iterations 121
# Cbc0038I Pass  27: suminf.    2.06749 (32) obj. -1.77567 iterations 32
# Cbc0038I Pass  28: suminf.    1.89663 (34) obj. -1.77567 iterations 12
# Cbc0038I Pass  29: suminf.    1.60424 (23) obj. -1.61162 iterations 21
# Cbc0038I Pass  30: suminf.    1.60424 (23) obj. -1.61162 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 198 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 970 rows 438 columns, reduced to 699 rows 240 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.32 seconds)
# Cbc0038I After 0.32 seconds - Feasibility pump exiting - took 0.04 seconds
# Cbc0031I 48 added rows had average density of 65.3125
# Cbc0013I At root node, 48 cuts changed objective from -12.501589 to -6.8602817 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 317 row cuts average 7.1 elements, 0 column cuts (0 active)  in 0.288 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 4914 row cuts average 71.5 elements, 0 column cuts (0 active)  in 0.204 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 3 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.076 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.090 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 13 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.048 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 733 row cuts average 56.9 elements, 0 column cuts (0 active)  in 0.128 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible -6.8602817 (2.12 seconds)
# Cbc0012I Integer solution of -4.116 found by DiveCoefficient after 23141 iterations and 1 nodes (2.29 seconds)
# Cbc0038I Full problem 970 rows 438 columns, reduced to 529 rows 197 columns - too large
# Cbc0012I Integer solution of -4.1503 found by DiveCoefficient after 23195 iterations and 3 nodes (2.45 seconds)
# Cbc0012I Integer solution of -4.1846 found by DiveCoefficient after 23236 iterations and 4 nodes (2.49 seconds)
# Cbc0004I Integer solution of -4.20518 found after 23966 iterations and 26 nodes (3.20 seconds)
# Cbc0016I Integer solution of -4.23948 found by strong branching after 24022 iterations and 27 nodes (3.21 seconds)
# Cbc0038I Full problem 970 rows 438 columns, reduced to 112 rows 44 columns
# Cbc0004I Integer solution of -4.2532 found after 26496 iterations and 90 nodes (3.65 seconds)
# Cbc0038I Full problem 970 rows 438 columns, reduced to 118 rows 46 columns
# Cbc0004I Integer solution of -4.2875 found after 27808 iterations and 126 nodes (3.85 seconds)
# Cbc0004I Integer solution of -4.3218 found after 32716 iterations and 286 nodes (4.32 seconds)
# Cbc0038I Full problem 970 rows 438 columns, reduced to 115 rows 45 columns
# Cbc0038I Full problem 970 rows 438 columns, reduced to 144 rows 54 columns
# Cbc0038I Full problem 970 rows 438 columns, reduced to 113 rows 46 columns
# Cbc0038I Full problem 970 rows 438 columns, reduced to 123 rows 45 columns
# Cbc0038I Full problem 970 rows 438 columns, reduced to 98 rows 37 columns
# Cbc0010I After 1000 nodes, 114 on tree, -4.3218 best solution, best possible -6.8602817 (6.36 seconds)
# Cbc0038I Full problem 970 rows 438 columns, reduced to 290 rows 120 columns
# Cbc0038I Full problem 970 rows 438 columns, reduced to 200 rows 80 columns
# Cbc0038I Full problem 970 rows 438 columns, reduced to 289 rows 116 columns
# Cbc0010I After 2000 nodes, 134 on tree, -4.3218 best solution, best possible -6.8602817 (10.53 seconds)
# Cbc0038I Full problem 970 rows 438 columns, reduced to 197 rows 79 columns
# Cbc0010I After 3000 nodes, 131 on tree, -4.3218 best solution, best possible -6.8602817 (12.89 seconds)
# Cbc0038I Full problem 970 rows 438 columns, reduced to 121 rows 48 columns
# Cbc0010I After 4000 nodes, 132 on tree, -4.3218 best solution, best possible -6.8602817 (15.23 seconds)
# Cbc0038I Full problem 970 rows 438 columns, reduced to 184 rows 68 columns
# Cbc0010I After 5000 nodes, 133 on tree, -4.3218 best solution, best possible -6.8602817 (17.30 seconds)
# Cbc0038I Full problem 970 rows 438 columns, reduced to
seconds)
# Cbc0038I Full problem 970 rows 438 columns, reduced to 253 rows 95 columns
# Cbc0010I After 29000 nodes, 2798 on tree, -4.3218 best solution, best possible -4.4461935 (100.66 seconds)
# Cbc0010I After 30000 nodes, 2554 on tree, -4.3218 best solution, best possible -4.4461935 (102.47 seconds)
# Cbc0010I After 31000 nodes, 2407 on tree, -4.3218 best solution, best possible -4.4309985 (104.52 seconds)
# Cbc0010I After 32000 nodes, 2266 on tree, -4.3218 best solution, best possible -4.4185698 (106.59 seconds)
# Cbc0038I Full problem 970 rows 438 columns, reduced to 237 rows 91 columns
# Cbc0010I After 33000 nodes, 2114 on tree, -4.3218 best solution, best possible -4.4067571 (108.94 seconds)
# Cbc0010I After 34000 nodes, 1804 on tree, -4.3218 best solution, best possible -4.4067571 (110.90 seconds)
# Cbc0010I After 35000 nodes, 1561 on tree, -4.3218 best solution, best possible -4.3885586 (112.81 seconds)
# Cbc0010I After 36000 nodes, 1433 on tree, -4.3218 best solution, best possible -4.376991 (114.80 seconds)
# Cbc0010I After 37000 nodes, 1164 on tree, -4.3218 best solution, best possible -4.3633618 (116.81 seconds)
# Cbc0010I After 38000 nodes, 703 on tree, -4.3218 best solution, best possible -4.3633618 (118.59 seconds)
# Cbc0010I After 39000 nodes, 414 on tree, -4.3218 best solution, best possible -4.3409557 (120.74 seconds)
# Cbc0001I Search completed - best objective -4.3218, took 1500816 iterations and 39932 nodes (122.18 seconds)
# Cbc0032I Strong branching done 78680 times (1500784 iterations), fathomed 2517 nodes and fixed 7377 variables
# Cbc0035I Maximum depth 42, 54816 variables fixed on reduced cost
# Cuts at root node changed objective from -12.5016 to -6.86028
# Probing was tried 29304 times and created 72896 cuts of which 0 were active after adding rounds of cuts (6.489 seconds)
# Gomory was tried 28936 times and created 5312 cuts of which 0 were active after adding rounds of cuts (9.272 seconds)
# Knapsack was tried 100 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.076 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.090 seconds)
# FlowCover was tried 100 times and created 13 cuts of which 0 were active after adding rounds of cuts (0.048 seconds)
# TwoMirCuts was tried 28936 times and created 1478 cuts of which 0 were active after adding rounds of cuts (14.043 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.32180000
# Enumerated nodes:               39932
# Total iterations:               1500816
# Time (CPU seconds):             121.28
# Time (Wallclock seconds):       122.21
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       121.28   (Wallclock seconds):       122.22
#
# k_1_1 = 1.0
# k_1_2 = 0.0
# k_1_3 = 1.0
# k_1_4 = 0.0
# k_1_5 = 1.0
# k_1_6 = 1.0
# k_2_1 = 0.0
# k_2_2 = 0.0
# k_2_3 = 0.0
# k_2_4 = 0.0
# k_2_5 = 1.0
# k_2_6 = 1.0
# k_3_1 = 1.0
# k_3_2 = 0.0
# k_3_3 = 0.0
# k_3_4 = 1.0
# k_3_5 = 0.0
# k_3_6 = 0.0
# k_4_1 = 0.0
# k_4_2 = 1.0
# k_4_3 = 0.0
# k_4_4 = 0.0
# k_4_5 = 0.0
# k_4_6 = 0.0
# k_5_1 = 0.0
# k_5_2 = 0.0
# k_5_3 = 0.0
# k_5_4 = 1.0
# k_5_5 = 0.0
# k_5_6 = 0.0
# k_6_1 = 0.0
# k_6_2 = 1.0
# k_6_3 = 0.0
# k_6_4 = 1.0
# k_6_5 = 0.0
# k_6_6 = 0.0
# k_7_1 = 0.0
# k_7_2 = 0.0
# k_7_3 = 1.0
# k_7_4 = 0.0
# k_7_5 = 1.0
# k_7_6 = 0.0
# x_8_2_4 = 0.0
# x_8_2_5 = 0.0
# x_8_2_6 = 0.0
# x_8_2_7 = 0.0
# x_8_2_8 = 0.0
# x_8_3_1 = 0.0
# x_8_3_2 = 0.0
# x_8_3_3 = 1.0
# x_8_3_4 = 0.0
# x_8_3_5 = 0.0
# x_8_3_6 = 0.0
# x_8_3_7 = 0.0
# x_8_3_8 = 0.0
# x_8_4_1 = 0.0
# x_8_4_2 = 0.0
# x_8_4_3 = 0.0
# x_8_4_4 = 0.0
# x_8_4_5 = 0.0
# x_8_4_6 = 0.0
# x_8_4_7 = 0.0
# x_8_4_8 = 0.0
# x_8_5_1 = 0.0
# x_8_5_2 = 0.0
# x_8_5_3 = 0.0
# x_8_5_4 = 0.0
# x_8_5_5 = 0.0
# x_8_5_6 = 0.0
# x_8_5_7 = 0.0
# x_8_5_8 = 0.0
# x_8_6_1 = 0.0
# x_8_6_2 = 0.0
# x_8_6_3 = 1.0
# x_8_6_4 = 0.0
# x_8_6_5 = 0.0
# x_8_6_6 = 0.0
# x_8_6_7 = 0.0
# x_8_6_8 = 0.0
# y_1_1 = 0.0
# y_1_2 = 0.0
# y_1_3 = 1.0
# y_1_4 = 0.0
# y_1_5 = 0.0
# y_1_6 = 0.0
# y_1_7 = 0.0
# y_1_8 = 0.0
# y_2_1 = 0.0
# y_2_2 = 0.0
# y_2_3 = 1.0
# y_2_4 = 0.0
# y_2_5 = 0.0
# y_2_6 = 0.0
# y_2_7 = 0.0
# y_2_8 = 0.0
# y_3_1 = 0.0
# y_3_2 = 0.0
# y_3_3 = 1.0
# y_3_4 = 0.0
# y_3_5 = 0.0
# y_3_6 = 0.0
# y_3_7 = 0.0
# y_3_8 = 0.0
# y_4_1 = 0.0
# y_4_2 = 0.0
# y_4_3 = 1.0
# y_4_4 = 0.0
# y_4_5 = 0.0
# y_4_6 = 0.0
# y_4_7 = 0.0
# y_4_8 = 0.0
# y_5_1 = 0.0
# y_5_2 = 0.0
# y_5_3 = 1.0
# y_5_4 = 0.0
# y_5_5 = 0.0
# y_5_6 = 0.0
# y_5_7 = 0.0
# y_5_8 = 0.0
# y_6_1 = 0.0
# y_6_2 = 0.0
# y_6_3 = 1.0
# y_6_4 = 0.0
# y_6_5 = 0.0
# y_6_6 = 0.0
# y_6_7 = 0.0
# y_6_8 = 0.0
# z_1 = 3.0
# z_2 = 3.0
# z_3 = 3.0
# z_4 = 3.0
# z_5 = 3.0
# z_6 = 3.0
# Objective value: 4.321799999999999
#      t1  t2  t3  t4  t5  t6
# m1    1   0   1   0   1   1
# m2    0   0   0   0   1   1
# m3    1   0   0   1   0   0
# m4    0   1   0   0   0   0
# m5    0   0   0   1   0   0
# m6    0   1   0   1   0   0
# m7    0   0   1   0   1   0
# m8    1   1   1   0   0   1
# Sum   3   3   3   3   3   3

# %%
print(18*P[18])
print(18*p)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(18*P[18])
#       2 print(18*p)
#
# KeyError: 18
