# %% [markdown]
# # Original Objective function
# $$
# E(A_{i}) = \sum_{j \in \{1, \ldots, n\}}^{\text{tag}} k_{ij} q_j \prod_{i' \in \{1, \ldots, m\}}^{\text{msg}} \left( k_{i'j} p_{i'} + 0^{k_{i'j}} \right)
# $$

# %% [markdown]
# ### Simplification assumption
# We assume probobility of recieving a tag $q_{j}$ is equal to probobility of recieving message $p_{i}$
# $$q_{j} = p_{i} = p$$

# %% [markdown]
# ### C1 : Using all tags
# Each tag must verify at least one message
# $$
# \sum_{i=1}^{m} k_{ij} \geq 1 \quad \forall j \in \{1, 2, \ldots, \text{|T|}\}
# $$
# ### C2: Using all messages
# Each message must be signed with at least one tag
# $$
# \sum_{j=1}^{n} k_{ij} \geq 1 \quad \forall i \in \{1, 2, \ldots, \text{|M|}\}
# $$

# %% [markdown]
# ### C3: Define auxiliary varible for number of messages each tag signs
# we define number of messages that each tag signs as an auxiliray variable to use later in transforming objective function to a linear model
# $$
# z_j = \sum_{i=1}^{n} k_{ij} \quad \forall j \in \{1, 2, \ldots, \text{tags}\}
# $$
# $$
# z_j \geq 1 \quad \forall j \in \{1, 2, \ldots, \text{tags}\}
# $$

# %% [markdown]
# ### C4: Re-writing the product part in linear
# After simplifying all probobilities to be equal the product part could be linearized using some auxiliary variable and constraints as follow:
#
# $$
# \prod_{i' \in \{1, \ldots, m\}}^{\text{msg}} \left( k_{i'j} p_{i'} + 0^{k_{i'j}} \right) =  \sum_{i' \in \{1, \ldots, m\}}^{\text{msg}} w_{ji'} p^{i'}
# $$
#
#
# Now the next constraint should be define to force the correcponding $w_{ji'} = 1$ which can be done as follow

# %% [markdown]
# 1. **Link $ z[j] $ and $ y[j,i] $ using big-M constraints:**
#
# $$
# z[j] - i \leq M(1 - y[j,i])
# $$
#
# $$
# i - z[j] \leq M(1 - y[j,i])
# $$
#
# 2. **Ensure $ y[j,i] $ selects only one $ i $:**
#
# $$
# \sum_{i \in \{1, \ldots, m\}}^{\text{msg}} y[j,i] = 1
# $$
#
# 3. **Link $ w[j,i] $ to $ y[j,i] $:**
#
# $$
# w[j,i] \leq y[j,i]
# $$
#
# $$
# w[j,i] \geq y[j,i] - (1 - y[j,i])
# $$
#
# $$
# \sum_{i \in \{1, \ldots, m\}}^{\text{msg}} w[j,i] = 1
# $$

# %% [markdown]
# The final part is linearizing the product of the two binary variables $k_{ij}w_{j}$ which could be done this way:
#
# $$x_{mij} \leq k_{ij} $$
# $$x_{mij} \leq w_{ji'} $$
# $$x_{mij} \geq k_{ij} + w_{ji'} -1 $$
# $$x_{mij}\in \{0,1\}$$

# %% [markdown]
# ## Simplified Objective function
# With linearizing product part, the objective function could be rewritten as:
#
# $$
# E(A_{i}) =\sum_{i \in \{1, \ldots, m\}}^{\text{msg}} \sum_{j \in \{1, \ldots, n\}}^{\text{tag}} \sum_{i' \in \{1, \ldots, m\}}^{\text{msg}} x_{iji'} p^{i'+1}
#
# $$

# %%
import numpy as np
import pandas as pd
from pulp import *

# %%
def max_expected_A(n_tags, m_msgs, p):
   
    # Create a PuLP problem with maximization
    prob = LpProblem("Maximize_Expected_A", LpMaximize)

    # Define the binary variables k indexed by (i, j)
    k = {(i, j): LpVariable(f'k_{i}_{j}', cat='Binary') for i in range(1, m_msgs+1) for j in range(1, n_tags+1)}

    # Define the binary variables w indexed by (j,i)
    w = {(j, i): LpVariable(f'w_{j}_{i}', cat='Binary') for j in range(1, n_tags+1) for i in range(1, m_msgs+1)}

    # Define the binary variables x indexed by (i, j)
    x = {(i, j, m): LpVariable(f'x_{i}_{j}_{m}', cat='Binary') for i in range(1, m_msgs+1) for j in range(1, n_tags+1) for m in range(1, m_msgs+1)}

    # Define the binary variables y indexed by (j, i)
    y = {(j, i): LpVariable(f'y_{j}_{i}', cat='Binary') for j in range(1, n_tags+1) for i in range(1, m_msgs+1)}

    # Define the continuous variables z indexed by j
    z = {j: LpVariable(f'z_{j}', cat='Integer', lowBound=0) for j in range(1, n_tags+1)}

    # Constraints
    # for j in range(1, n_tags+1):
    #     prob += lpSum(k[i, j] for i in range(1, m_msgs+1)) >= 1, f"Tag_{j}_constraint"

    # for i in range(1, m_msgs+1):
    #     prob += lpSum(k[i, j] for j in range(1, n_tags+1)) >= 1, f"Message_{i}_constraint"

    for j in range(1, n_tags+1):
        prob += z[j] == lpSum(k[i, j] for i in range(1, m_msgs+1)), f"Z_{j}_definition"
        #prob += z[j] >= 1, f"Z_{j}_non_zero"
        
    for j in range(1, n_tags+1):
        prob += lpSum(w[j, i] for i in range(1, m_msgs+1)) == 1, f"Sum_w_{j}_equals_1"

    for j in range(1, n_tags+1):
        for i in range(1, m_msgs+1):
            prob += z[j] - i <= M * (1 - y[j,i]), f"BigM_1_{j}_{i}"
            prob += i - z[j] <= M * (1 - y[j,i]), f"BigM_2_{j}_{i}"

    for j in range(1, n_tags+1):
        prob += lpSum(y[j, i] for i in range(1, m_msgs+1)) == 1, f"y_{j}_{i}_equals_one"
    
    for j in range(1, n_tags+1):
        prob += lpSum(w[j, i] for i in range(1, m_msgs+1)) == 1, f"w_{j}_{i}_equals_one"

    for j in range(1, n_tags+1):
        for i in range(1, m_msgs+1):
            prob += w[j, i]  <= y[j, i] , f"w_{j}_{i}_less_y_{j}_{i}"

    for j in range(1, n_tags+1):
        for i in range(1, m_msgs+1):
            prob += w[j,i] >= y[j, i] - (1 - y[j,i])  , f"y_{j}_{i}_w_{j}_{i}"


    for i in range(1, m_msgs+1):
        for j in range(1, n_tags+1):
            for m in range(1, m_msgs+1):
                prob += x[i,j, m] <= k[i, j], f"x_{i}_{j}_{m}_leq_k_{i}_{j}"
                prob += x[i,j, m] <= w[j,m], f"x_{i}_{j}_{m}_leq_w_{j}_{m}"
                prob += x[i,j, m] >= k[i, j] + w[j,m] - 1, f"x_{i}_{j}_{m}_geq_k_{i}_{j}_plus_w_{j}_{m}_minus_1"


    # Objective Function
    prob += lpSum(x[i,j,m]*P[m] for i in range(1, m_msgs+1) for j in range(1, n_tags+1)for m in range(1, m_msgs+1)), "Maximize_E_A"

    # Solve the problem
    #solver = pulp.PULP_CBC_CMD(timeLimit=120)
    #prob.solve(solver)
    prob.solve()

    # Extract the optimal values of k_{ij}
    k_values = np.zeros((m_msgs, n_tags), dtype=int)
    for i in range(1, m_msgs+1):
        for j in range(1, n_tags+1):
            k_values[i-1, j-1] = value(k[i, j])


    k_df = pd.DataFrame(k_values, columns=[f'k_{j}' for j in range(1, n_tags+1)], index=[f'Msg_{i}' for i in range(1, m_msgs+1)])
    k_df.columns = [f't{i}' for i in range(1,n_tags+1)]
    k_df.index = [f'm{i}' for i in range(1,m_msgs+1)]


    sum_row = k_df.sum()
    k_df.loc['Sum'] = sum_row


    # Print the variable values
    for v in prob.variables():
        print(f"{v.name} = {v.varValue}")

    # Print the objective value
    print(f"Objective value: {value(prob.objective)}")


    return k_df

# %%
n_tags = 4
n_msgs = 8
p = 0.7
P = {i: p**(i) for i in range(1, n_msgs+2)}  # p^i coefficients
M = 1000     # A sufficiently large number for the constraints

# %%
K = max_expected_A(n_tags, n_msgs, p)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/jv/12n64fl91y1d9jr6561fpx2c0000gn/T/10f84086c9384c828ddcf24d0f48e377-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/jv/12n64fl91y1d9jr6561fpx2c0000gn/T/10f84086c9384c828ddcf24d0f48e377-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 917 COLUMNS
# At line 4066 RHS
# At line 4979 BOUNDS
# At line 5336 ENDATA
# Problem MODEL has 912 rows, 356 columns and 2180 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 22.3533 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 252 strengthened rows, 128 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 479 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 485 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 472 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 421 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 417 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 368 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 329 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 146 strengthened rows, 0 substitutions
# Cgl0004I processed model has 629 rows, 292 columns (292 integer (288 of which binary)) and 4166 elements
# Cbc0038I Initial state - 78 integers unsatisfied sum - 10.8694
# Cbc0038I Pass   1: suminf.    0.17618 (44) obj. -9.57293 iterations 311
# Cbc0038I Pass   2: suminf.    2.13213 (47) obj. -7.1797 iterations 53
# Cbc0038I Pass   3: suminf.    0.13213 (33) obj. -7.64088 iterations 12
# Cbc0038I Pass   4: suminf.    0.13213 (33) obj. -7.64088 iterations 9
# Cbc0038I Pass   5: suminf.    1.03673 (12) obj. -3.55017 iterations 87
# Cbc0038I Pass   6: suminf.    0.03116 (19) obj. -3.43539 iterations 29
# Cbc0038I Pass   7: suminf.    2.00000 (14) obj. -1.38355 iterations 35
# Cbc0038I Pass   8: suminf.    0.01200 (3) obj. -1.38355 iterations 41
# Cbc0038I Pass   9: suminf.    0.01200 (2) obj. -1.38355 iterations 3
# Cbc0038I Pass  10: suminf.    0.00800 (2) obj. -1.38355 iterations 5
# Cbc0038I Pass  11: suminf.    0.01000 (2) obj. -1.38355 iterations 3
# Cbc0038I Pass  12: suminf.   15.66667 (59) obj. -0.987387 iterations 129
# Cbc0038I Pass  13: suminf.    6.01080 (49) obj. -0.239235 iterations 89
# Cbc0038I Pass  14: suminf.    6.01000 (50) obj. -0.239379 iterations 2
# Cbc0038I Pass  15: suminf.    5.15286 (42) obj. -0.239379 iterations 22
# Cbc0038I Pass  16: suminf.    5.15286 (42) obj. -0.239379 iterations 0
# Cbc0038I Pass  17: suminf.    1.71461 (26) obj. -0.239379 iterations 30
# Cbc0038I Pass  18: suminf.    1.59943 (24) obj. -0.239379 iterations 7
# Cbc0038I Pass  19: suminf.    1.30571 (15) obj. 0 iterations 22
# Cbc0038I Pass  20: suminf.    1.30571 (15) obj. 0 iterations 4
# Cbc0038I Pass  21: suminf.    0.03600 (9) obj. 0 iterations 15
# Cbc0038I Pass  22: suminf.    0.03600 (8) obj. 0 iterations 3
# Cbc0038I Pass  23: suminf.    0.03200 (8) obj. 0 iterations 7
# Cbc0038I Pass  24: suminf.    0.03400 (8) obj. 0 iterations 7
# Cbc0038I Pass  25: suminf.    4.31753 (31) obj. -1.91872 iterations 54
# Cbc0038I Pass  26: suminf.    2.81023 (45) obj. -1.56509 iterations 79
# Cbc0038I Pass  27: suminf.    1.31372 (24) obj. -0.239379 iterations 65
# Cbc0038I Pass  28: suminf.    1.31372 (23) obj. -0.239379 iterations 4
# Cbc0038I Pass  29: suminf.    1.30371 (15) obj. 0 iterations 16
# Cbc0038I Pass  30: suminf.    1.30371 (15) obj. 0 iterations 2
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 141 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 629 rows 292 columns, reduced to 449 rows 151 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.24 seconds)
# Cbc0038I After 0.24 seconds - Feasibility pump exiting - took 0.03 seconds
# Cbc0012I Integer solution of -3.92 found by DiveCoefficient after 14735 iterations and 0 nodes (1.28 seconds)
# Cbc0031I 39 added rows had average density of 67.307692
# Cbc0013I At root node, 39 cuts changed objective from -10.467328 to -6.5328023 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 243 row cuts average 7.2 elements, 0 column cuts (0 active)  in 0.189 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 3037 row cuts average 71.6 elements, 0 column cuts (0 active)  in 0.123 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 1 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.045 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 4 row cuts average 57.0 elements, 0 column cuts (0 active)  in 0.066 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 1 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.034 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 450 row cuts average 53.3 elements, 0 column cuts (0 active)  in 0.079 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -3.92 best solution, best possible -6.5328023 (1.45 seconds)
# Cbc0038I Full problem 629 rows 292 columns, reduced to 380 rows 143 columns - 8 fixed gives 32, 26 - ok now
# Cbc0012I Integer solution of -3.969 found by DiveCoefficient after 15711 iterations and 2 nodes (1.58 seconds)
# Cbc0016I Integer solution of -3.9984 found by strong branching after 17106 iterations and 38 nodes (2.03 seconds)
# Cbc0038I Full problem 629 rows 292 columns, reduced to 264 rows 103 columns
# Cbc0016I Integer solution of -4.0474 found by strong branching after 19204 iterations and 78 nodes (2.55 seconds)
# Cbc0038I Full problem 629 rows 292 columns, reduced to 129 rows 47 columns
# Cbc0038I Full problem 629 rows 292 columns, reduced to 133 rows 53 columns
# Cbc0038I Full problem 629 rows 292 columns, reduced to 148 rows 55 columns
# Cbc0038I Full problem 629 rows 292 columns, reduced to 130 rows 50 columns
# Cbc0038I Full problem 629 rows 292 columns, reduced to 163 rows 60 columns
# Cbc0010I After 1000 nodes, 13 on tree, -4.0474 best solution, best possible -6.5328023 (7.66 seconds)
# Cbc0038I Full problem 629 rows 292 columns, reduced to 178 rows 67 columns
# Cbc0038I Full problem 629 rows 292 columns, reduced to 187 rows 72 columns
# Cbc0038I Full problem 629 rows 292 columns, reduced to 203 rows 77 columns
# Cbc0038I Full problem 629 rows 292 columns, reduced to 225 rows 86 columns
# Cbc0010I After 2000 nodes, 7 on tree, -4.0474 best solution, best possible -6.5328023 (12.42 seconds)
# Cbc0004I Integer solution of -4.067 found after 127772 iterations and 2528 nodes (14.60 seconds)
# Cbc0012I Integer solution of -4.116 found by rounding after 128301 iterations and 2537 nodes (14.66 seconds)
# Cbc0001I Search completed - best objective -4.116000000000001, took 153027 iterations and 2994 nodes (17.53 seconds)
# Cbc0032I Strong branching done 18928 times (474697 iterations), fathomed 304 nodes and fixed 901 variables
# Cbc0035I Maximum depth 36, 3690 variables fixed on reduced cost
# Cuts at root node changed objective from -10.4673 to -6.5328
# Probing was tried 3041 times and created 15956 cuts of which 0 were active after adding rounds of cuts (1.197 seconds)
# Gomory was tried 2962 times and created 3058 cuts of which 0 were active after adding rounds of cuts (0.742 seconds)
# Knapsack was tried 100 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.045 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# MixedIntegerRounding2 was tried 100 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.066 seconds)
# FlowCover was tried 100 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.034 seconds)
# TwoMirCuts was tried 2962 times and created 741 cuts of which 0 were active after adding rounds of cuts (1.030 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.11600000
# Enumerated nodes:               2994
# Total iterations:               153027
# Time (CPU seconds):             17.39
# Time (Wallclock seconds):       17.55
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       17.39   (Wallclock seconds):       17.56
#
# k_1_1 = 0.0
# k_1_2 = 1.0
# k_1_3 = 1.0
# k_1_4 = 1.0
# k_2_1 = 1.0
# k_2_2 = 0.0
# k_2_3 = 0.0
# k_2_4 = 0.0
# k_3_1 = 0.0
# k_3_2 = 0.0
# k_3_3 = 0.0
# k_3_4 = 1.0
# k_4_1 = 1.0
# k_4_2 = 1.0
# k_4_3 = 1.0
# k_4_4 = 0.0
# k_5_1 = 0.0
# k_5_2 = 1.0
# k_5_3 = 0.0
# k_5_4 = 1.0
# k_6_1 = 1.0
# k_6_2 = 0.0
# k_6_3 = 1.0
# k_6_4 = 0.0
# k_7_1 = 0.0
# k_7_2 = 0.0
# k_7_3 = 0.0
# k_7_4 = 0.0
# k_8_1 = 0.0
# k_8_2 = 0.0
# k_8_3 = 0.0
# k_8_4 = 0.0
# w_1_1 = 0.0
# w_1_2 = 0.0
# w_1_3 = 1.0
# w_1_4 = 0.0
# w_1_5 = 0.0
# w_1_6 = 0.0
# w_1_7 = 0.0
# w_1_8 = 0.0
# w_2_1 = 0.0
# w_2_2 = 0.0
# w_2_3 = 1.0
# w_2_4 = 0.0
# w_2_5 = 0.0
# w_2_6 = 0.0
# w_2_7 = 0.0
# w_2_8 = 0.0
# w_3_1 = 0.0
# w_3_2 = 0.0
# w_3_3 = 1.0
# w_3_4 = 0.0
# w_3_5 = 0.0
# w_3_6 = 0.0
# w_3_7 = 0.0
# w_3_8 = 0.0
# w_4_1 = 0.0
# w_4_2 = 0.0
# w_4_3 = 1.0
# w_4_4 = 0.0
# w_4_5 = 0.0
# w_4_6 = 0.0
# w_4_7 = 0.0
# w_4_8 = 0.0
# x_1_1_1 = 0.0
# x_1_1_2 = 0.0
# x_1_1_3 = 0.0
# x_1_1_4 = 0.0
# x_1_1_5 = 0.0
# x_1_1_6 = 0.0
# x_7_1_8 = 0.0
# x_7_2_1 = 0.0
# x_7_2_2 = 0.0
# x_7_2_3 = 0.0
# x_7_2_4 = 0.0
# x_7_2_5 = 0.0
# x_7_2_6 = 0.0
# x_7_2_7 = 0.0
# x_7_2_8 = 0.0
# x_7_3_1 = 0.0
# x_7_3_2 = 0.0
# x_7_3_3 = 0.0
# x_7_3_4 = 0.0
# x_7_3_5 = 0.0
# x_7_3_6 = 0.0
# x_7_3_7 = 0.0
# x_7_3_8 = 0.0
# x_7_4_1 = 0.0
# x_7_4_2 = 0.0
# x_7_4_3 = 0.0
# x_7_4_4 = 0.0
# x_7_4_5 = 0.0
# x_7_4_6 = 0.0
# x_7_4_7 = 0.0
# x_7_4_8 = 0.0
# x_8_1_1 = 0.0
# x_8_1_2 = 0.0
# x_8_1_3 = 0.0
# x_8_1_4 = 0.0
# x_8_1_5 = 0.0
# x_8_1_6 = 0.0
# x_8_1_7 = 0.0
# x_8_1_8 = 0.0
# x_8_2_1 = 0.0
# x_8_2_2 = 0.0
# x_8_2_3 = 0.0
# x_8_2_4 = 0.0
# x_8_2_5 = 0.0
# x_8_2_6 = 0.0
# x_8_2_7 = 0.0
# x_8_2_8 = 0.0
# x_8_3_1 = 0.0
# x_8_3_2 = 0.0
# x_8_3_3 = 0.0
# x_8_3_4 = 0.0
# x_8_3_5 = 0.0
# x_8_3_6 = 0.0
# x_8_3_7 = 0.0
# x_8_3_8 = 0.0
# x_8_4_1 = 0.0
# x_8_4_2 = 0.0
# x_8_4_3 = 0.0
# x_8_4_4 = 0.0
# x_8_4_5 = 0.0
# x_8_4_6 = 0.0
# x_8_4_7 = 0.0
# x_8_4_8 = 0.0
# y_1_1 = 0.0
# y_1_2 = 0.0
# y_1_3 = 1.0
# y_1_4 = 0.0
# y_1_5 = 0.0
# y_1_6 = 0.0
# y_1_7 = 0.0
# y_1_8 = 0.0
# y_2_1 = 0.0
# y_2_2 = 0.0
# y_2_3 = 1.0
# y_2_4 = 0.0
# y_2_5 = 0.0
# y_2_6 = 0.0
# y_2_7 = 0.0
# y_2_8 = 0.0
# y_3_1 = 0.0
# y_3_2 = 0.0
# y_3_3 = 1.0
# y_3_4 = 0.0
# y_3_5 = 0.0
# y_3_6 = 0.0
# y_3_7 = 0.0
# y_3_8 = 0.0
# y_4_1 = 0.0
# y_4_2 = 0.0
# y_4_3 = 1.0
# y_4_4 = 0.0
# y_4_5 = 0.0
# y_4_6 = 0.0
# y_4_7 = 0.0
# y_4_8 = 0.0
# z_1 = 3.0
# z_2 = 3.0
# z_3 = 3.0
# z_4 = 3.0
# Objective value: 4.115999999999999
#      t1  t2  t3  t4
# m1    0   1   1   1
# m2    1   0   0   0
# m3    0   0   0   1
# m4    1   1   1   0
# m5    0   1   0   1
# m6    1   0   1   0
# m7    0   0   0   0
# m8    0   0   0   0
# Sum   3   3   3   3
