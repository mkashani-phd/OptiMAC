# %% [markdown]
# Objective:
# $$ Max \sum_{i \in \{1, \ldots, m\}}^{\text{msg}} \sum_{j \in \{1, \ldots, n\}}^{\text{tag}} \sum_{i' \in \{1, \ldots, m\}}^{\text{msg}} y_{iji'} p^{i'}$$

# %% [markdown]
# Subject to:
#
# $$
# \sum_{i \in \{1, \ldots, m\}}^{\text{msg}} k_{ij} - \sum_{i' \in \{1, \ldots, m\}}^{\text{msg}} i' z_{ji'} =0  \quad \forall j \in \{1,...n\}
# $$
#
# $$
# \sum_{i' \in \{0, \ldots, m\}}^{\text{msg}}  z_{ji'} <=1 \quad \forall j \in \{1,...n\}
# $$

# %% [markdown]
# $$
# k_{ij} - z_{ji'} - 2y_{iji'} >=0 \quad \forall i \in \{1,..m\} \quad \forall j \in \{1,..n\} \quad \forall i' \in \{0,..m\}
# $$

# %% [markdown]
# $$
# \sum_{j \in \{1, \ldots, n\}}^{\text{tag}}  k_{ij} >=1 \quad \forall i \in \{1,...m\}
# $$

# %%
import numpy as np
import pandas as pd
from pulp import *

# %%
def max_expected_A(n_tags, m_msgs, p):
   
    # Create a PuLP problem with maximization
    prob = LpProblem("Maximize_Expected_A", LpMaximize)

    # Define the binary variables k indexed by (i, j)
    k = {(i, j): LpVariable(f'k_{i}_{j}', cat='Binary') for i in range(1, m_msgs+1) for j in range(1, n_tags+1)}

    # Define the binary variables x indexed by (i, j,i')
    y = {(i, j, m): LpVariable(f'x_{i}_{j}_{m}', cat='Binary') for i in range(1, m_msgs+1) for j in range(1, n_tags+1) for m in range(0, m_msgs+1)}

    
    # Define the continuous variables z indexed by j
    z = {(j,m): LpVariable(f'z_{j}_{m}', cat='Integer', lowBound=0) for j in range(1, n_tags+1) for m in range(0, m_msgs+1)}

    # Constraints
  
    for j in range(1, n_tags+1):
        prob += lpSum(k[i, j] for i in range(1, m_msgs+1)) - lpSum(m*z[j, m] for m in range(1, m_msgs+1)) == 0, f"Sum_k_{j}_equal_z_{j}"

    for j in range(1, n_tags+1):
            prob += lpSum(z[j, m] for m in range(0, m_msgs+1)) <= 1, f"Sum_z_{j}_less_than_1"

    for i in range(1, m_msgs+1):
        for j in range(1, n_tags+1):
            for m in range(1, m_msgs+1):
                 prob += k[i,j]+z[j,m] - 2*y[i,j,m] >= 0, f"Constraint_{i}_{j}_{m}"
    
    for j in range(1, n_tags+1):
        prob += lpSum(k[i, j] for i in range(1, m_msgs+1)) >= 1, f"Sum_k_{j}_greater_than_1"


    # Objective Function
    prob += lpSum(y[i,j,m]*P[m] for i in range(1, m_msgs+1) for j in range(1, n_tags+1)for m in range(1, m_msgs+1)), "Maximize_E_A"

    # Solve the problem
    #solver = pulp.PULP_CBC_CMD(timeLimit=120)
    #prob.solve(solver)
    prob.solve()

    # Extract the optimal values of k_{ij}
    k_values = np.zeros((m_msgs, n_tags), dtype=int)
    for i in range(1, m_msgs+1):
        for j in range(1, n_tags+1):
            k_values[i-1, j-1] = value(k[i, j])


    k_df = pd.DataFrame(k_values, columns=[f'k_{j}' for j in range(1, n_tags+1)], index=[f'Msg_{i}' for i in range(1, m_msgs+1)])
    k_df.columns = [f't{i}' for i in range(1,n_tags+1)]
    k_df.index = [f'm{i}' for i in range(1,m_msgs+1)]


    sum_row = k_df.sum()
    k_df.loc['Sum'] = sum_row


    # Print the variable values
    for v in prob.variables():
        print(f"{v.name} = {v.varValue}")

    # Print the objective value
    print(f"Objective value: {value(prob.objective)}")


    return k_df

# %%
n_tags = 5
m_msgs = 6
p = 0.5
P = {i: p**(i+1) for i in range(0, m_msgs+2)}  # p^i coefficients
M = 1000     # A sufficiently large number for the constraints

# %%
max_expected_A(n_tags, m_msgs, p)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/jv/12n64fl91y1d9jr6561fpx2c0000gn/T/5c96e47d71b44ed097d2a902429acc42-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/jv/12n64fl91y1d9jr6561fpx2c0000gn/T/5c96e47d71b44ed097d2a902429acc42-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 200 COLUMNS
# At line 1536 RHS
# At line 1732 BOUNDS
# At line 1978 ENDATA
# Problem MODEL has 195 rows, 245 columns and 665 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 185 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 180 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 180 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 180 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 180 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 30 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 30 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 30 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 30 strengthened rows, 0 substitutions
# Cgl0004I processed model has 195 rows, 240 columns (240 integer (240 of which binary)) and 1685 elements
# Cutoff increment increased from 1e-05 to 0.00780469
# Cbc0038I Initial state - 74 integers unsatisfied sum - 20.6181
# Cbc0038I Solution found of -0.125
# Cbc0038I Before mini branch and bound, 166 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 195 rows 240 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.10 seconds)
# Cbc0038I Round again with cutoff of -0.360276
# Cbc0038I Pass   1: suminf.    0.94110 (2) obj. -0.360276 iterations 109
# Cbc0038I Pass   2: suminf.    1.00000 (2) obj. -0.375 iterations 2
# Cbc0038I Pass   3: suminf.   16.99792 (49) obj. -0.803304 iterations 71
# Cbc0038I Pass   4: suminf.    3.17694 (17) obj. -0.360276 iterations 62
# Cbc0038I Pass   5: suminf.    2.46048 (12) obj. -0.360276 iterations 16
# Cbc0038I Pass   6: suminf.    2.46048 (12) obj. -0.360276 iterations 2
# Cbc0038I Pass   7: suminf.    1.51971 (5) obj. -0.360276 iterations 17
# Cbc0038I Pass   8: suminf.    1.48485 (5) obj. -0.360276 iterations 8
# Cbc0038I Pass   9: suminf.    1.89667 (6) obj. -0.393229 iterations 4
# Cbc0038I Pass  10: suminf.    1.76485 (6) obj. -0.360276 iterations 4
# Cbc0038I Pass  11: suminf.    1.61667 (5) obj. -0.393229 iterations 3
# Cbc0038I Pass  12: suminf.   12.70000 (32) obj. -0.809635 iterations 43
# Cbc0038I Pass  13: suminf.    3.02735 (11) obj. -0.360276 iterations 34
# Cbc0038I Pass  14: suminf.    3.04149 (10) obj. -0.360276 iterations 21
# Cbc0038I Pass  15: suminf.    2.95577 (12) obj. -0.360276 iterations 9
# Cbc0038I Pass  16: suminf.    3.28714 (12) obj. -0.392411 iterations 14
# Cbc0038I Pass  17: suminf.    2.95577 (12) obj. -0.360276 iterations 11
# Cbc0038I Pass  18: suminf.    3.28714 (12) obj. -0.392411 iterations 13
# Cbc0038I Pass  19: suminf.    2.95577 (12) obj. -0.360276 iterations 11
# Cbc0038I Pass  20: suminf.    3.28714 (12) obj. -0.392411 iterations 14
# Cbc0038I Pass  21: suminf.   10.13333 (36) obj. -0.710579 iterations 66
# Cbc0038I Pass  22: suminf.    3.42664 (15) obj. -0.360276 iterations 41
# Cbc0038I Pass  23: suminf.    2.22496 (12) obj. -0.360276 iterations 7
# Cbc0038I Pass  24: suminf.    3.64211 (15) obj. -0.360276 iterations 25
# Cbc0038I Pass  25: suminf.    3.64211 (15) obj. -0.360276 iterations 6
# Cbc0038I Pass  26: suminf.    3.93399 (14) obj. -0.360276 iterations 18
# Cbc0038I Pass  27: suminf.    3.36065 (11) obj. -0.360276 iterations 5
# Cbc0038I Pass  28: suminf.    3.36065 (11) obj. -0.360276 iterations 1
# Cbc0038I Pass  29: suminf.    3.72957 (14) obj. -0.360276 iterations 11
# Cbc0038I Pass  30: suminf.    3.59399 (13) obj. -0.360276 iterations 5
# Cbc0038I Rounding solution of -0.234375 is better than previous of -0.125
#
# Cbc0038I Before mini branch and bound, 90 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 195 rows 240 columns, reduced to 185 rows 150 columns - 7 fixed gives 150, 120 - still too large
# Cbc0038I Full problem 195 rows 240 columns, reduced to 39 rows 36 columns
# Cbc0038I Mini branch and bound improved solution from -0.234375 to -0.242188 (0.13 seconds)
# Cbc0038I Round again with cutoff of -0.769724
# Cbc0038I Pass  30: suminf.    2.57890 (6) obj. -0.769724 iterations 10
# Cbc0038I Pass  31: suminf.    2.75000 (6) obj. -0.8125 iterations 6
# Cbc0038I Pass  32: suminf.   16.16154 (45) obj. -1.0003 iterations 68
# Cbc0038I Pass  33: suminf.    4.62111 (16) obj. -0.769724 iterations 47
# Cbc0038I Pass  34: suminf.    3.90025 (15) obj. -0.769724 iterations 6
# Cbc0038I Pass  35: suminf.    2.99131 (12) obj. -0.769724 iterations 22
# Cbc0038I Pass  36: suminf.    2.99131 (12) obj. -0.769724 iterations 10
# Cbc0038I Pass  37: suminf.    3.19765 (13) obj. -0.769724 iterations 15
# Cbc0038I Pass  38: suminf.    3.04529 (12) obj. -0.769724 iterations 8
# Cbc0038I Pass  39: suminf.    3.38333 (12) obj. -0.811979 iterations 5
# Cbc0038I Pass  40: suminf.   11.95465 (36) obj. -0.769724 iterations 69
# Cbc0038I Pass  41: suminf.    6.73103 (24) obj. -0.769724 iterations 34
# Cbc0038I Pass  42: suminf.    5.23696 (19) obj. -0.769724 iterations 18
# Cbc0038I Pass  43: suminf.    4.32446 (17) obj. -0.769724 iterations 22
# Cbc0038I Pass  44: suminf.    4.24186 (17) obj. -0.769724 iterations 17
# Cbc0038I Pass  45: suminf.    5.20779 (17) obj. -0.769724 iterations 19
# Cbc0038I Pass  46: suminf.    3.92890 (15) obj. -0.769724 iterations 19
# Cbc0038I Pass  47: suminf.    3.92890 (15) obj. -0.769724 iterations 9
# Cbc0038I Pass  48: suminf.    5.00779 (16) obj. -0.769724 iterations 23
# Cbc0038I Pass  49: suminf.    3.92890 (14) obj. -0.769724 iterations 18
# Cbc0038I Pass  50: suminf.    3.92890 (14) obj. -0.769724 iterations 3
# Cbc0038I Pass  51: suminf.    4.90779 (16) obj. -0.769724 iterations 31
# Cbc0038I Pass  52: suminf.    4.79603 (17) obj. -0.769724 iterations 16
# Cbc0038I Pass  53: suminf.    4.81035 (18) obj. -0.769724 iterations 12
# Cbc0038I Pass  54: suminf.    4.81035 (18) obj. -0.769724 iterations 6
# Cbc0038I Pass  55: suminf.    4.85779 (17) obj. -0.769724 iterations 24
# Cbc0038I Pass  56: suminf.   11.41563 (34) obj. -0.769724 iterations 64
# Cbc0038I Pass  57: suminf.    5.31612 (20) obj. -0.769724 iterations 38
# Cbc0038I Pass  58: suminf.    4.98279 (21) obj. -0.769724 iterations 9
# Cbc0038I Pass  59: suminf.    5.77893 (20) obj. -0.769724 iterations 20
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 88 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 195 rows 240 columns, reduced to 185 rows 152 columns - 30 fixed gives 93, 70 - ok now
# Cbc0038I Full problem 195 rows 240 columns, reduced to 39 rows 32 columns
# Cbc0038I Mini branch and bound did not improve solution (0.16 seconds)
# Cbc0038I After 0.16 seconds - Feasibility pump exiting with objective of -0.242188 - took 0.05 seconds
# Cbc0012I Integer solution of -0.2421875 found by feasibility pump after 0 iterations and 0 nodes (0.16 seconds)
# Cbc0031I 69 added rows had average density of 23.884058
# Cbc0013I At root node, 69 cuts changed objective from -2.4075163 to -1.4003873 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 3380 row cuts average 2.3 elements, 0 column cuts (0 active)  in 0.133 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 3187 row cuts average 47.6 elements, 0 column cuts (0 active)  in 0.053 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 576 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.220 seconds - new frequency is 1
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 225 row cuts average 39.9 elements, 0 column cuts (0 active)  in 0.036 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 852 row cuts average 22.4 elements, 0 column cuts (0 active)  in 0.037 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 746 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.354 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -0.2421875 best solution, best possible -1.4003873 (1.40 seconds)
# Cbc0012I Integer solution of -0.5625 found by DiveCoefficient after 14477 iterations and 4 nodes (1.58 seconds)
# Cbc0004I Integer solution of -1.0625 found after 16538 iterations and 19 nodes (1.87 seconds)
# Cbc0004I Integer solution of -1.09375 found after 16975 iterations and 25 nodes (1.92 seconds)
# Cbc0016I Integer solution of -1.1875 found by strong branching after 17189 iterations and 30 nodes (1.96 seconds)
# Cbc0016I Integer solution of -1.25 found by strong branching after 17217 iterations and 31 nodes (1.96 seconds)
# Cbc0038I Full problem 195 rows 240 columns, reduced to 77 rows 47 columns
# Cbc0001I Search completed - best objective -1.25, took 22393 iterations and 76 nodes (2.69 seconds)
# Cbc0032I Strong branching done 1318 times (24458 iterations), fathomed 14 nodes and fixed 18 variables
# Cbc0035I Maximum depth 17, 448 variables fixed on reduced cost
# Cuts at root node changed objective from -2.40752 to -1.40039
# Probing was tried 264 times and created 5155 cuts of which 0 were active after adding rounds of cuts (0.168 seconds)
# Gomory was tried 264 times and created 3860 cuts of which 0 were active after adding rounds of cuts (0.092 seconds)
# Knapsack was tried 264 times and created 892 cuts of which 0 were active after adding rounds of cuts (0.370 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 264 times and created 434 cuts of which 0 were active after adding rounds of cuts (0.076 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 264 times and created 1514 cuts of which 0 were active after adding rounds of cuts (0.086 seconds)
# ZeroHalf was tried 264 times and created 1386 cuts of which 0 were active after adding rounds of cuts (0.808 seconds)
# ImplicationCuts was tried 136 times and created 1823 cuts of which 0 were active after adding rounds of cuts (0.065 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1.25000000
# Enumerated nodes:               76
# Total iterations:               22393
# Time (CPU seconds):             2.61
# Time (Wallclock seconds):       2.70
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.61   (Wallclock seconds):       2.71
#
# k_1_1 = 0.0
# k_1_2 = 0.0
# k_1_3 = 0.0
# k_1_4 = 1.0
# k_1_5 = 1.0
# k_2_1 = 0.0
# k_2_2 = 1.0
# k_2_3 = 0.0
# k_2_4 = 0.0
# k_2_5 = 0.0
# k_3_1 = 0.0
# k_3_2 = 0.0
# k_3_3 = 0.0
# k_3_4 = 1.0
# k_3_5 = 0.0
# k_4_1 = 0.0
# k_4_2 = 0.0
# k_4_3 = 0.0
# k_4_4 = 0.0
# k_4_5 = 0.0
# k_5_1 = 1.0
# k_5_2 = 0.0
# k_5_3 = 1.0
# k_5_4 = 0.0
# k_5_5 = 0.0
# k_6_1 = 0.0
# k_6_2 = 0.0
# k_6_3 = 0.0
# k_6_4 = 0.0
# k_6_5 = 0.0
# x_1_1_1 = 0.0
# x_1_1_2 = 0.0
